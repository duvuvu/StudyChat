# %%
# Imports section
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ## Part 1. Loading the dataset

# %%
# Using pandas load the dataset (load remotely, not locally)
sci_data = pd.read_csv("science_data_large.csv")
# Output the first 15 rows of the data
print(sci_data.head(15))
# Display a summary of the table information (number of datapoints, etc.)
print(sci_data.info())
# Out:
#     Temperature °C  Mols KCL     Size nm^3
# 0              469       647  6.244743e+05
# 1              403       694  5.779610e+05
# 2              302       975  6.196847e+05
# 3              779       916  1.460449e+06
# 4              901        18  4.325726e+04
# 5              545       637  7.124634e+05
# 6              660       519  7.006960e+05
# 7              143       869  2.718260e+05
# 8               89       461  8.919803e+04
# 9              294       776  4.770210e+05
# 10             991       117  2.441771e+05
# 11             307       781  5.006455e+05
# 12             206        70  3.145200e+04
# 13             437       599  5.390215e+05
# 14             566        75  9.185271e+04
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temperature °C  1000 non-null   int64
# ...

# %% [markdown]
# ## Part 2. Splitting the dataset

# %%
# Take the pandas dataset and split it into our features (X) and label (y)
labels = sci_data.iloc[:,-1]
print(labels)
features = sci_data.iloc[:, :]
print(features)
# Use sklearn to split the features and labels into a training/test set. (90% train, 10% test)
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.1, train_size=0.9, random_state=42)
# Out:
# 0      6.244743e+05
# 1      5.779610e+05
# 2      6.196847e+05
# 3      1.460449e+06
# 4      4.325726e+04
#            ...
# 995    1.545661e+06
# 996    6.737041e+05
# 997    3.477543e+05
# 998    8.684794e+05
# 999    8.476413e+05
# Name: Size nm^3, Length: 1000, dtype: float64
#      Temperature °C  Mols KCL     Size nm^3
# 0               469       647  6.244743e+05
# 1               403       694  5.779610e+05
# 2               302       975  6.196847e+05
# 3               779       916  1.460449e+06
# 4               901        18  4.325726e+04
# ..              ...       ...           ...
# 995             894       847  1.545661e+06
# 996             327       982  6.737041e+05
# 997             791       213  3.477543e+05
# 998             769       553  8.684794e+05
# 999             919       452  8.476413e+05
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## Part 3. Perform a Linear Regression

# %%
# Use sklearn to train a model on the training set
reg = LinearRegression().fit(X_train, y_train)
# Create a sample datapoint and predict the output of that sample with the trained model
sample_row = features.iloc[2]
sample = [sample_row.values]
print(reg.predict(sample))
# Report on the score for that model, in your own words (markdown, not code) explain what the score means
print(reg.score(X_train, y_train))

# Extract the coefficents and intercept from the model and write an equation for your h(x) using LaTeX
# Out:
# [619684.7143]
# 1.0
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# The Score of this model is the best possible score as it is a 1.0, so it is explaining the variance the best that it can for a model.

# %% [markdown]
# Sample equation: $E = mc^2$

# %% [markdown]
# ## Part 4. Use Cross Validation

# %%
# Use the cross_val_score function to repeat your experiment across many shuffles of the data
clf = svm.SVC(kernel='linear', C=1, random_state=42)
labels_int = labels.astype(int)

print(features.shape)
print(labels_int.shape)

print(features.value_counts())


scores = cross_val_score(clf, features, labels_int, cv=5)
# Report on their finding and their significance
# Out:
# (1000, 3)
# (1000,)
# Temperature °C  Mols KCL  Size nm^3
# 1000            600       1.222286e+06    1
# 1               2         1.611429e+01    1
# 2               3         3.625714e+01    1
# 3               5         6.671429e+01    1
# 4               7         1.054000e+02    1
#                                          ..
# 13              41        1.270029e+03    1
# 12              37        1.071114e+03    1
# 11              31        8.414571e+02    1
# 10              29        7.240286e+02    1
# 9               23        5.371143e+02    1
# Name: count, Length: 1000, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 11
#       6 print(labels_int.shape)
#       8 print(features.value_counts())
# ---> 11 scores = cross_val_score(clf, features, labels_int, cv=5)
#      12 # Report on their finding and their significance
#
# ...

# %% [markdown]
# No Matter What I can not get past this error with the cross_val_score

# %% [markdown]
# ## Part 5. Using Polynomial Regression

# %%
# Using the PolynomialFeatures library perform another regression on an augmented dataset of degree 2
poly = PolynomialFeatures(2)
poly.fit_transform(features)
poly = PolynomialFeatures(interaction_only=True)
poly.fit_transform(features)
# Report on the metrics and output the resultant equation as you did in Part 3.
# Out:
# array([[1.00000000e+00, 4.69000000e+02, 6.47000000e+02, ...,
#         3.03443000e+05, 2.92878427e+08, 4.04034844e+08],
#        [1.00000000e+00, 4.03000000e+02, 6.94000000e+02, ...,
#         2.79682000e+05, 2.32918295e+08, 4.01104954e+08],
#        [1.00000000e+00, 3.02000000e+02, 9.75000000e+02, ...,
#         2.94450000e+05, 1.87144784e+08, 6.04192596e+08],
#        ...,
#        [1.00000000e+00, 7.91000000e+02, 2.13000000e+02, ...,
#         1.68483000e+05, 2.75073617e+08, 7.40716568e+07],
#        [1.00000000e+00, 7.69000000e+02, 5.53000000e+02, ...,
#         4.25257000e+05, 6.67860659e+08, 4.80269108e+08],
#        [1.00000000e+00, 9.19000000e+02, 4.52000000e+02, ...,
#         4.15388000e+05, 7.78982315e+08, 3.83133848e+08]])

# %%
# Imports and pip installations (if needed)
import pandas as pd

# %% [markdown]
# # Part 1: Load the dataset

# %%
# Load the given datasets
categorical = pd.read_csv("chronic_kidney_disease_categorical.csv")
numerical = pd.read_csv("chronic_kidney_disease_numerical.csv")

# Print the data
categorical
numerical

# %% [markdown]
# # Part 2: Analyze the Dataset

# %% [markdown]
# Refer to this: https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease
#
# Explain what the each data is in your own words. What are the features and labels? Are the features in the given datasets : categorical, numerical or both? Give 3 examples of categorical and numerical columns each (if they exist)

# %% [markdown]
# Answer: There are 24 features in the dataset (age, blood pressure, specific gravity, albumin, sugar, red blood cells, pus cell, pus cell clumps, bacteria, blood gluscose random, blood urea, serum creatinine, sodium, potassium, hemoglobin, packed cell volume, white blood cell count, red blood cell count, hypertension, diabetes mellitus, coronary artery disease, appetitie, pedal edema, anemia). These help to predict the label which is to predict the chronic kidney disease. There are both categorical and numerical features. There are other features beyond these two as well such as binary (boolean) and continuous. Three categorical features are 'specific gravity', 'albumin', and 'sugar'. Three numerical features are 'blood pressure', 'packed cell volume', and 'white blood cell count'.

# %% [markdown]
# # Part 3: Data Preprocessing
#
# A fundamental skill in Machine Learning is mastering the art of data cleaning and preprocessing. In this assignment, you will learn and apply essential data cleaning techniques to transform a raw dataset into a clean, ready-to-use form which you can use for regression or classification tasks. By the end of this assignment, you'll have a fully clean dataset and a solid foundation in preparing data for various machine learning models.

# %% [markdown]
# ## Part 3.1 : Drop Duplicate rows
#
# Let's start by checking if the given datasets have any duplicate rows (same Unique Id). Use pandas to identify and remove these duplicate rows from the given dataset

# %%
# For the numerical dataset, check if there are duplicate rows in the dataset. If yes, print total number of duplicate rows
num_bool = numerical.duplicated(subset = ['unique_id'], keep = "first")

num_dup = 0

for i in num_bool: 
    if i:
        num_dup += 1

if num_dup > 0:
    print(f"There are {num_dup} duplicate rows in numerical.")
else:
    print("There are no duplicate rows in numerical.")

# Drop these duplicate rows
numerical_drop_dup = numerical.drop_duplicates(subset = ['unique_id'], keep = "first")

# Repeat the same for categorical dataset. Print the duplicate rows and drop them
cat_bool = categorical.duplicated(subset = ['unique_id'], keep = "first")

cat_dup = 0

for i in cat_bool: 
    if i:
        cat_dup += 1

if cat_dup > 0:
    print(f"There are {cat_dup} duplicate rows in categorical.")
else:
    print("There are no duplicate rows in categorical.")


categorical_drop_dup = categorical.drop_duplicates(subset = ['unique_id'], keep = "first")

# %% [markdown]
# ## Part 3.2: Combine two differents datasets
#
# A good skill to have is to know how to combine 2 different datasets.
#
# Are all the unique ids are present in both datasets? Why do you think so? If not, what do the rows that are missing from one of the datasets look like in the combined table?

# %% [markdown]
# Answer:

# %%
# Merge the two given numerical and categorical datasets based on their unique_ID.

#Print the combined dataset
merged

# %% [markdown]
# ## Part 3.3: Rows with Missing values
#
# Removing missing values from a dataset is important for classification because it ensures the model is trained on complete and accurate data, leading to better performance and reliable predictions. Incomplete data can introduce bias and errors, negatively impacting the model's effectiveness.

# %%
# Calculate the percentage of rows that contain atleast one missing value
missing_rows = 0

for i in range(len(merged.index)):
    if merged.loc[i].isnull().values.any():
        missing_rows += 1

# Print %
print(f"{round((missing_rows / len(merged.index)) * 100 )}% of rows contain at least one missing value" )

# Drop these rows from the dataset
dropped = merged.dropna()

# Print the Dataset
dropped

# %% [markdown]
# ## Part 3.4: Sort the dataset according to the Labels

# %%
# Sort the dataset according to the values in 'Target' column. Make sure reset the indices after sorting
sorted = dropped.sort_values(by = ['Target'])

# Print the dataset
sorted

# %% [markdown]
# ## Part 3.5: Encoding Categorical data
#
# In this step, we identify and process the categorical columns in the sorted dataset. We map each unique value in these columns to separate "dummy" columns.
#
# For example, the column 'rbc' will be transformed into two columns 'rbc_normal' and 'rbc_abnormal'. If a row's value in 'rbc' is 'normal', the 'rbc_normal' column will be set to 1 and 'rbc_abnormal' will be set to 0.
#
#
# **Note: Find a correct pandas function to do this **

# %%
# Write code here
categorical_columns = ['rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'Target']

# Print the dataset

# %% [markdown]
# In the example we went through above, another solution is to have a single column for the binary variable. In the downstream modeling would this be equivalent? What effect would this have if the categorical variable could take more than 2 values? For example, let's say we have a categorical feature that is "type of condiment" that can take 5 separate values and we are trying to predict the rating of a particular sandwich.

# %% [markdown]
# ## Part 3.6 : Remove Outliers from Numerical Columns
#
# Outliers can disproportionately influence the fit of a regression model, potentially leading to a model that does not generalize well therefore it is important that we remove outliers from the numerical columns of the dataset.
#
# For this dataset, we define an outlier to be 3 times the standard deviation from the mean. Drop these outliers from the dataset

# %%
# Remove outliers
numerical_columns = ['age', 'bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']

# Print the dataset

# %% [markdown]
# ## Part 3.7 : Normalize the Numerical Columns
#
# Normalizing numerical attributes ensures that all features contribute equally to the model by scaling them to a consistent range, which improves model performance and convergence. It prevents features with larger scales from disproportionately influencing the model's learning process.

# %%
# Normalize the all Numerical Attributes in the dataset.
normalize = 

# Print the dataset

# %% [markdown]
# ## Part 3.8: Remove Unnecessary columns

# %% [markdown]
# Are there any columns in this dataset which are not appropriate for modeling and predictions? Which column(s)? Justify their exclusion and remove them

# %% [markdown]
# Answer: Columns that are not appropriate for modeling and predictions would be those that aren't retrieved from lab results or possibe medical records from the patients. We don't want those types of columns since modeling them could not give us an accurate statistical viewpoint. With this in mind the 'Target' column would not be appropritate. The column in not a feature. Instead it determines (makes a prediction) if the patient would have CKD or not. This is not a given piece of information and we do not want to include it in our model. These types of columns should be excluded. For our dataset specficially, I'm unsure which medical conditions are not relevant for CKD. If there were any that are no obtained from a concrete source, it would be best to exclude them from the model.

# %%
#Remove that column

# Print the dataset
# Out:
#      unique_id   age     bp    bgr     bu    sc    sod  pot  hemo   pcv  \
# 388     474407  21.0   90.0  107.0   40.0   1.7  125.0  3.5   8.3  23.0
# 94      137148  73.0  100.0  295.0   90.0   5.6  140.0  2.9   9.2  30.0
# 106     484175  53.0   90.0   70.0  107.0   7.2  114.0  3.7   9.5  29.0
# 320     343710  61.0   80.0  173.0  148.0   3.9  135.0  5.2   7.7  24.0
# 307     532520  60.0   90.0  105.0   53.0   2.3  136.0  5.2  11.1  33.0
# 306     566924  49.0  100.0  129.0  158.0  11.8  122.0  3.2   8.1  24.0
# 300     546225  46.0   60.0  163.0   92.0   3.3  141.0  4.0   9.8  28.0
# 134     602404  55.0   90.0  273.0  235.0  14.2  132.0  3.4   8.3  22.0
# 136     514721  56.0   90.0  129.0  107.0   6.7  131.0  4.8   9.1  29.0
# 295     899916  83.0   70.0  102.0   60.0   2.6  115.0  5.7   8.7  26.0
# 288     621332  59.0   80.0  303.0   35.0   1.3  122.0  3.5  10.4  35.0
# 150     428486  73.0   70.0   70.0   32.0   0.9  125.0  4.0  10.0  29.0
# 151     734698  59.0   50.0  241.0  191.0  12.0  114.0  2.9   9.6  31.0
# 152     481293  60.0   60.0  288.0   36.0   1.7  130.0  3.0   7.9  25.0
# 286     153227  60.0   90.0  490.0   95.0   2.7  131.0  3.8  11.5  35.0
#
#         wbcc  rbcc   al   su       rbc        pc         pcc          ba  htn  \
# 388  12400.0   3.9  4.0  0.0    normal  abnormal     present     present   no
# 94    7000.0   3.2  3.0  2.0  abnormal  abnormal     present  notpresent  yes
# 106  12100.0   3.7  2.0  0.0  abnormal  abnormal     present  notpresent  yes
# 320   9200.0   3.2  2.0  0.0  abnormal  abnormal  notpresent  notpresent  yes
# 307  10500.0   4.1  2.0  0.0  abnormal    normal  notpresent  notpresent   no
# 306   9600.0   3.5  3.0  0.0  abnormal  abnormal  notpresent  notpresent  yes
# 300  14600.0   3.2  1.0  0.0    normal    normal  notpresent  notpresent  yes
# 134  14600.0   2.9  2.0  1.0  abnormal  abnormal  notpresent  notpresent  yes
# 136   6400.0   3.4  2.0  0.0  abnormal  abnormal  notpresent  notpresent  yes
# 295  12800.0   3.1  3.0  0.0    normal    normal  notpresent  notpresent  yes
# 288  10900.0   4.3  1.0  0.0  abnormal    normal  notpresent  notpresent   no
# 150  18900.0   3.5  0.0  0.0    normal    normal  notpresent  notpresent  yes
# 151  15700.0   3.8  3.0  0.0    normal  abnormal  notpresent  notpresent   no
# 152  15200.0   3.0  3.0  1.0    normal  abnormal     present  notpresent  yes
# 286  12000.0   4.5  3.0  5.0  abnormal    normal  notpresent     present  yes
#
#       dm  cad appet   pe  ane
# 388   no   no  good   no  yes
# 94   yes  yes  poor   no   no
# 106  yes   no  poor   no  yes
# 320  yes  yes  poor  yes  yes
# 307   no   no  good   no   no
# 306  yes   no  poor  yes  yes
# 300  yes   no  good   no   no
# 134  yes   no  poor  yes  yes
# 136   no   no  good   no   no
# 295   no   no  poor   no  yes
# 288  yes   no  poor   no   no
# 150  yes   no  good  yes   no
# 151  yes   no  good  yes   no
# 152   no   no  poor   no  yes
# 286  yes   no  good   no   no

# %% [markdown]
# ## Part 3.9: Export the Cleaned Data

# %% [markdown]
# Now that you've completed these cleaning steps you should have a pandas dataframe which is much cleaner and ready for modeling. Our final step is to save our work. Export the DataFrame to a two new formats: csv and json.

# %%
# Export the dataframe to a new csv file

# Export the dataframe to a new json file

# %% [markdown]
# # Part 4: Data conversions with Large Language Models
#
# One powerful use case of ChatGPT (and other generative language models) is cleaning and transforming data. In some cases, these models can directly manipulate loosely structured data that you provide to them into a standard format. In the other cases, you can often prompt the model to create a conversion or extraction script for you in python or Pandas and then run it on your own.
#
# In this part of the assignment you will prompt 383GPT to explore these capabilities.

# %% [markdown]
# ## Part 4.1 GPT Data Manipulation
#
# Take the cleaned dataset that you created in part three and output the top 15 rows of that dataset. Then copy the terminal output, open 383gpt and ask it to convert that output to a markdown table. Paste that markdown table in the cell bellow

# %% [markdown]
# ### Paste the markdown table here

# %%
| unique_id | age   |   bp |   bgr |    bu |   sc |   sod |   pot | hemo |   pcv |   wbcc |   rbcc |   al |   su |         rbc |           pc |         pcc |    ba | htn | dm | cad | appet | pe  | ane  |
|-----------|-------|-------|-------|-------|------|-------|-------|------|-------|--------|--------|------|------|--------------|---------------|--------------|-------|-----|----|-----|-------|-----|------|
|     388   |  47.4 |  90.0 | 107.0 |  40.0 |  1.7 | 125.0 |   3.5 |  8.3 |  23.0 | 12400.0 |  3.9   |  4.0  |  0.0 | normal      | abnormal      | present      | present | no  | no | no  | good  | no  | yes  |
|      94   | 137.1 | 100.0 | 295.0 |  90.0 |  5.6 | 140.0 |   2.9 |  9.2 |  30.0 |  7000.0 |  3.2   |  3.0  |  2.0 | abnormal    | abnormal      | present      | notpresent | yes  | yes | yes | poor  | no  | no   |
|     106   |  48.4 |  90.0 |  70.0 | 107.0 |  7.2 | 114.0 |   3.7 |  9.5 |  29.0 | 12100.0 |  3.7   |  2.0  |  0.0 | abnormal    | abnormal      | present      | notpresent | yes  | yes | no  | poor  | no  | yes  |
|     320   |  34.3 |  80.0 | 173.0 | 148.0 |  3.9 | 135.0 |   5.2 |  7.7 |  24.0 |  9200.0 |  3.2   |  2.0  |  0.0 | abnormal    | abnormal      | notpresent   | notpresent | yes  | yes | yes | poor  | yes | yes  |
|     307   |  53.2 |  90.0 | 105.0 |  53.0 |  2.3 | 136.0 |   5.2 | 11.1 |  33.0 | 10500.0 |  4.1   |  2.0  |  0.0 | abnormal    | normal        | notpresent   | notpresent | no   | no  | no  | good  | no  | no   |
|     306   |  56.6 | 100.0 | 129.0 | 158.0 | 11.8 | 122.0 |   3.2 |  8.1 |  24.0 | 9600.0  |  3.5   |  3.0  |  0.0 | abnormal    | abnormal      | notpresent   | notpresent | yes  | yes | no  | poor  | yes | yes  |
|     300   |  54.6 |  60.0 | 163.0 |  92.0 |  3.3 | 141.0 |   4.0 |  9.8 |  28.0 | 14600.0 |  3.2   |  1.0  |  0.0 | normal      | normal        | notpresent   | notpresent | yes  | yes | no  | good  | no  | no   |
|     134   |  60.2 |  90.0 | 273.0 | 235.0 | 14.2 | 132.0 |   3.4 |  8.3 |  22.0 | 14600.0 |  2.9   |  2.0  |  1.0 | abnormal    | abnormal      | notpresent   | notpresent | yes  | yes | no  | poor  | yes | yes  |
|     136   |  51.4 |  90.0 | 129.0 | 107.0 |  6.7 | 131.0 |   4.8 |  9.1 |  29.0 |  6400.0 |  3.4   |  2.0  |  0.0 | abnormal    | abnormal      | notpresent   | notpresent | yes  | no  | no  | good  | no  | no   |
|     295   |  89.9 |  70.0 | 102.0 |  60.0 |  2.6 | 115.0 |   5.7 |  8.7 |  26.0 | 12800.0 |  3.1   |  3.0  |  0.0 | normal      | normal        | notpresent   | notpresent | yes  | no  | no  | poor  | no  | yes  |
|     288   |  62.1 |  80.0 | 303.0 |  35.0 |  1.3 | 122.0 |   3.5 | 10.4 |  35.0 | 10900.0 |  4.3   |  1.0  |  0.0 | abnormal    | normal        | notpresent   | notpresent | no   | yes | no  | poor  | no  | no   |
|     150   |  42.8 |  70.0 |  70.0 |  32.0 |  0.9 | 125.0 |   4.0 | 10.0 |  29.0 | 18900.0 |  3.5   |  0.0  |  0.0 | normal      | normal        | notpresent   | notpresent | yes  | yes | no  | good  | yes | no   |
|     151   |  73.4 |  50.0 | 241.0 | 191.0 | 12.0 | 114.0 |   2.9 |  9.6 |  31.0 | 15700.0 |  3.8   |  3.0  |  0.0 | normal      | abnormal      | notpresent   | notpresent | no   | yes | no  | good  | yes | no   |
|     152   |  48.1 |  60.0 | 288.0 |  36.0 |  1.7 | 130.0 |   3.0 |  7.9 |  25.0 | 15200.0 |  3.0   |  3.0  |  1.0 | normal      | abnormal      | present      | notpresent | yes  | no  | no  | poor  | no  | yes  |
|     286   |  15.3 |  90.0 | 490.0 |  95.0 |  2.7 | 131.0 |   3.8 | 11.5 |  35.0 | 12000.0 |  4.5   |  3.0  |  5.0 | abnormal    | normal        | notpresent   | present     | yes  | yes | no  | good  | no  | no   |

# %% [markdown]
# | unique_id | age   |   bp |   bgr |    bu |   sc |   sod |   pot | hemo |   pcv |   wbcc |   rbcc |   al |   su |         rbc |           pc |         pcc |    ba | htn | dm | cad | appet | pe  | ane  |
# |-----------|-------|-------|-------|-------|------|-------|-------|------|-------|--------|--------|------|------|--------------|---------------|--------------|-------|-----|----|-----|-------|-----|------|
# |     388   |  47.4 |  90.0 | 107.0 |  40.0 |  1.7 | 125.0 |   3.5 |  8.3 |  23.0 | 12400.0 |  3.9   |  4.0  |  0.0 | normal      | abnormal      | present      | present | no  | no | no  | good  | no  | yes  |
# |      94   | 137.1 | 100.0 | 295.0 |  90.0 |  5.6 | 140.0 |   2.9 |  9.2 |  30.0 |  7000.0 |  3.2   |  3.0  |  2.0 | abnormal    | abnormal      | present      | notpresent | yes  | yes | yes | poor  | no  | no   |
# |     106   |  48.4 |  90.0 |  70.0 | 107.0 |  7.2 | 114.0 |   3.7 |  9.5 |  29.0 | 12100.0 |  3.7   |  2.0  |  0.0 | abnormal    | abnormal      | present      | notpresent | yes  | yes | no  | poor  | no  | yes  |
# |     320   |  34.3 |  80.0 | 173.0 | 148.0 |  3.9 | 135.0 |   5.2 |  7.7 |  24.0 |  9200.0 |  3.2   |  2.0  |  0.0 | abnormal    | abnormal      | notpresent   | notpresent | yes  | yes | yes | poor  | yes | yes  |
# |     307   |  53.2 |  90.0 | 105.0 |  53.0 |  2.3 | 136.0 |   5.2 | 11.1 |  33.0 | 10500.0 |  4.1   |  2.0  |  0.0 | abnormal    | normal        | notpresent   | notpresent | no   | no  | no  | good  | no  | no   |
# |     306   |  56.6 | 100.0 | 129.0 | 158.0 | 11.8 | 122.0 |   3.2 |  8.1 |  24.0 | 9600.0  |  3.5   |  3.0  |  0.0 | abnormal    | abnormal      | notpresent   | notpresent | yes  | yes | no  | poor  | yes | yes  |
# |     300   |  54.6 |  60.0 | 163.0 |  92.0 |  3.3 | 141.0 |   4.0 |  9.8 |  28.0 | 14600.0 |  3.2   |  1.0  |  0.0 | normal      | normal        | notpresent   | notpresent | yes  | yes | no  | good  | no  | no   |
# |     134   |  60.2 |  90.0 | 273.0 | 235.0 | 14.2 | 132.0 |   3.4 |  8.3 |  22.0 | 14600.0 |  2.9   |  2.0  |  1.0 | abnormal    | abnormal      | notpresent   | notpresent | yes  | yes | no  | poor  | yes | yes  |
# |     136   |  51.4 |  90.0 | 129.0 | 107.0 |  6.7 | 131.0 |   4.8 |  9.1 |  29.0 |  6400.0 |  3.4   |  2.0  |  0.0 | abnormal    | abnormal      | notpresent   | notpresent | yes  | no  | no  | good  | no  | no   |
# |     295   |  89.9 |  70.0 | 102.0 |  60.0 |  2.6 | 115.0 |   5.7 |  8.7 |  26.0 | 12800.0 |  3.1   |  3.0  |  0.0 | normal      | normal        | notpresent   | notpresent | yes  | no  | no  | poor  | no  | yes  |
# |     288   |  62.1 |  80.0 | 303.0 |  35.0 |  1.3 | 122.0 |   3.5 | 10.4 |  35.0 | 10900.0 |  4.3   |  1.0  |  0.0 | abnormal    | normal        | notpresent   | notpresent | no   | yes | no  | poor  | no  | no   |
# |     150   |  42.8 |  70.0 |  70.0 |  32.0 |  0.9 | 125.0 |   4.0 | 10.0 |  29.0 | 18900.0 |  3.5   |  0.0  |  0.0 | normal      | normal        | notpresent   | notpresent | yes  | yes | no  | good  | yes | no   |
# |     151   |  73.4 |  50.0 | 241.0 | 191.0 | 12.0 | 114.0 |   2.9 |  9.6 |  31.0 | 15700.0 |  3.8   |  3.0  |  0.0 | normal      | abnormal      | notpresent   | notpresent | no   | yes | no  | good  | yes | no   |
# |     152   |  48.1 |  60.0 | 288.0 |  36.0 |  1.7 | 130.0 |   3.0 |  7.9 |  25.0 | 15200.0 |  3.0   |  3.0  |  1.0 | normal      | abnormal      | present      | notpresent | yes  | no  | no  | poor  | no  | yes  |
# |     286   |  15.3 |  90.0 | 490.0 |  95.0 |  2.7 | 131.0 |   3.8 | 11.5 |  35.0 | 12000.0 |  4.5   |  3.0  |  5.0 | abnormal    | normal        | notpresent   | present     | yes  | yes | no  | good  | no  | no   |

# %% [markdown]
# ** Caution: ** while language models can perform data conversions they also can * hallucinate * during this process, particularly for bigger datasets. Reflect on this below, how could you mitigate data conversion hallucinations from LLM conversions?

# %% [markdown]
# ## Part 4.2 GPT Pandas Prompting
#
# In this section, you will prompt 383GPT to write pandas code manipulations for you.
#
# After working with this data for awhile, we realized we're starting to forget the meanings of the abbreviated column names. Let's ask 383GPT to fix this for us. First, navigate to the [UCI dataset overview](https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease) and copy the abbrevation to name mapping. Then, go to 383GPT and instruct the LLM to provide you with a pandas script to apply this renaming to all the columns of your dataset. Paste that code below and make any adjustments necessary to run it in your notebook.

# %%
# Column mapping from abbreviations to full names
column_mapping = {
    'age': 'Age',
    'bp': 'Blood Pressure',
    'sg': 'Specific Gravity',
    'al': 'Albumin',
    'su': 'Sugar',
    'rbc': 'Red Blood Cells',
    'pc': 'Pus Cell',
    'pcc': 'Pus Cell Clumps',
    'ba': 'Bacteria',
    'bgr': 'Blood Glucose Random',
    'bu': 'Blood Urea',
    'sc': 'Serum Creatinine',
    'sod': 'Sodium',
    'pot': 'Potassium',
    'hemo': 'Hemoglobin',
    'pcv': 'Packed Cell Volume',
    'wc': 'White Blood Cell Count',
    'rc': 'Red Blood Cell Count',
    'htn': 'Hypertension',
    'dm': 'Diabetes Mellitus',
    'cad': 'Coronary Artery Disease',
    'appet': 'Appetite',
    'pe': 'Pedal Edema',
    'ane': 'Anemia',
}

# Rename the columns
removed.rename(columns=column_mapping, inplace=True)

# Display the renamed DataFrame
removed
# Out:
#      unique_id   Age  Blood Pressure  Blood Glucose Random  Blood Urea  \
# 388     474407  21.0            90.0                 107.0        40.0
# 94      137148  73.0           100.0                 295.0        90.0
# 106     484175  53.0            90.0                  70.0       107.0
# 320     343710  61.0            80.0                 173.0       148.0
# 307     532520  60.0            90.0                 105.0        53.0
# ..         ...   ...             ...                   ...         ...
# 131     647552  61.0            70.0                 120.0        29.0
# 128     125587  37.0            60.0                 109.0        47.0
# 124     614376  57.0            80.0                 119.0        17.0
# 173     853426  41.0            70.0                 125.0        38.0
# 208     572140  55.0            80.0                 104.0        28.0
#
#      Serum Creatinine  Sodium  Potassium  Hemoglobin  Packed Cell Volume  \
# 388               1.7   125.0        3.5         8.3                23.0
# 94                5.6   140.0        2.9         9.2                30.0
# 106               7.2   114.0        3.7         9.5                29.0
# 320               3.9   135.0        5.2         7.7                24.0
# 307               2.3   136.0        5.2        11.1                33.0
# ..                ...     ...        ...         ...                 ...
# 131               0.7   137.0        3.5        17.4                52.0
# 128               1.1   141.0        4.9        15.0                48.0
# 124               1.2   135.0        4.7        15.4                42.0
# 173               0.6   140.0        5.0        16.8                41.0
# 208               0.9   142.0        4.8        17.3                52.0
#
#         wbcc  rbcc  Albumin  Sugar Red Blood Cells  Pus Cell Pus Cell Clumps  \
# 388  12400.0   3.9      4.0    0.0          normal  abnormal         present
# 94    7000.0   3.2      3.0    2.0        abnormal  abnormal         present
# 106  12100.0   3.7      2.0    0.0        abnormal  abnormal         present
# 320   9200.0   3.2      2.0    0.0        abnormal  abnormal      notpresent
# 307  10500.0   4.1      2.0    0.0        abnormal    normal      notpresent
# ..       ...   ...      ...    ...             ...       ...             ...
# 131   7000.0   5.3      0.0    0.0          normal    normal      notpresent
# 128   7000.0   5.2      0.0    0.0          normal    normal      notpresent
# 124   6200.0   6.2      0.0    0.0          normal    normal      notpresent
# 173   6300.0   5.9      0.0    0.0          normal    normal      notpresent
# 208   8200.0   4.8      0.0    0.0          normal    normal      notpresent
#
#        Bacteria Hypertension Diabetes Mellitus Coronary Artery Disease  \
# 388     present           no                no                      no
# 94   notpresent          yes               yes                     yes
# 106  notpresent          yes               yes                      no
# 320  notpresent          yes               yes                     yes
# 307  notpresent           no                no                      no
# ..          ...          ...               ...                     ...
# 131  notpresent           no                no                      no
# 128  notpresent           no                no                      no
# 124  notpresent           no                no                      no
# 173  notpresent           no                no                      no
# 208  notpresent           no                no                      no
#
#     Appetite Pedal Edema Anemia
# 388     good          no    yes
# 94      poor          no     no
# 106     poor          no    yes
# 320     poor         yes    yes
# 307     good          no     no
# ..       ...         ...    ...
# 131     good          no     no
# 128     good          no     no
# 124     good          no     no
# 173     good          no     no
# 208     good          no     no
#
# [153 rows x 24 columns]

# %% [markdown]
# ## Part 4.3 Augmenting our skills with prompting
#
# In addition, we can also use 383GPT to convert our data manipulation operations between different data manipulation languages and libraries. For example let's prompt 383GPT to convert the following SQL query to a pandas query.
#
# **SQL Query**
# ```sql
# SELECT Target, COUNT(*) AS count
# FROM your_table_name
# GROUP BY Target;
# ```
#
# Prompt 383GPT to convert this to a pandas query. Run this query below, then describe what it does. (If you're not familiar with SQL that is okay you need to only comment on the final resulting output.)

# %%
# Converted SQL to Pandas code
import pandas as pd

# Sample data in a DataFrame
data = {
    'Target': ['A', 'B', 'A', 'C', 'B', 'A', 'C', 'B'],  # Example target values
}

df = pd.DataFrame(data)

# Pandas equivalent of the SQL query
result = df.groupby('Target').size().reset_index(name='count')

# Display the result
print(result)
# Out:
#   Target  count
# 0      A      3
# 1      B      3
# 2      C      2

# %% [markdown]
# *Describe what the above code does here*
# First we create a DataFrame from the given data. We then organize our data by frequency. The groupby() function gives us a matrix. The first column is the indices which number off the rows. The second column contains the different Targets from out data. The third column stores the frequncy of the Target in the data. Each row represents a different Target.

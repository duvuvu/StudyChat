# %%
# Imports and pip installations (if needed)
import pandas as pd
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
import re

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Part 1: Load the dataset

# %%
# Load the given datasets
ckdNum = pd.read_csv("chronic_kidney_disease_numerical.csv")
ckdCat = pd.read_csv("chronic_kidney_disease_categorical.csv")

# Print the data
print("Categorical Data:")
print(ckdCat.head(5))

print("\nNumerical Data:")
print(ckdNum)
# Out:
# Categorical Data:
#    unique_id   al   su       rbc        pc         pcc          ba  htn   dm  \
# 0     224481  3.0  NaN       NaN       NaN  notpresent  notpresent  yes  yes
# 1     992643  0.0  0.0       NaN       NaN  notpresent  notpresent   no   no
# 2     308740  1.0  0.0  abnormal  abnormal  notpresent  notpresent  yes   no
# 3     450314  1.0  0.0       NaN    normal  notpresent  notpresent   no   no
# 4     881763  0.0  0.0    normal    normal  notpresent  notpresent   no   no
#
#   cad appet   pe  ane  Target
# 0  no  good  yes   no     ckd
# 1  no  good   no   no  notckd
# 2  no  good  yes   no     ckd
# 3  no  good   no  yes     ckd
# 4  no  good   no   no  notckd
#
# Numerical Data:
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       203694  38.0   80.0   99.0   19.0  0.5  147.0  3.5  13.6  44.0
# 1       938027  43.0   60.0  108.0   25.0  1.0  144.0  5.0  17.8  43.0
# 2       421471  37.0   60.0  111.0   35.0  0.8  135.0  4.1  16.2  50.0
# 3       764115  70.0   90.0  144.0  125.0  4.0  136.0  4.6  12.0  37.0
# 4       240975  47.0   80.0   95.0   35.0  0.9  140.0  4.1   NaN   NaN
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 415     522912  56.0   80.0  165.0   55.0  1.8    NaN  NaN  13.5  40.0
# 416     475200  64.0  100.0  163.0   54.0  7.2  140.0  4.6   7.9  26.0
# 417     168242  48.0   60.0  112.0   44.0  1.2  142.0  4.9  14.5  44.0
# 418     474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 419     926033  50.0   70.0  230.0   50.0  2.2    NaN  NaN  12.0  41.0
#
#         wbcc  rbcc
# 0     7300.0   6.4
# 1     7200.0   5.5
# 2     5500.0   5.7
# 3     8200.0   4.5
# 4        NaN   NaN
# ..       ...   ...
# 415  11800.0   5.0
# 416   7500.0   3.4
# 417   9400.0   6.4
# 418  12400.0   3.9
# 419  10400.0   4.6
#
# [420 rows x 12 columns]

# %% [markdown]
# # Part 2: Analyze the Dataset

# %% [markdown]
# Refer to this: https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease
#
# Explain what the each data is in your own words. What are the features and labels? Are the features in the given datasets : categorical, numerical or both? Give 3 examples of categorical and numerical columns each (if they exist)

# %% [markdown]
# Answer: The data is a series of measurements and characteristics taken from patients that do or do not have chronic kidney disease. The features are these measurements and the labels are whether each patient has or does not have chronic kidney disease. The features are both categorical and numerical. Three examples of categorical columns are pedal edema, appetite, and cornonary artery disease. Three examples of numerical columnns are age, blood pressure, and blood glucose random.

# %% [markdown]
# # Part 3: Data Preprocessing
#
# A fundamental skill in Machine Learning is mastering the art of data cleaning and preprocessing. In this assignment, you will learn and apply essential data cleaning techniques to transform a raw dataset into a clean, ready-to-use form which you can use for regression or classification tasks. By the end of this assignment, you'll have a fully clean dataset and a solid foundation in preparing data for various machine learning models.

# %% [markdown]
# ## Part 3.1 : Drop Duplicate rows
#
# Let's start by checking if the given datasets have any duplicate rows (same Unique Id). Use pandas to identify and remove these duplicate rows from the given dataset

# %%
# For the numerical dataset, check if there are duplicate rows in the dataset. If yes, print total number of duplicate rows
numDuplicates = ckdNum['unique_id'].duplicated().sum()
print("Number of numerical duplicates:")
print(numDuplicates)
# Drop these duplicate rows

ckdNum = ckdNum.drop_duplicates(subset='unique_id')
# Repeat the same for categorical dataset. Print the duplicate rows and drop them

catDuplicates = ckdCat['unique_id'].duplicated().sum()
print("Number of categorical duplicates:")
print(catDuplicates)

ckdCat = ckdCat.drop_duplicates(subset='unique_id')
# Out:
# Number of numerical duplicates:
# 30
# Number of categorical duplicates:
# 30

# %% [markdown]
# ## Part 3.2: Combine two differents datasets
#
# A good skill to have is to know how to combine 2 different datasets.
#
# Are all the unique ids are present in both datasets? Why do you think so? If not, what do the rows that are missing from one of the datasets look like in the combined table?

# %% [markdown]
# Answer:

# %%
# Merge the two given numerical and categorical datasets based on their unique_ID.
ckdComb = pd.merge(ckdNum, ckdCat, on='unique_id')
#Print the combined dataset
print(ckdComb)
# Out:
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       203694  38.0   80.0   99.0   19.0  0.5  147.0  3.5  13.6  44.0
# 1       938027  43.0   60.0  108.0   25.0  1.0  144.0  5.0  17.8  43.0
# 2       421471  37.0   60.0  111.0   35.0  0.8  135.0  4.1  16.2  50.0
# 3       764115  70.0   90.0  144.0  125.0  4.0  136.0  4.6  12.0  37.0
# 4       240975  47.0   80.0   95.0   35.0  0.9  140.0  4.1   NaN   NaN
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 385     522912  56.0   80.0  165.0   55.0  1.8    NaN  NaN  13.5  40.0
# 386     475200  64.0  100.0  163.0   54.0  7.2  140.0  4.6   7.9  26.0
# 387     168242  48.0   60.0  112.0   44.0  1.2  142.0  4.9  14.5  44.0
# 388     474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 389     926033  50.0   70.0  230.0   50.0  2.2    NaN  NaN  12.0  41.0
#
#         wbcc  rbcc   al   su       rbc        pc         pcc          ba  htn  \
# 0     7300.0   6.4  0.0  0.0    normal    normal  notpresent  notpresent   no
# 1     7200.0   5.5  0.0  0.0    normal    normal  notpresent  notpresent   no
# 2     5500.0   5.7  0.0  0.0    normal    normal  notpresent  notpresent   no
# 3     8200.0   4.5  0.0  0.0       NaN    normal  notpresent  notpresent  yes
# 4        NaN   NaN  0.0  0.0    normal    normal  notpresent  notpresent   no
# ..       ...   ...  ...  ...       ...       ...         ...         ...  ...
# 385  11800.0   5.0  1.0  0.0       NaN    normal  notpresent  notpresent  yes
# 386   7500.0   3.4  4.0  2.0  abnormal  abnormal  notpresent     present  yes
# 387   9400.0   6.4  0.0  0.0    normal    normal  notpresent  notpresent   no
# 388  12400.0   3.9  4.0  0.0    normal  abnormal     present     present   no
# 389  10400.0   4.6  0.0  0.0       NaN    normal  notpresent  notpresent  yes
#
#       dm cad appet   pe  ane  Target
# 0     no  no  good   no   no  notckd
# 1     no  no  good   no   no  notckd
# 2     no  no  good   no   no  notckd
# 3    yes  no  poor  yes   no     ckd
# 4     no  no  good   no   no  notckd
# ..   ...  ..   ...  ...  ...     ...
# 385  yes  no  poor  yes   no     ckd
# 386  yes  no  good  yes   no     ckd
# 387   no  no  good   no   no  notckd
# 388   no  no  good   no  yes     ckd
# 389  yes  no  good   no   no     ckd
#
# [390 rows x 25 columns]

# %% [markdown]
# ## Part 3.3: Rows with Missing values
#
# Removing missing values from a dataset is important for classification because it ensures the model is trained on complete and accurate data, leading to better performance and reliable predictions. Incomplete data can introduce bias and errors, negatively impacting the model's effectiveness.

# %%
# Calculate the percentage of rows that contain atleast one missing value
missingRows = ckdComb.isnull().any(axis=1).sum() / len(ckdComb) * 100
# Print %
print(missingRows)
# Drop these rows from the dataset
ckdCombCleaned = ckdComb.dropna()
# Print the Dataset
print(ckdCombCleaned)
# Out:
# 60.76923076923077
#      unique_id   age     bp    bgr    bu   sc    sod  pot  hemo   pcv  \
# 0       203694  38.0   80.0   99.0  19.0  0.5  147.0  3.5  13.6  44.0
# 1       938027  43.0   60.0  108.0  25.0  1.0  144.0  5.0  17.8  43.0
# 2       421471  37.0   60.0  111.0  35.0  0.8  135.0  4.1  16.2  50.0
# 7       109053  64.0   60.0  106.0  27.0  0.7  150.0  3.3  14.4  42.0
# 13      349892  59.0   70.0  424.0  55.0  1.7  138.0  4.5  12.6  37.0
# ..         ...   ...    ...    ...   ...  ...    ...  ...   ...   ...
# 379     486397  20.0   70.0  123.0  44.0  1.0  135.0  3.8  14.6  44.0
# 381     462892  36.0   80.0   85.0  16.0  1.1  142.0  4.1  15.6  44.0
# 386     475200  64.0  100.0  163.0  54.0  7.2  140.0  4.6   7.9  26.0
# 387     168242  48.0   60.0  112.0  44.0  1.2  142.0  4.9  14.5  44.0
# 388     474407  21.0   90.0  107.0  40.0  1.7  125.0  3.5   8.3  23.0
#
#         wbcc  rbcc   al   su       rbc        pc         pcc          ba  htn  \
# 0     7300.0   6.4  0.0  0.0    normal    normal  notpresent  notpresent   no
# 1     7200.0   5.5  0.0  0.0    normal    normal  notpresent  notpresent   no
# 2     5500.0   5.7  0.0  0.0    normal    normal  notpresent  notpresent   no
# 7     8100.0   4.7  0.0  0.0    normal    normal  notpresent  notpresent   no
# 13   10200.0   4.1  1.0  3.0  abnormal  abnormal  notpresent  notpresent  yes
# ..       ...   ...  ...  ...       ...       ...         ...         ...  ...
# 379   5500.0   4.8  0.0  0.0    normal    normal  notpresent  notpresent   no
# 381   5800.0   6.3  0.0  0.0    normal    normal  notpresent  notpresent   no
# 386   7500.0   3.4  4.0  2.0  abnormal  abnormal  notpresent     present  yes
# 387   9400.0   6.4  0.0  0.0    normal    normal  notpresent  notpresent   no
# 388  12400.0   3.9  4.0  0.0    normal  abnormal     present     present   no
#
#       dm  cad appet   pe  ane  Target
# 0     no   no  good   no   no  notckd
# 1     no   no  good   no   no  notckd
# 2     no   no  good   no   no  notckd
# 7     no   no  good   no   no  notckd
# 13   yes  yes  good   no   no     ckd
# ..   ...  ...   ...  ...  ...     ...
# 379   no   no  good   no   no  notckd
# 381   no   no  good   no   no  notckd
# 386  yes   no  good  yes   no     ckd
# 387   no   no  good   no   no  notckd
# 388   no   no  good   no  yes     ckd
#
# [153 rows x 25 columns]

# %% [markdown]
# ## Part 3.4: Sort the dataset according to the Labels

# %%
# Sort the dataset according to the values in 'Target' column. Make sure reset the indices after sorting
ckdSorted = ckdCombCleaned.sort_values(by='Target')
ckdSorted.reset_index(drop=True, inplace=True)
# Print the dataset
print(ckdSorted)
# Out:
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 1       137148  73.0  100.0  295.0   90.0  5.6  140.0  2.9   9.2  30.0
# 2       484175  53.0   90.0   70.0  107.0  7.2  114.0  3.7   9.5  29.0
# 3       343710  61.0   80.0  173.0  148.0  3.9  135.0  5.2   7.7  24.0
# 4       532520  60.0   90.0  105.0   53.0  2.3  136.0  5.2  11.1  33.0
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 148     647552  61.0   70.0  120.0   29.0  0.7  137.0  3.5  17.4  52.0
# 149     125587  37.0   60.0  109.0   47.0  1.1  141.0  4.9  15.0  48.0
# 150     614376  57.0   80.0  119.0   17.0  1.2  135.0  4.7  15.4  42.0
# 151     853426  41.0   70.0  125.0   38.0  0.6  140.0  5.0  16.8  41.0
# 152     572140  55.0   80.0  104.0   28.0  0.9  142.0  4.8  17.3  52.0
#
#         wbcc  rbcc   al   su       rbc        pc         pcc          ba  htn  \
# 0    12400.0   3.9  4.0  0.0    normal  abnormal     present     present   no
# 1     7000.0   3.2  3.0  2.0  abnormal  abnormal     present  notpresent  yes
# 2    12100.0   3.7  2.0  0.0  abnormal  abnormal     present  notpresent  yes
# 3     9200.0   3.2  2.0  0.0  abnormal  abnormal  notpresent  notpresent  yes
# 4    10500.0   4.1  2.0  0.0  abnormal    normal  notpresent  notpresent   no
# ..       ...   ...  ...  ...       ...       ...         ...         ...  ...
# 148   7000.0   5.3  0.0  0.0    normal    normal  notpresent  notpresent   no
# 149   7000.0   5.2  0.0  0.0    normal    normal  notpresent  notpresent   no
# 150   6200.0   6.2  0.0  0.0    normal    normal  notpresent  notpresent   no
# 151   6300.0   5.9  0.0  0.0    normal    normal  notpresent  notpresent   no
# 152   8200.0   4.8  0.0  0.0    normal    normal  notpresent  notpresent   no
#
#       dm  cad appet   pe  ane  Target
# 0     no   no  good   no  yes     ckd
# 1    yes  yes  poor   no   no     ckd
# 2    yes   no  poor   no  yes     ckd
# 3    yes  yes  poor  yes  yes     ckd
# 4     no   no  good   no   no     ckd
# ..   ...  ...   ...  ...  ...     ...
# 148   no   no  good   no   no  notckd
# 149   no   no  good   no   no  notckd
# 150   no   no  good   no   no  notckd
# 151   no   no  good   no   no  notckd
# 152   no   no  good   no   no  notckd
#
# [153 rows x 25 columns]

# %% [markdown]
# ## Part 3.5: Encoding Categorical data
#
# In this step, we identify and process the categorical columns in the sorted dataset. We map each unique value in these columns to separate "dummy" columns.
#
# For example, the column 'rbc' will be transformed into two columns 'rbc_normal' and 'rbc_abnormal'. If a row's value in 'rbc' is 'normal', the 'rbc_normal' column will be set to 1 and 'rbc_abnormal' will be set to 0.
#
#
# **Note: Find a correct pandas function to do this **

# %%
# Write code here
categorical_columns = ['rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'Target']
ckdEncoded = pd.get_dummies(data=ckdSorted, columns=categorical_columns)
# Print the dataset
print(ckdEncoded)
# Out:
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 1       137148  73.0  100.0  295.0   90.0  5.6  140.0  2.9   9.2  30.0
# 2       484175  53.0   90.0   70.0  107.0  7.2  114.0  3.7   9.5  29.0
# 3       343710  61.0   80.0  173.0  148.0  3.9  135.0  5.2   7.7  24.0
# 4       532520  60.0   90.0  105.0   53.0  2.3  136.0  5.2  11.1  33.0
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 148     647552  61.0   70.0  120.0   29.0  0.7  137.0  3.5  17.4  52.0
# 149     125587  37.0   60.0  109.0   47.0  1.1  141.0  4.9  15.0  48.0
# 150     614376  57.0   80.0  119.0   17.0  1.2  135.0  4.7  15.4  42.0
# 151     853426  41.0   70.0  125.0   38.0  0.6  140.0  5.0  16.8  41.0
# 152     572140  55.0   80.0  104.0   28.0  0.9  142.0  4.8  17.3  52.0
#
#         wbcc  rbcc   al   su  rbc_abnormal  rbc_normal  pc_abnormal  \
# 0    12400.0   3.9  4.0  0.0         False        True         True
# 1     7000.0   3.2  3.0  2.0          True       False         True
# 2    12100.0   3.7  2.0  0.0          True       False         True
# 3     9200.0   3.2  2.0  0.0          True       False         True
# 4    10500.0   4.1  2.0  0.0          True       False        False
# ..       ...   ...  ...  ...           ...         ...          ...
# 148   7000.0   5.3  0.0  0.0         False        True        False
# 149   7000.0   5.2  0.0  0.0         False        True        False
# 150   6200.0   6.2  0.0  0.0         False        True        False
# 151   6300.0   5.9  0.0  0.0         False        True        False
# 152   8200.0   4.8  0.0  0.0         False        True        False
#
#      pc_normal  pcc_notpresent  pcc_present  ba_notpresent  ba_present  \
# 0        False           False         True          False        True
# 1        False           False         True           True       False
# 2        False           False         True           True       False
# 3        False            True        False           True       False
# 4         True            True        False           True       False
# ..         ...             ...          ...            ...         ...
# 148       True            True        False           True       False
# 149       True            True        False           True       False
# 150       True            True        False           True       False
# 151       True            True        False           True       False
# 152       True            True        False           True       False
#
#      htn_no  htn_yes  dm_no  dm_yes  cad_no  cad_yes  appet_good  appet_poor  \
# 0      True    False   True   False    True    False        True       False
# 1     False     True  False    True   False     True       False        True
# 2     False     True  False    True    True    False       False        True
# 3     False     True  False    True   False     True       False        True
# 4      True    False   True   False    True    False        True       False
# ..      ...      ...    ...     ...     ...      ...         ...         ...
# 148    True    False   True   False    True    False        True       False
# 149    True    False   True   False    True    False        True       False
# 150    True    False   True   False    True    False        True       False
# 151    True    False   True   False    True    False        True       False
# 152    True    False   True   False    True    False        True       False
#
#      pe_no  pe_yes  ane_no  ane_yes  Target_ckd  Target_notckd
# 0     True   False   False     True        True          False
# 1     True   False    True    False        True          False
# 2     True   False   False     True        True          False
# 3    False    True   False     True        True          False
# 4     True   False    True    False        True          False
# ..     ...     ...     ...      ...         ...            ...
# 148   True   False    True    False       False           True
# 149   True   False    True    False       False           True
# 150   True   False    True    False       False           True
# 151   True   False    True    False       False           True
# 152   True   False    True    False       False           True
#
# [153 rows x 36 columns]

# %% [markdown]
# In the example we went through above, another solution is to have a single column for the binary variable. In the downstream modeling would this be equivalent? What effect would this have if the categorical variable could take more than 2 values? For example, let's say we have a categorical feature that is "type of condiment" that can take 5 separate values and we are trying to predict the rating of a particular sandwich.

# %% [markdown]
# ## Part 3.6 : Remove Outliers from Numerical Columns
#
# Outliers can disproportionately influence the fit of a regression model, potentially leading to a model that does not generalize well therefore it is important that we remove outliers from the numerical columns of the dataset.
#
# For this dataset, we define an outlier to be 3 times the standard deviation from the mean. Drop these outliers from the dataset

# %%
# Remove outliers
numerical_columns = ['age', 'bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']
ckdNoOutliers = ckdEncoded
for col in numerical_columns:
    zScores = stats.zscore(ckdEncoded[col])
    ckdNoOutliers = ckdNoOutliers[(zScores < 3) & (zScores > -3)]
# Print the dataset
print(ckdNoOutliers)
# Out:
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 1       137148  73.0  100.0  295.0   90.0  5.6  140.0  2.9   9.2  30.0
# 3       343710  61.0   80.0  173.0  148.0  3.9  135.0  5.2   7.7  24.0
# 4       532520  60.0   90.0  105.0   53.0  2.3  136.0  5.2  11.1  33.0
# 6       546225  46.0   60.0  163.0   92.0  3.3  141.0  4.0   9.8  28.0
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 148     647552  61.0   70.0  120.0   29.0  0.7  137.0  3.5  17.4  52.0
# 149     125587  37.0   60.0  109.0   47.0  1.1  141.0  4.9  15.0  48.0
# 150     614376  57.0   80.0  119.0   17.0  1.2  135.0  4.7  15.4  42.0
# 151     853426  41.0   70.0  125.0   38.0  0.6  140.0  5.0  16.8  41.0
# 152     572140  55.0   80.0  104.0   28.0  0.9  142.0  4.8  17.3  52.0
#
#         wbcc  rbcc   al   su  rbc_abnormal  rbc_normal  pc_abnormal  \
# 0    12400.0   3.9  4.0  0.0         False        True         True
# 1     7000.0   3.2  3.0  2.0          True       False         True
# 3     9200.0   3.2  2.0  0.0          True       False         True
# 4    10500.0   4.1  2.0  0.0          True       False        False
# 6    14600.0   3.2  1.0  0.0         False        True        False
# ..       ...   ...  ...  ...           ...         ...          ...
# 148   7000.0   5.3  0.0  0.0         False        True        False
# 149   7000.0   5.2  0.0  0.0         False        True        False
# 150   6200.0   6.2  0.0  0.0         False        True        False
# 151   6300.0   5.9  0.0  0.0         False        True        False
# 152   8200.0   4.8  0.0  0.0         False        True        False
#
#      pc_normal  pcc_notpresent  pcc_present  ba_notpresent  ba_present  \
# 0        False           False         True          False        True
# 1        False           False         True           True       False
# 3        False            True        False           True       False
# 4         True            True        False           True       False
# 6         True            True        False           True       False
# ..         ...             ...          ...            ...         ...
# 148       True            True        False           True       False
# 149       True            True        False           True       False
# 150       True            True        False           True       False
# 151       True            True        False           True       False
# 152       True            True        False           True       False
#
#      htn_no  htn_yes  dm_no  dm_yes  cad_no  cad_yes  appet_good  appet_poor  \
# 0      True    False   True   False    True    False        True       False
# 1     False     True  False    True   False     True       False        True
# 3     False     True  False    True   False     True       False        True
# 4      True    False   True   False    True    False        True       False
# 6     False     True  False    True    True    False        True       False
# ..      ...      ...    ...     ...     ...      ...         ...         ...
# 148    True    False   True   False    True    False        True       False
# 149    True    False   True   False    True    False        True       False
# 150    True    False   True   False    True    False        True       False
# 151    True    False   True   False    True    False        True       False
# 152    True    False   True   False    True    False        True       False
#
#      pe_no  pe_yes  ane_no  ane_yes  Target_ckd  Target_notckd
# 0     True   False   False     True        True          False
# 1     True   False    True    False        True          False
# 3    False    True   False     True        True          False
# 4     True   False    True    False        True          False
# 6     True   False    True    False        True          False
# ..     ...     ...     ...      ...         ...            ...
# 148   True   False    True    False       False           True
# 149   True   False    True    False       False           True
# 150   True   False    True    False       False           True
# 151   True   False    True    False       False           True
# 152   True   False    True    False       False           True
#
# [134 rows x 36 columns]
# /tmp/ipykernel_1703/1387644844.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ckdNoOutliers = ckdNoOutliers[(zScores < 3) & (zScores > -3)]
# /tmp/ipykernel_1703/1387644844.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ckdNoOutliers = ckdNoOutliers[(zScores < 3) & (zScores > -3)]
# /tmp/ipykernel_1703/1387644844.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ckdNoOutliers = ckdNoOutliers[(zScores < 3) & (zScores > -3)]
# /tmp/ipykernel_1703/1387644844.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ckdNoOutliers = ckdNoOutliers[(zScores < 3) & (zScores > -3)]
# /tmp/ipykernel_1703/1387644844.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ckdNoOutliers = ckdNoOutliers[(zScores < 3) & (zScores > -3)]
# /tmp/ipykernel_1703/1387644844.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ckdNoOutliers = ckdNoOutliers[(zScores < 3) & (zScores > -3)]
# /tmp/ipykernel_1703/1387644844.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ckdNoOutliers = ckdNoOutliers[(zScores < 3) & (zScores > -3)]
# /tmp/ipykernel_1703/1387644844.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ckdNoOutliers = ckdNoOutliers[(zScores < 3) & (zScores > -3)]
# /tmp/ipykernel_1703/1387644844.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ckdNoOutliers = ckdNoOutliers[(zScores < 3) & (zScores > -3)]

# %% [markdown]
# ## Part 3.7 : Normalize the Numerical Columns
#
# Normalizing numerical attributes ensures that all features contribute equally to the model by scaling them to a consistent range, which improves model performance and convergence. It prevents features with larger scales from disproportionately influencing the model's learning process.

# %%
# Normalize the all Numerical Attributes in the dataset.
scaler = MinMaxScaler()

ckdNoOutliers[numerical_columns] = scaler.fit_transform(ckdNoOutliers[numerical_columns])
# Print the dataset
print(ckdNoOutliers)
# Out:
#      unique_id       age    bp       bgr        bu        sc       sod  \
# 0       474407  0.202703  0.75  0.158798  0.196078  0.160494  0.166667
# 1       137148  0.905405  1.00  0.965665  0.522876  0.641975  0.666667
# 3       343710  0.743243  0.50  0.442060  0.901961  0.432099  0.500000
# 4       532520  0.729730  0.75  0.150215  0.281046  0.234568  0.533333
# 6       546225  0.540541  0.00  0.399142  0.535948  0.358025  0.700000
# ..         ...       ...   ...       ...       ...       ...       ...
# 148     647552  0.743243  0.25  0.214592  0.124183  0.037037  0.566667
# 149     125587  0.418919  0.00  0.167382  0.241830  0.086420  0.700000
# 150     614376  0.689189  0.50  0.210300  0.045752  0.098765  0.500000
# 151     853426  0.472973  0.25  0.236052  0.183007  0.024691  0.666667
# 152     572140  0.662162  0.50  0.145923  0.117647  0.061728  0.733333
#
#           pot      hemo       pcv      wbcc      rbcc   al   su  rbc_abnormal  \
# 0    0.171429  0.221311  0.184211  0.653226  0.333333  4.0  0.0         False
# 1    0.000000  0.295082  0.368421  0.217742  0.153846  3.0  2.0          True
# 3    0.657143  0.172131  0.210526  0.395161  0.153846  2.0  0.0          True
# 4    0.657143  0.450820  0.447368  0.500000  0.384615  2.0  0.0          True
# 6    0.314286  0.344262  0.315789  0.830645  0.153846  1.0  0.0         False
# ..        ...       ...       ...       ...       ...  ...  ...           ...
# 148  0.171429  0.967213  0.947368  0.217742  0.692308  0.0  0.0         False
# 149  0.571429  0.770492  0.842105  0.217742  0.666667  0.0  0.0         False
# 150  0.514286  0.803279  0.684211  0.153226  0.923077  0.0  0.0         False
# 151  0.600000  0.918033  0.657895  0.161290  0.846154  0.0  0.0         False
# 152  0.542857  0.959016  0.947368  0.314516  0.564103  0.0  0.0         False
#
#      rbc_normal  pc_abnormal  pc_normal  pcc_notpresent  pcc_present  \
# 0          True         True      False           False         True
# 1         False         True      False           False         True
# 3         False         True      False            True        False
# 4         False        False       True            True        False
# 6          True        False       True            True        False
# ..          ...          ...        ...             ...          ...
# 148        True        False       True            True        False
# 149        True        False       True            True        False
# 150        True        False       True            True        False
# 151        True        False       True            True        False
# 152        True        False       True            True        False
#
#      ba_notpresent  ba_present  htn_no  htn_yes  dm_no  dm_yes  cad_no  \
# 0            False        True    True    False   True   False    True
# 1             True       False   False     True  False    True   False
# 3             True       False   False     True  False    True   False
# 4             True       False    True    False   True   False    True
# 6             True       False   False     True  False    True    True
# ..             ...         ...     ...      ...    ...     ...     ...
# 148           True       False    True    False   True   False    True
# 149           True       False    True    False   True   False    True
# 150           True       False    True    False   True   False    True
# 151           True       False    True    False   True   False    True
# 152           True       False    True    False   True   False    True
#
#      cad_yes  appet_good  appet_poor  pe_no  pe_yes  ane_no  ane_yes  \
# 0      False        True       False   True   False   False     True
# 1       True       False        True   True   False    True    False
# 3       True       False        True  False    True   False     True
# 4      False        True       False   True   False    True    False
# 6      False        True       False   True   False    True    False
# ..       ...         ...         ...    ...     ...     ...      ...
# 148    False        True       False   True   False    True    False
# 149    False        True       False   True   False    True    False
# 150    False        True       False   True   False    True    False
# 151    False        True       False   True   False    True    False
# 152    False        True       False   True   False    True    False
#
#      Target_ckd  Target_notckd
# 0          True          False
# 1          True          False
# 3          True          False
# 4          True          False
# 6          True          False
# ..          ...            ...
# 148       False           True
# 149       False           True
# 150       False           True
# 151       False           True
# 152       False           True
#
# [134 rows x 36 columns]

# %% [markdown]
# ## Part 3.8: Remove Unnecessary columns

# %% [markdown]
# Are there any columns in this dataset which are not appropriate for modeling and predictions? Which column(s)? Justify their exclusion and remove them

# %% [markdown]
# Answer: The appetite column should not be included because it's a subjective measure and can vary greatly between individuals.

# %%
#Remove that column
ckdNoAppet = ckdNoOutliers.drop(columns=['appet_good', 'appet_poor'])
# Print the dataset
print(ckdNoAppet.head(15))
# Out:
#     unique_id       age    bp       bgr        bu        sc       sod  \
# 0      474407  0.202703  0.75  0.158798  0.196078  0.160494  0.166667
# 1      137148  0.905405  1.00  0.965665  0.522876  0.641975  0.666667
# 3      343710  0.743243  0.50  0.442060  0.901961  0.432099  0.500000
# 4      532520  0.729730  0.75  0.150215  0.281046  0.234568  0.533333
# 6      546225  0.540541  0.00  0.399142  0.535948  0.358025  0.700000
# 8      514721  0.675676  0.75  0.253219  0.633987  0.777778  0.366667
# 10     621332  0.716216  0.50  1.000000  0.163399  0.111111  0.066667
# 13     481293  0.729730  0.00  0.935622  0.169935  0.160494  0.333333
# 15     297893  0.837838  0.50  0.373391  0.522876  0.456790  0.333333
# 17     615697  0.000000  0.00  0.103004  0.372549  0.074074  0.500000
# 19     843362  0.878378  0.00  0.206009  0.751634  0.604938  0.533333
# 20     995177  0.851351  0.25  0.618026  0.562092  0.728395  0.000000
# 21     828592  0.878378  0.25  0.639485  0.470588  0.395062  0.433333
# 22     923613  0.783784  0.00  0.725322  0.313725  0.481481  0.566667
# 24     955830  0.662162  0.50  0.618026  0.411765  0.432099  0.566667
#
#          pot      hemo       pcv      wbcc      rbcc   al   su  rbc_abnormal  \
# 0   0.171429  0.221311  0.184211  0.653226  0.333333  4.0  0.0         False
# 1   0.000000  0.295082  0.368421  0.217742  0.153846  3.0  2.0          True
# 3   0.657143  0.172131  0.210526  0.395161  0.153846  2.0  0.0          True
# 4   0.657143  0.450820  0.447368  0.500000  0.384615  2.0  0.0          True
# 6   0.314286  0.344262  0.315789  0.830645  0.153846  1.0  0.0         False
# 8   0.542857  0.286885  0.342105  0.169355  0.205128  2.0  0.0          True
# 10  0.171429  0.393443  0.500000  0.532258  0.435897  1.0  0.0          True
# 13  0.028571  0.188525  0.236842  0.879032  0.102564  3.0  1.0         False
# 15  1.000000  0.000000  0.000000  0.540323  0.000000  3.0  2.0         False
# 17  0.571429  0.352459  0.368421  1.000000  0.564103  4.0  0.0          True
# 19  0.571429  0.475410  0.500000  0.879032  0.435897  4.0  0.0         False
# 20  0.285714  0.311475  0.315789  0.580645  0.179487  4.0  3.0         False
# 21  0.428571  0.393443  0.447368  0.104839  0.256410  3.0  0.0         False
# 22  0.714286  0.319672  0.342105  0.258065  0.205128  4.0  1.0          True
# 24  0.571429  0.434426  0.473684  0.250000  0.282051  3.0  1.0         False
#
#     rbc_normal  pc_abnormal  pc_normal  pcc_notpresent  pcc_present  \
# 0         True         True      False           False         True
# 1        False         True      False           False         True
# 3        False         True      False            True        False
# 4        False        False       True            True        False
# 6         True        False       True            True        False
# 8        False         True      False            True        False
# 10       False        False       True            True        False
# 13        True         True      False           False         True
# 15        True         True      False           False         True
# 17       False         True      False            True        False
# 19        True        False       True            True        False
# 20        True         True      False           False         True
# 21        True         True      False           False         True
# 22       False         True      False            True        False
# 24        True         True      False           False         True
#
#     ba_notpresent  ba_present  htn_no  htn_yes  dm_no  dm_yes  cad_no  \
# 0           False        True    True    False   True   False    True
# 1            True       False   False     True  False    True   False
# 3            True       False   False     True  False    True   False
# 4            True       False    True    False   True   False    True
# 6            True       False   False     True  False    True    True
# 8            True       False   False     True   True   False    True
# 10           True       False    True    False  False    True    True
# 13           True       False   False     True   True   False    True
# 15          False        True   False     True  False    True   False
# 17          False        True    True    False   True   False    True
# 19           True       False   False     True  False    True    True
# 20          False        True   False     True  False    True   False
# 21          False        True   False     True  False    True   False
# 22          False        True   False     True  False    True    True
# 24          False        True   False     True  False    True    True
#
#     cad_yes  pe_no  pe_yes  ane_no  ane_yes  Target_ckd  Target_notckd
# 0     False   True   False   False     True        True          False
# 1      True   True   False    True    False        True          False
# 3      True  False    True   False     True        True          False
# 4     False   True   False    True    False        True          False
# 6     False   True   False    True    False        True          False
# 8     False   True   False    True    False        True          False
# 10    False   True   False    True    False        True          False
# 13    False   True   False   False     True        True          False
# 15     True  False    True    True    False        True          False
# 17    False   True   False    True    False        True          False
# 19    False  False    True    True    False        True          False
# 20     True  False    True   False     True        True          False
# 21     True   True   False    True    False        True          False
# 22    False  False    True    True    False        True          False
# 24    False  False    True    True    False        True          False

# %% [markdown]
# ## Part 3.9: Export the Cleaned Data

# %% [markdown]
# Now that you've completed these cleaning steps you should have a pandas dataframe which is much cleaner and ready for modeling. Our final step is to save our work. Export the DataFrame to a two new formats: csv and json.

# %%
ckdNoAppet.reset_index(drop=True, inplace=True)
# Export the dataframe to a new csv file
ckdNoAppet.to_csv('data.csv', index=False)
# Export the dataframe to a new json file
ckdNoAppet.to_json('data.json', orient='records')

# %% [markdown]
# # Part 4: Data conversions with Large Language Models
#
# One powerful use case of ChatGPT (and other generative language models) is cleaning and transforming data. In some cases, these models can directly manipulate loosely structured data that you provide to them into a standard format. In the other cases, you can often prompt the model to create a conversion or extraction script for you in python or Pandas and then run it on your own.
#
# In this part of the assignment you will prompt 383GPT to explore these capabilities.

# %% [markdown]
# ## Part 4.1 GPT Data Manipulation
#
# Take the cleaned dataset that you created in part three and output the top 15 rows of that dataset. Then copy the terminal output, open 383gpt and ask it to convert that output to a markdown table. Paste that markdown table in the cell bellow

# %% [markdown]
# ### Paste the markdown table here
# | unique_id |      age |   bp |       bgr |        bu |        sc |       sod |       pot |      hemo |      pcv |      wbcc |      rbcc |   al |   su | rbc_abnormal | rbc_normal | pc_abnormal | pc_normal | pcc_notpresent | pcc_present | ba_notpresent | ba_present | htn_no | htn_yes | dm_no | dm_yes | cad_no | cad_yes | pe_no | pe_yes | ane_no | ane_yes | Target_ckd | Target_notckd |
# |-----------|----------|------|-----------|-----------|-----------|-----------|-----------|-----------|-----------|-----------|-----------|------|------|---------------|------------|-------------|-----------|----------------|-------------|---------------|-----------|--------|---------|-------|--------|--------|---------|-------|--------|--------|---------|-------------|----------------|
# |     474407 | 0.202703 | 0.75 | 0.158798  | 0.196078  | 0.160494  | 0.166667  | 0.171429  | 0.221311  | 0.184211  | 0.653226  | 0.333333  | 4.0  | 0.0  |        False  |       True |        True  |      False |        False   |        True  |       False    |        True |    True |   False |  True |  False |   True |   False | True  | False  | False  |    True  |       True   |       False      |
# |     137148 | 0.905405 | 1.00 | 0.965665  | 0.522876  | 0.641975  | 0.666667  | 0.000000  | 0.295082  | 0.368421  | 0.217742  | 0.153846  | 3.0  | 2.0  |         True  |      False |        True  |      False |        False   |        True  |        True    |        True |   False |    True | False |   True |  False |    True  |   True | True   |  False  |    True  |       True   |       False      |
# |     343710 | 0.743243 | 0.50 | 0.442060  | 0.901961  | 0.432099  | 0.500000  | 0.657143  | 0.172131  | 0.210526  | 0.395161  | 0.153846  | 2.0  | 0.0  |         True  |      False |        True  |      False |         True    |       False  |        True    |        True |   False |   False | False |   True |  False |    True  |  False | True   |  False  |    True  |       True   |       False      |
# |     532520 | 0.729730 | 0.75 | 0.150215  | 0.281046  | 0.234568  | 0.533333  | 0.657143  | 0.450820  | 0.447368  | 0.500000  | 0.384615  | 2.0  | 0.0  |         True  |      False |       False  |       True |         True    |       False  |        True    |        True |   True  |   False | False |   True |  False |    True  |  False | True   |  False  |    True  |       True   |       False      |
# |     546225 | 0.540541 | 0.00 | 0.399142  | 0.535948  | 0.358025  | 0.700000  | 0.314286  | 0.344262  | 0.315789  | 0.830645  | 0.153846  | 1.0  | 0.0  |        False  |       True |       False  |       True |         True    |       False  |        True    |        True |   False |   False | False |   True |  False |    True  |  False | True   |  False  |    True  |       True   |       False      |
# |     514721 | 0.675676 | 0.75 | 0.253219  | 0.633987  | 0.777778  | 0.366667  | 0.542857  | 0.286885  | 0.342105  | 0.169355  | 0.205128  | 2.0  | 0.0  |         True  |      False |        True  |      False |         True    |       False  |        True    |        True |   False |   False | False |   True |  True |    False |  False | True   |  False  |    True  |       True   |       False      |
# |     621332 | 0.716216 | 0.50 | 1.000000  | 0.163399  | 0.111111  | 0.066667  | 0.171429  | 0.393443  | 0.500000  | 0.532258  | 0.435897  | 1.0  | 0.0  |         True  |      False |       False  |       True |         True    |       False  |        True    |        True |    True |    False | True  |   False |  False |    True  |  False | True   |  False  |    True  |       True   |       False      |
# |     481293 | 0.729730 | 0.00 | 0.935622  | 0.169935  | 0.160494  | 0.333333  | 0.028571  | 0.188525  | 0.236842  | 0.879032  | 0.102564  | 3.0  | 1.0  |        False  |       True |        True  |      False |        False    |        True  |       False    |        True |   True  |    True  | False |   True |  False |    False |  True  | False  |  True   |    False |       True   |       False      |
# |     297893 | 0.837838 | 0.50 | 0.373391  | 0.522876  | 0.456790  | 0.333333  | 1.000000  | 0.000000  | 0.000000  | 0.540323  | 0.000000  | 3.0  | 2.0  |        False  |       True |        True  |      False |         True    |       False  |        True    |        True |   True  |   False | False |   True |  False |    False |  True  | False  |  False  |    True  |       True   |       False      |
# |     615697 | 0.000000 | 0.00 | 0.103004  | 0.372549  | 0.074074  | 0.500000  | 0.571429  | 0.352459  | 0.368421  | 1.000000  | 0.564103  | 4.0  | 0.0  |         True  |      False |        True  |      False |         True    |       False  |        True    |        True |   True  |    False | True  |   False |  False |    True  |  False | True   |  False  |    True  |       True   |       False      |
# |     843362 | 0.878378 | 0.00 | 0.206009  | 0.751634  | 0.604938  | 0.533333  | 0.571429  | 0.475410  | 0.500000  | 0.879032  | 0.435897  | 4.0  | 0.0  |         False |      True  |        False  |      True |         True    |       False  |        True    |        True |   True  |   False | False |   True |  False |    True  |  False | True   |  True   |    False  |       True   |       False      |
# |     995177 | 0.851351 | 0.25 | 0.618026  | 0.562092  | 0.728395  | 0.000000  | 0.285714  | 0.311475  | 0.315789  | 0.580645  | 0.179487  | 4.0  | 3.0  |        False  |       True |        True  |      False |        False    |       True   |        False   |        True |   True  |    True  | False |   True |   True |   False   |  False | False  |  False   |    True   |       True   |       False      |
# |     828592 | 0.878378 | 0.25 | 0.639485  | 0.470588  | 0.395062  | 0.433333  | 0.428571  | 0.393443  | 0.447368  | 0.104839  | 0.256410  | 3.0  | 0.0  |         False |       True |        True  |      False |        False    |       True   |        False   |        True |   True  |   True   | False |   True |   True |    False  |   True  | True   |  False  |    True  |       True   |       False      |
# |     923613 | 0.783784 | 0.00 | 0.725322  | 0.313725  | 0.481481  | 0.566667  | 0.714286  | 0.319672  | 0.342105  | 0.258065  | 0.205128  | 4.0  | 1.0  |         True  |      False |        True  |      False |         True    |       False  |        True    |        True |   True  |   True   | False |   True |  False |    False  |  True  | False  |  True   |    True    |       True   |       False      |
# |     955830 | 0.662162 | 0.50 | 0.618026  | 0.411765  | 0.432099  | 0.566667  | 0.571429  | 0.434426  | 0.473684  | 0.250000  | 0.282051  | 3.0  | 1.0  |        False  |       True |        True  |      False |         False   |       True   |        False   |        True |   True  |   True   | False |   True |  False |    False  |  True  | True   |  True   |   True     |      True    |       True      |

# %% [markdown]
# ** Caution: ** while language models can perform data conversions they also can * hallucinate * during this process, particularly for bigger datasets. Reflect on this below, how could you mitigate data conversion hallucinations from LLM conversions?

# %% [markdown]
# ## Part 4.2 GPT Pandas Prompting
#
# In this section, you will prompt 383GPT to write pandas code manipulations for you.
#
# After working with this data for awhile, we realized we're starting to forget the meanings of the abbreviated column names. Let's ask 383GPT to fix this for us. First, navigate to the [UCI dataset overview](https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease) and copy the abbrevation to name mapping. Then, go to 383GPT and instruct the LLM to provide you with a pandas script to apply this renaming to all the columns of your dataset. Paste that code below and make any adjustments necessary to run it in your notebook.

# %%
# Code to rename all the columns in the dataset
# Dictionary to map abbreviations to full names
column_mappings = {
    'age': 'age',
    'bp': 'blood pressure',
    'sg': 'specific gravity',
    'al': 'albumin',
    'su': 'sugar',
    'rbc': 'red blood cells',
    'pc': 'pus cell',
    'pcc': 'pus cell clumps',
    'ba': 'bacteria',
    'bgr': 'blood glucose random',
    'bu': 'blood urea',
    'sc': 'serum creatinine',
    'sod': 'sodium',
    'pot': 'potassium',
    'hemo': 'hemoglobin',
    'pcv': 'packed cell volume',
    'wc': 'white blood cell count',
    'rc': 'red blood cell count',
    'htn': 'hypertension',
    'dm': 'diabetes mellitus',
    'cad': 'coronary artery disease',
    'appet': 'appetite',
    'pe': 'pedal edema',
    'ane': 'anemia',
    'class': 'class'
}

# Function to rename columns using the mapping
def rename_columns(col_name):
    # Match the abbreviation using regex
    for abbr, full_name in column_mappings.items():
        # Create a regex pattern that matches the abbreviation followed by any suffix
        pattern = r'\b' + re.escape(abbr) + r'(_\w+)?$'
        if re.search(pattern, col_name):
            # If found, replace it with the corresponding full name, keeping the suffix
            suffix = re.search(pattern, col_name).group(1) if re.search(pattern, col_name).group(1) else ""
            return full_name + (suffix if suffix else "")
    return col_name  # If no match, return the original name

# Apply the function to rename columns
ckdNoAppet.rename(columns=rename_columns, inplace=True)
print(ckdNoAppet)
# Out:
#      unique_id       age  blood pressure  blood glucose random  blood urea  \
# 0       474407  0.202703            0.75              0.158798    0.196078
# 1       137148  0.905405            1.00              0.965665    0.522876
# 2       343710  0.743243            0.50              0.442060    0.901961
# 3       532520  0.729730            0.75              0.150215    0.281046
# 4       546225  0.540541            0.00              0.399142    0.535948
# ..         ...       ...             ...                   ...         ...
# 129     647552  0.743243            0.25              0.214592    0.124183
# 130     125587  0.418919            0.00              0.167382    0.241830
# 131     614376  0.689189            0.50              0.210300    0.045752
# 132     853426  0.472973            0.25              0.236052    0.183007
# 133     572140  0.662162            0.50              0.145923    0.117647
#
#      serum creatinine    sodium  potassium  hemoglobin  packed cell volume  \
# 0            0.160494  0.166667   0.171429    0.221311            0.184211
# 1            0.641975  0.666667   0.000000    0.295082            0.368421
# 2            0.432099  0.500000   0.657143    0.172131            0.210526
# 3            0.234568  0.533333   0.657143    0.450820            0.447368
# 4            0.358025  0.700000   0.314286    0.344262            0.315789
# ..                ...       ...        ...         ...                 ...
# 129          0.037037  0.566667   0.171429    0.967213            0.947368
# 130          0.086420  0.700000   0.571429    0.770492            0.842105
# 131          0.098765  0.500000   0.514286    0.803279            0.684211
# 132          0.024691  0.666667   0.600000    0.918033            0.657895
# 133          0.061728  0.733333   0.542857    0.959016            0.947368
#
#          wbcc      rbcc  albumin  sugar  red blood cells_abnormal  \
# 0    0.653226  0.333333      4.0    0.0                     False
# 1    0.217742  0.153846      3.0    2.0                      True
# 2    0.395161  0.153846      2.0    0.0                      True
# 3    0.500000  0.384615      2.0    0.0                      True
# 4    0.830645  0.153846      1.0    0.0                     False
# ..        ...       ...      ...    ...                       ...
# 129  0.217742  0.692308      0.0    0.0                     False
# 130  0.217742  0.666667      0.0    0.0                     False
# 131  0.153226  0.923077      0.0    0.0                     False
# 132  0.161290  0.846154      0.0    0.0                     False
# 133  0.314516  0.564103      0.0    0.0                     False
#
#      red blood cells_normal  pus cell_abnormal  pus cell_normal  \
# 0                      True               True            False
# 1                     False               True            False
# 2                     False               True            False
# 3                     False              False             True
# 4                      True              False             True
# ..                      ...                ...              ...
# 129                    True              False             True
# 130                    True              False             True
# 131                    True              False             True
# 132                    True              False             True
# 133                    True              False             True
#
#      pus cell clumps_notpresent  pus cell clumps_present  bacteria_notpresent  \
# 0                         False                     True                False
# 1                         False                     True                 True
# 2                          True                    False                 True
# 3                          True                    False                 True
# 4                          True                    False                 True
# ..                          ...                      ...                  ...
# 129                        True                    False                 True
# 130                        True                    False                 True
# 131                        True                    False                 True
# 132                        True                    False                 True
# 133                        True                    False                 True
#
#      bacteria_present  hypertension_no  hypertension_yes  \
# 0                True             True             False
# 1               False            False              True
# 2               False            False              True
# 3               False             True             False
# 4               False            False              True
# ..                ...              ...               ...
# 129             False             True             False
# 130             False             True             False
# 131             False             True             False
# 132             False             True             False
# 133             False             True             False
#
#      diabetes mellitus_no  diabetes mellitus_yes  coronary artery disease_no  \
# 0                    True                  False                        True
# 1                   False                   True                       False
# 2                   False                   True                       False
# 3                    True                  False                        True
# 4                   False                   True                        True
# ..                    ...                    ...                         ...
# 129                  True                  False                        True
# 130                  True                  False                        True
# 131                  True                  False                        True
# 132                  True                  False                        True
# 133                  True                  False                        True
#
#      coronary artery disease_yes  pedal edema_no  pedal edema_yes  anemia_no  \
# 0                          False            True            False      False
# 1                           True            True            False       True
# 2                           True           False             True      False
# 3                          False            True            False       True
# 4                          False            True            False       True
# ..                           ...             ...              ...        ...
# 129                        False            True            False       True
# 130                        False            True            False       True
# 131                        False            True            False       True
# 132                        False            True            False       True
# 133                        False            True            False       True
#
#      anemia_yes  Target_ckd  Target_notckd
# 0          True        True          False
# 1         False        True          False
# 2          True        True          False
# 3         False        True          False
# 4         False        True          False
# ..          ...         ...            ...
# 129       False       False           True
# 130       False       False           True
# 131       False       False           True
# 132       False       False           True
# 133       False       False           True
#
# [134 rows x 34 columns]

# %% [markdown]
# ## Part 4.3 Augmenting our skills with prompting
#
# In addition, we can also use 383GPT to convert our data manipulation operations between different data manipulation languages and libraries. For example let's prompt 383GPT to convert the following SQL query to a pandas query.
#
# **SQL Query**
# ```sql
# SELECT Target, COUNT(*) AS count
# FROM your_table_name
# GROUP BY Target;
# ```
#
# Prompt 383GPT to convert this to a pandas query. Run this query below, then describe what it does. (If you're not familiar with SQL that is okay you need to only comment on the final resulting output.)

# %%
# Converted SQL to Pandas code
your_table_name.groupby('Target').size().reset_index(name='count')

# %% [markdown]
# *Describe what the above code does here*
# The code above groups the data by the value stored in the Target column. It then gets how many are in each group and returns a data frame with columns Target and count to show how many of each Target value there are.

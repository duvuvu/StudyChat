# %%
# Imports and pip installations (if needed)
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Part 1: Load the dataset

# %%
# Load the given datasets
categorical = pd.read_csv("chronic_kidney_disease_categorical.csv")
numerical = pd.read_csv("chronic_kidney_disease_numerical.csv")

# Print the data
print(categorical)
print(numerical)
# Out:
#      unique_id   al   su       rbc        pc         pcc          ba  htn  \
# 0       224481  3.0  NaN       NaN       NaN  notpresent  notpresent  yes
# 1       992643  0.0  0.0       NaN       NaN  notpresent  notpresent   no
# 2       308740  1.0  0.0  abnormal  abnormal  notpresent  notpresent  yes
# 3       450314  1.0  0.0       NaN    normal  notpresent  notpresent   no
# 4       881763  0.0  0.0    normal    normal  notpresent  notpresent   no
# ..         ...  ...  ...       ...       ...         ...         ...  ...
# 425     769512  0.0  0.0    normal    normal  notpresent  notpresent   no
# 426     872034  2.0  1.0  abnormal  abnormal  notpresent     present  yes
# 427     643007  NaN  NaN       NaN    normal  notpresent  notpresent  yes
# 428     840392  NaN  NaN       NaN       NaN  notpresent  notpresent  yes
# 429     856244  0.0  0.0       NaN    normal  notpresent  notpresent  yes
#
#       dm  cad appet   pe  ane  Target
# 0    yes   no  good  yes   no     ckd
# 1     no   no  good   no   no  notckd
# 2     no   no  good  yes   no     ckd
# 3     no   no  good   no  yes     ckd
# 4     no   no  good   no   no  notckd
# ..   ...  ...   ...  ...  ...     ...
# 425   no   no  good   no   no  notckd
# 426  yes  yes  poor   no   no     ckd
# 427  yes  yes  poor   no   no     ckd
# 428   no   no  poor   no   no     ckd
# 429  yes   no  poor   no   no     ckd
#
# [430 rows x 14 columns]
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       203694  38.0   80.0   99.0   19.0  0.5  147.0  3.5  13.6  44.0
# 1       938027  43.0   60.0  108.0   25.0  1.0  144.0  5.0  17.8  43.0
# 2       421471  37.0   60.0  111.0   35.0  0.8  135.0  4.1  16.2  50.0
# 3       764115  70.0   90.0  144.0  125.0  4.0  136.0  4.6  12.0  37.0
# 4       240975  47.0   80.0   95.0   35.0  0.9  140.0  4.1   NaN   NaN
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 415     522912  56.0   80.0  165.0   55.0  1.8    NaN  NaN  13.5  40.0
# 416     475200  64.0  100.0  163.0   54.0  7.2  140.0  4.6   7.9  26.0
# 417     168242  48.0   60.0  112.0   44.0  1.2  142.0  4.9  14.5  44.0
# 418     474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 419     926033  50.0   70.0  230.0   50.0  2.2    NaN  NaN  12.0  41.0
#
#         wbcc  rbcc
# 0     7300.0   6.4
# 1     7200.0   5.5
# 2     5500.0   5.7
# 3     8200.0   4.5
# 4        NaN   NaN
# ..       ...   ...
# 415  11800.0   5.0
# 416   7500.0   3.4
# 417   9400.0   6.4
# 418  12400.0   3.9
# 419  10400.0   4.6
#
# [420 rows x 12 columns]

# %% [markdown]
# # Part 2: Analyze the Dataset

# %% [markdown]
# Refer to this: https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease
#
# Explain what the each data is in your own words. What are the features and labels? Are the features in the given datasets : categorical, numerical or both? Give 3 examples of categorical and numerical columns each (if they exist)

# %% [markdown]
# Answer: Each data is a set of a variety of health factors, including the patient's kidney health. The features are the attributes used to describe each patient's health, and the labels are whether or not the patient has Chronic Kidney Disease or not. There are both categorical and numerical features in the dataset. Some categorical features include the patient's specific gravity (sg), albumin (al), and sugar (su). Some numerical features include the patient's age (age), blood pressure (bp), and blood glucose random (bgr).

# %% [markdown]
# # Part 3: Data Preprocessing
#
# A fundamental skill in Machine Learning is mastering the art of data cleaning and preprocessing. In this assignment, you will learn and apply essential data cleaning techniques to transform a raw dataset into a clean, ready-to-use form which you can use for regression or classification tasks. By the end of this assignment, you'll have a fully clean dataset and a solid foundation in preparing data for various machine learning models.

# %% [markdown]
# ## Part 3.1 : Drop Duplicate rows
#
# Let's start by checking if the given datasets have any duplicate rows (same Unique Id). Use pandas to identify and remove these duplicate rows from the given dataset

# %%
# For the numerical dataset, check if there are duplicate rows in the dataset. If yes, print total number of duplicate rows
numerical_duplicates = numerical.duplicated(subset=["unique_id"])
print(f"# Duplicate rows in numerical dataset: {numerical_duplicates.sum()}")

# Drop these duplicate rows
numerical_cleaned = numerical.drop_duplicates(subset=["unique_id"])

# Repeat the same for categorical dataset. Print the duplicate rows and drop them
categorical_duplicates = categorical.duplicated(subset=["unique_id"])
print(f"# Duplicate rows in categorical dataset: {categorical_duplicates.sum()}")
categorical_cleaned = categorical.drop_duplicates(subset=["unique_id"])
# Out:
# # Duplicate rows in numerical dataset: 30
# # Duplicate rows in categorical dataset: 30

# %% [markdown]
# ## Part 3.2: Combine two differents datasets
#
# A good skill to have is to know how to combine 2 different datasets.
#
# Are all the unique ids are present in both datasets? Why do you think so? If not, what do the rows that are missing from one of the datasets look like in the combined table?

# %% [markdown]
# Answer: Not all of the unique ids are present in both datasets. Some of the medical records could have been incomplete during the documentation of the patient's health. The rows that are missing from one of the datasets will look like a set of some data and NaN values in the combined table.

# %%
# Merge the two given numerical and categorical datasets based on their unique_ID.
combined_data = pd.merge(numerical_cleaned, categorical_cleaned, on="unique_id", how='outer')

#Print the combined dataset
print(combined_data)
# Out:
#      unique_id   age    bp    bgr     bu    sc    sod  pot  hemo   pcv  ...  \
# 0       102677  59.0  70.0   76.0  186.0  15.0  135.0  7.6   7.1  22.0  ...
# 1       103570  24.0  80.0  125.0    NaN   NaN  136.0  3.5  15.4  43.0  ...
# 2       104675  65.0  80.0  215.0  133.0   2.5    NaN  NaN  13.2  41.0  ...
# 3       105923  90.0  90.0  139.0   89.0   3.0  140.0  4.1  12.0  37.0  ...
# 4       107297  60.0  70.0    NaN    NaN   NaN    NaN  NaN  16.4  43.0  ...
# ..         ...   ...   ...    ...    ...   ...    ...  ...   ...   ...  ...
# 395     995177  69.0  70.0  214.0   96.0   6.3  120.0  3.9   9.4  28.0  ...
# 396     996076  57.0  60.0  105.0   49.0   1.2  150.0  4.7  15.7  44.0  ...
# 397     996412  70.0  60.0  120.0   40.0   0.5  140.0  4.6  16.0  43.0  ...
# 398     997629  35.0   NaN   99.0   30.0   0.5  135.0  4.9  15.4  48.0  ...
# 399     997876  64.0  70.0  107.0   15.0   NaN    NaN  NaN  12.8  38.0  ...
#
#            pc         pcc          ba  htn   dm  cad appet   pe  ane  Target
# 0    abnormal  notpresent  notpresent  yes   no   no  poor  yes  yes     ckd
# 1      normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 2      normal     present  notpresent   no  yes   no  good   no   no     ckd
# 3      normal  notpresent  notpresent  yes  yes   no  good   no   no     ckd
# 4      normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# ..        ...         ...         ...  ...  ...  ...   ...  ...  ...     ...
# 395  abnormal     present     present  yes  yes  yes  good  yes  yes     ckd
# 396    normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 397       NaN  notpresent  notpresent   no   no   no  good   no   no  notckd
# 398    normal         NaN         NaN   no   no   no  good   no   no  notckd
# 399    normal  notpresent  notpresent   no   no   no  good   no   no     ckd
#
# [400 rows x 25 columns]

# %% [markdown]
# ## Part 3.3: Rows with Missing values
#
# Removing missing values from a dataset is important for classification because it ensures the model is trained on complete and accurate data, leading to better performance and reliable predictions. Incomplete data can introduce bias and errors, negatively impacting the model's effectiveness.

# %%
# Calculate the percentage of rows that contain at least one missing value
total_rows = combined_data.shape[0]
incomplete_rows = combined_data.isnull().any(axis=1).sum()
percentage_missing = incomplete_rows / total_rows * 100
# Print %
print(f"Percentage of rows with missing values: {percentage_missing:f}%")
# Drop these rows from the dataset
removed_missing_values = combined_data.dropna()
# Print the Dataset
print(removed_missing_values)
# Out:
# Percentage of rows with missing values: 61.750000%
#      unique_id   age    bp    bgr     bu    sc    sod  pot  hemo   pcv  ...  \
# 0       102677  59.0  70.0   76.0  186.0  15.0  135.0  7.6   7.1  22.0  ...
# 6       109053  64.0  60.0  106.0   27.0   0.7  150.0  3.3  14.4  42.0  ...
# 7       114717  41.0  80.0  122.0   25.0   0.8  138.0  5.0  17.1  41.0  ...
# 8       118191  42.0  70.0   93.0   32.0   0.9  143.0  4.7  16.6  43.0  ...
# 9       118596  74.0  60.0   88.0   50.0   0.6  147.0  3.7  17.2  53.0  ...
# ..         ...   ...   ...    ...    ...   ...    ...  ...   ...   ...  ...
# 390     980291  62.0  70.0  122.0   42.0   1.7  136.0  4.7  12.6  39.0  ...
# 391     991031  30.0  80.0   89.0   42.0   0.5  139.0  5.0  16.7  52.0  ...
# 394     994377  71.0  70.0   81.0   18.0   0.8  145.0  5.0  14.7  44.0  ...
# 395     995177  69.0  70.0  214.0   96.0   6.3  120.0  3.9   9.4  28.0  ...
# 396     996076  57.0  60.0  105.0   49.0   1.2  150.0  4.7  15.7  44.0  ...
#
#            pc         pcc          ba  htn   dm  cad appet   pe  ane  Target
# 0    abnormal  notpresent  notpresent  yes   no   no  poor  yes  yes     ckd
# 6      normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 7      normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 8      normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 9      normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# ..        ...         ...         ...  ...  ...  ...   ...  ...  ...     ...
# 390  abnormal  notpresent  notpresent  yes  yes   no  good   no   no     ckd
# 391    normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 394    normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 395  abnormal     present     present  yes  yes  yes  good  yes  yes     ckd
# 396    normal  notpresent  notpresent   no   no   no  good   no   no  notckd
#
# [153 rows x 25 columns]

# %% [markdown]
# ## Part 3.4: Sort the dataset according to the Labels

# %%
# Sort the dataset according to the values in 'Target' column. Make sure reset the indices after sorting
sorted_data = removed_missing_values.sort_values(by="Target")
# Print the dataset
print(sorted_data)
# Out:
#      unique_id   age    bp    bgr     bu    sc    sod  pot  hemo   pcv  ...  \
# 0       102677  59.0  70.0   76.0  186.0  15.0  135.0  7.6   7.1  22.0  ...
# 103     337834  48.0  70.0  117.0   56.0   3.8  111.0  2.5  11.2  32.0  ...
# 105     343710  61.0  80.0  173.0  148.0   3.9  135.0  5.2   7.7  24.0  ...
# 108     349892  59.0  70.0  424.0   55.0   1.7  138.0  4.5  12.6  37.0  ...
# 110     353025  40.0  70.0  253.0  150.0  11.9  132.0  5.6  10.9  31.0  ...
# ..         ...   ...   ...    ...    ...   ...    ...  ...   ...   ...  ...
# 171     486397  20.0  70.0  123.0   44.0   1.0  135.0  3.8  14.6  44.0  ...
# 43      203466  22.0  60.0   97.0   18.0   1.2  138.0  4.3  13.5  42.0  ...
# 169     482105  44.0  60.0   95.0   46.0   0.5  138.0  4.2  15.0  50.0  ...
# 54      228849  58.0  80.0  100.0   50.0   1.2  140.0  3.5  14.0  50.0  ...
# 396     996076  57.0  60.0  105.0   49.0   1.2  150.0  4.7  15.7  44.0  ...
#
#            pc         pcc          ba  htn   dm  cad appet   pe  ane  Target
# 0    abnormal  notpresent  notpresent  yes   no   no  poor  yes  yes     ckd
# 103  abnormal     present  notpresent  yes   no   no  poor  yes  yes     ckd
# 105  abnormal  notpresent  notpresent  yes  yes  yes  poor  yes  yes     ckd
# 108  abnormal  notpresent  notpresent  yes  yes  yes  good   no   no     ckd
# 110    normal  notpresent  notpresent  yes  yes   no  poor  yes   no     ckd
# ..        ...         ...         ...  ...  ...  ...   ...  ...  ...     ...
# 171    normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 43     normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 169    normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 54     normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 396    normal  notpresent  notpresent   no   no   no  good   no   no  notckd
#
# [153 rows x 25 columns]

# %% [markdown]
# ## Part 3.5: Encoding Categorical data
#
# In this step, we identify and process the categorical columns in the sorted dataset. We map each unique value in these columns to separate "dummy" columns.
#
# For example, the column 'rbc' will be transformed into two columns 'rbc_normal' and 'rbc_abnormal'. If a row's value in 'rbc' is 'normal', the 'rbc_normal' column will be set to 1 and 'rbc_abnormal' will be set to 0.
#
#
# **Note: Find a correct pandas function to do this **

# %%
# Write code here
categorical_columns = ["al", "su", "rbc", "pc", "pcc", "ba", "htn", "dm", "cad", "appet", "pe", "ane", "Target"]
encoded_data = pd.get_dummies(sorted_data, columns=categorical_columns, drop_first=False)

# Print the dataset
print(encoded_data)
# Out:
#      unique_id   age    bp    bgr     bu    sc    sod  pot  hemo   pcv  ...  \
# 0       102677  59.0  70.0   76.0  186.0  15.0  135.0  7.6   7.1  22.0  ...
# 103     337834  48.0  70.0  117.0   56.0   3.8  111.0  2.5  11.2  32.0  ...
# 105     343710  61.0  80.0  173.0  148.0   3.9  135.0  5.2   7.7  24.0  ...
# 108     349892  59.0  70.0  424.0   55.0   1.7  138.0  4.5  12.6  37.0  ...
# 110     353025  40.0  70.0  253.0  150.0  11.9  132.0  5.6  10.9  31.0  ...
# ..         ...   ...   ...    ...    ...   ...    ...  ...   ...   ...  ...
# 171     486397  20.0  70.0  123.0   44.0   1.0  135.0  3.8  14.6  44.0  ...
# 43      203466  22.0  60.0   97.0   18.0   1.2  138.0  4.3  13.5  42.0  ...
# 169     482105  44.0  60.0   95.0   46.0   0.5  138.0  4.2  15.0  50.0  ...
# 54      228849  58.0  80.0  100.0   50.0   1.2  140.0  3.5  14.0  50.0  ...
# 396     996076  57.0  60.0  105.0   49.0   1.2  150.0  4.7  15.7  44.0  ...
#
#      cad_no  cad_yes  appet_good  appet_poor  pe_no  pe_yes  ane_no  ane_yes  \
# 0      True    False       False        True  False    True   False     True
# 103    True    False       False        True  False    True   False     True
# 105   False     True       False        True  False    True   False     True
# 108   False     True        True       False   True   False    True    False
# 110    True    False       False        True  False    True    True    False
# ..      ...      ...         ...         ...    ...     ...     ...      ...
# 171    True    False        True       False   True   False    True    False
# 43     True    False        True       False   True   False    True    False
# 169    True    False        True       False   True   False    True    False
# 54     True    False        True       False   True   False    True    False
# 396    True    False        True       False   True   False    True    False
#
#      Target_ckd  Target_notckd
# 0          True          False
# 103        True          False
# 105        True          False
# 108        True          False
# 110        True          False
# ..          ...            ...
# 171       False           True
# 43        False           True
# 169       False           True
# 54        False           True
# 396       False           True
#
# [153 rows x 45 columns]

# %% [markdown]
# In the example we went through above, another solution is to have a single column for the binary variable. In the downstream modeling would this be equivalent? What effect would this have if the categorical variable could take more than 2 values? For example, let's say we have a categorical feature that is "type of condiment" that can take 5 separate values and we are trying to predict the rating of a particular sandwich.

# %% [markdown]
# Answer: This would be equivalent for the downstream task model because there are only two categories for CKD: has CKD and does not have CKD. This would not be equivalent if there were more than two values that the category could take, however. Using dummy variables instead of binary variables might also help in analyzing the correlation between combination of variables

# %% [markdown]
# ## Part 3.6 : Remove Outliers from Numerical Columns
#
# Outliers can disproportionately influence the fit of a regression model, potentially leading to a model that does not generalize well therefore it is important that we remove outliers from the numerical columns of the dataset.
#
# For this dataset, we define an outlier to be 3 times the standard deviation from the mean. Drop these outliers from the dataset

# %%
# Remove outliers
numerical_columns = ['age', 'bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']
for column in numerical_columns:
    mean = encoded_data[column].mean()
    std_dev = encoded_data[column].std()
    lower_bound = mean - 3 * std_dev
    upper_bound = mean + 3 * std_dev
    removed_outliers = encoded_data[(encoded_data[column] >= lower_bound) & (encoded_data[column] <= upper_bound)]

# Print the dataset
print(removed_outliers)
# Out:
#      unique_id   age    bp    bgr     bu    sc    sod  pot  hemo   pcv  ...  \
# 0       102677  59.0  70.0   76.0  186.0  15.0  135.0  7.6   7.1  22.0  ...
# 103     337834  48.0  70.0  117.0   56.0   3.8  111.0  2.5  11.2  32.0  ...
# 105     343710  61.0  80.0  173.0  148.0   3.9  135.0  5.2   7.7  24.0  ...
# 108     349892  59.0  70.0  424.0   55.0   1.7  138.0  4.5  12.6  37.0  ...
# 110     353025  40.0  70.0  253.0  150.0  11.9  132.0  5.6  10.9  31.0  ...
# ..         ...   ...   ...    ...    ...   ...    ...  ...   ...   ...  ...
# 171     486397  20.0  70.0  123.0   44.0   1.0  135.0  3.8  14.6  44.0  ...
# 43      203466  22.0  60.0   97.0   18.0   1.2  138.0  4.3  13.5  42.0  ...
# 169     482105  44.0  60.0   95.0   46.0   0.5  138.0  4.2  15.0  50.0  ...
# 54      228849  58.0  80.0  100.0   50.0   1.2  140.0  3.5  14.0  50.0  ...
# 396     996076  57.0  60.0  105.0   49.0   1.2  150.0  4.7  15.7  44.0  ...
#
#      cad_no  cad_yes  appet_good  appet_poor  pe_no  pe_yes  ane_no  ane_yes  \
# 0      True    False       False        True  False    True   False     True
# 103    True    False       False        True  False    True   False     True
# 105   False     True       False        True  False    True   False     True
# 108   False     True        True       False   True   False    True    False
# 110    True    False       False        True  False    True    True    False
# ..      ...      ...         ...         ...    ...     ...     ...      ...
# 171    True    False        True       False   True   False    True    False
# 43     True    False        True       False   True   False    True    False
# 169    True    False        True       False   True   False    True    False
# 54     True    False        True       False   True   False    True    False
# 396    True    False        True       False   True   False    True    False
#
#      Target_ckd  Target_notckd
# 0          True          False
# 103        True          False
# 105        True          False
# 108        True          False
# 110        True          False
# ..          ...            ...
# 171       False           True
# 43        False           True
# 169       False           True
# 54        False           True
# 396       False           True
#
# [152 rows x 45 columns]

# %% [markdown]
# ## Part 3.7 : Normalize the Numerical Columns
#
# Normalizing numerical attributes ensures that all features contribute equally to the model by scaling them to a consistent range, which improves model performance and convergence. It prevents features with larger scales from disproportionately influencing the model's learning process.

# %%
# Normalize the all Numerical Attributes in the dataset.
scaler = MinMaxScaler()
removed_outliers[numerical_columns] = scaler.fit_transform(removed_outliers[numerical_columns])
normalized_data = removed_outliers
# Print the dataset
print(normalized_data)
# Out:
#      unique_id       age        bp       bgr        bu        sc       sod  \
# 0       102677  0.688312  0.333333  0.014286  0.588629  0.986486  0.615385
# 103     337834  0.545455  0.333333  0.111905  0.153846  0.229730  0.000000
# 105     343710  0.714286  0.500000  0.245238  0.461538  0.236486  0.615385
# 108     349892  0.688312  0.333333  0.842857  0.150502  0.087838  0.692308
# 110     353025  0.441558  0.333333  0.435714  0.468227  0.777027  0.538462
# ..         ...       ...       ...       ...       ...       ...       ...
# 171     486397  0.181818  0.333333  0.126190  0.113712  0.040541  0.615385
# 43      203466  0.207792  0.166667  0.064286  0.026756  0.054054  0.692308
# 169     482105  0.493506  0.166667  0.059524  0.120401  0.006757  0.692308
# 54      228849  0.675325  0.500000  0.071429  0.133779  0.054054  0.743590
# 396     996076  0.662338  0.166667  0.083333  0.130435  0.054054  1.000000
#
#           pot      hemo       pcv  ...  cad_no  cad_yes  appet_good  \
# 0    0.114607  0.272109  0.288889  ...    True    False       False
# 103  0.000000  0.551020  0.511111  ...    True    False       False
# 105  0.060674  0.312925  0.333333  ...   False     True       False
# 108  0.044944  0.646259  0.622222  ...   False     True        True
# 110  0.069663  0.530612  0.488889  ...    True    False       False
# ..        ...       ...       ...  ...     ...      ...         ...
# 171  0.029213  0.782313  0.777778  ...    True    False        True
# 43   0.040449  0.707483  0.733333  ...    True    False        True
# 169  0.038202  0.809524  0.911111  ...    True    False        True
# 54   0.022472  0.741497  0.911111  ...    True    False        True
# 396  0.049438  0.857143  0.777778  ...    True    False        True
#
#      appet_poor  pe_no  pe_yes  ane_no  ane_yes  Target_ckd  Target_notckd
# 0          True  False    True   False     True        True          False
# 103        True  False    True   False     True        True          False
# 105        True  False    True   False     True        True          False
# 108       False   True   False    True    False        True          False
# 110        True  False    True    True    False        True          False
# ..          ...    ...     ...     ...      ...         ...            ...
# 171       False   True   False    True    False       False           True
# 43        False   True   False    True    False       False           True
# 169       False   True   False    True    False       False           True
# 54        False   True   False    True    False       False           True
# 396       False   True   False    True    False       False           True
#
# [152 rows x 45 columns]
# C:\Users\jeffr\AppData\Local\Temp\ipykernel_16380\2055539137.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   removed_outliers[numerical_columns] = scaler.fit_transform(removed_outliers[numerical_columns])

# %% [markdown]
# ## Part 3.8: Remove Unnecessary columns

# %% [markdown]
# Are there any columns in this dataset which are not appropriate for modeling and predictions? Which column(s)? Justify their exclusion and remove them

# %% [markdown]
# Answer: The unique_id variable should not be included for modeling and predictions because it does not provide any relevant data to be analyzed.

# %%
# Remove that column
normalized_data.drop("unique_id", axis="columns", inplace=True)

# Print the dataset
print(normalized_data)
# Out:
#           age        bp       bgr        bu        sc       sod       pot  \
# 0    0.688312  0.333333  0.014286  0.588629  0.986486  0.615385  0.114607
# 103  0.545455  0.333333  0.111905  0.153846  0.229730  0.000000  0.000000
# 105  0.714286  0.500000  0.245238  0.461538  0.236486  0.615385  0.060674
# 108  0.688312  0.333333  0.842857  0.150502  0.087838  0.692308  0.044944
# 110  0.441558  0.333333  0.435714  0.468227  0.777027  0.538462  0.069663
# ..        ...       ...       ...       ...       ...       ...       ...
# 171  0.181818  0.333333  0.126190  0.113712  0.040541  0.615385  0.029213
# 43   0.207792  0.166667  0.064286  0.026756  0.054054  0.692308  0.040449
# 169  0.493506  0.166667  0.059524  0.120401  0.006757  0.692308  0.038202
# 54   0.675325  0.500000  0.071429  0.133779  0.054054  0.743590  0.022472
# 396  0.662338  0.166667  0.083333  0.130435  0.054054  1.000000  0.049438
#
#          hemo       pcv      wbcc  ...  cad_no  cad_yes  appet_good  \
# 0    0.272109  0.288889  0.000000  ...    True    False       False
# 103  0.551020  0.511111  0.128319  ...    True    False       False
# 105  0.312925  0.333333  0.238938  ...   False     True       False
# 108  0.646259  0.622222  0.283186  ...   False     True        True
# 110  0.530612  0.488889  0.221239  ...    True    False       False
# ..        ...       ...       ...  ...     ...      ...         ...
# 171  0.782313  0.777778  0.075221  ...    True    False        True
# 43   0.707483  0.733333  0.181416  ...    True    False        True
# 169  0.809524  0.911111  0.172566  ...    True    False        True
# 54   0.741497  0.911111  0.128319  ...    True    False        True
# 396  0.857143  0.777778  0.292035  ...    True    False        True
#
#      appet_poor  pe_no  pe_yes  ane_no  ane_yes  Target_ckd  Target_notckd
# 0          True  False    True   False     True        True          False
# 103        True  False    True   False     True        True          False
# 105        True  False    True   False     True        True          False
# 108       False   True   False    True    False        True          False
# 110        True  False    True    True    False        True          False
# ..          ...    ...     ...     ...      ...         ...            ...
# 171       False   True   False    True    False       False           True
# 43        False   True   False    True    False       False           True
# 169       False   True   False    True    False       False           True
# 54        False   True   False    True    False       False           True
# 396       False   True   False    True    False       False           True
#
# [152 rows x 44 columns]
# C:\Users\jeffr\AppData\Local\Temp\ipykernel_16380\812532580.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   normalized_data.drop("unique_id", axis="columns", inplace=True)

# %% [markdown]
# ## Part 3.9: Export the Cleaned Data

# %% [markdown]
# Now that you've completed these cleaning steps you should have a pandas dataframe which is much cleaner and ready for modeling. Our final step is to save our work. Export the DataFrame to a two new formats: csv and json.

# %%
# Export the dataframe to a new csv file
removed_missing_values.to_csv('cleaned_data.csv', index=False)
# Export the dataframe to a new json file
removed_missing_values.to_json('cleaned_data.json', orient='records', lines=True)

# %% [markdown]
# # Part 4: Data conversions with Large Language Models
#
# One powerful use case of ChatGPT (and other generative language models) is cleaning and transforming data. In some cases, these models can directly manipulate loosely structured data that you provide to them into a standard format. In the other cases, you can often prompt the model to create a conversion or extraction script for you in python or Pandas and then run it on your own.
#
# In this part of the assignment you will prompt 383GPT to explore these capabilities.

# %% [markdown]
# ## Part 4.1 GPT Data Manipulation
#
# Take the cleaned dataset that you created in part three and output the top 15 rows of that dataset. Then copy the terminal output, open 383gpt and ask it to convert that output to a markdown table. Paste that markdown table in the cell bellow

# %% [markdown]
# ### Paste the markdown table here

# %%
# |    age |    bp |    bgr |    bu |    sc |    sod |    pot |    hemo |    pcv |    wbcc |    rbcc |    al |    su |      rbc  |      pc  |         pcc  |         ba | htn | dm | cad | appet | pe | ane   |
# |--------|-------|--------|-------|-------|--------|--------|---------|--------|---------|---------|-------|-------|-----------|----------|--------------|------------|-----|----|-----|-------|----|-------|
# | 0.7838 | 0.0   | 0.1545 | 0.111 | 0.037 | 1.0    | 0.1379 | 0.6634  | 0.6129 | 0.3065  | 0.4857  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.4730 | 0.5   | 0.2232 | 0.098 | 0.049 | 0.6    | 0.7241 | 0.9307  | 0.5806 | 0.3871  | 0.6286  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.4865 | 0.25  | 0.0987 | 0.143 | 0.062 | 0.7667 | 0.6207 | 0.8812  | 0.6452 | 0.2258  | 0.6571  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.9189 | 0.0   | 0.0773 | 0.261 | 0.025 | 0.9    | 0.2759 | 0.9406  | 0.9677 | 0.1371  | 0.4286  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.4189 | 0.0   | 0.1674 | 0.242 | 0.086 | 0.7    | 0.6897 | 0.7228  | 0.8065 | 0.2177  | 0.6286  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.6216 | 0.5   | 0.2361 | 0.078 | 0.099 | 0.6333 | 0.5862 | 0.8713  | 0.6452 | 0.0323  | 0.4571  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.3108 | 0.5   | 0.0558 | 0.255 | 0.062 | 0.6333 | 0.1379 | 0.9703  | 0.5484 | 0.4516  | 0.4857  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.8378 | 0.0   | 0.2361 | 0.203 | 0.086 | 0.6333 | 0.3103 | 0.9604  | 0.8710 | 0.1935  | 0.8857  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.7162 | 0.0   | 0.1845 | 0.085 | 0.086 | 0.6333 | 0.2069 | 0.7525  | 1.0    | 0.1774  | 0.5429  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.5676 | 0.0   | 0.1803 | 0.222 | 0.099 | 0.7333 | 0.6897 | 0.6733  | 0.6774 | 0.4113  | 0.9714  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.8108 | 0.25  | 0.1588 | 0.039 | 0.086 | 0.6667 | 0.2414 | 0.5842  | 0.6129 | 0.5403  | 0.5429  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.6081 | 0.0   | 0.1245 | 0.183 | 0.049 | 0.5    | 0.2759 | 0.5248  | 0.8387 | 0.3226  | 0.6286  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.6757 | 0.25  | 0.6009 | 0.105 | 0.160 | 0.5333 | 0.3103 | 0.8317  | 0.9355 | 0.6613  | 0.7429  | 4.0   | 1.0   | abnormal  | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.3649 | 0.5   | 0.0815 | 0.059 | 0.086 | 0.8    | 0.7241 | 0.7228  | 0.5484 | 0.4839  | 0.5143  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |
# | 0.7027 | 0.25  | 0.0773 | 0.039 | 0.086 | 0.9    | 0.2069 | 0.8614  | 0.9677 | 0.3871  | 0.6286  | 0.0   | 0.0   | normal    | normal   | notpresent   | notpresent | no  | no | no  | good  | no | no    |

# %% [markdown]
# ** Caution: ** while language models can perform data conversions they also can * hallucinate * during this process, particularly for bigger datasets. Reflect on this below, how could you mitigate data conversion hallucinations from LLM conversions?

# %% [markdown]
# You could mitigate data conversion hallucinations from LLM conversations by providing small examples with correct data conversions (few-shot) or by asking the LLM to perform the task at a smaller scale while writing and explaining each step carefully (CoT), then asking it to apply the data conversion at a longer scale if it has a large enough memory capacity.

# %% [markdown]
# ## Part 4.2 GPT Pandas Prompting
#
# In this section, you will prompt 383GPT to write pandas code manipulations for you.
#
# After working with this data for awhile, we realized we're starting to forget the meanings of the abbreviated column names. Let's ask 383GPT to fix this for us. First, navigate to the [UCI dataset overview](https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease) and copy the abbrevation to name mapping. Then, go to 383GPT and instruct the LLM to provide you with a pandas script to apply this renaming to all the columns of your dataset. Paste that code below and make any adjustments necessary to run it in your notebook.

# %%
# Code to rename all the columns in the dataset
rename_dict = {
    'age': 'age',
    'bp': 'blood pressure',
    'sg': 'specific gravity',
    'al': 'albumin',
    'su': 'sugar',
    'rbc': 'red blood cells',
    'pc': 'pus cell',
    'pcc': 'pus cell clumps',
    'ba': 'bacteria',
    'bgr': 'blood glucose random',
    'bu': 'blood urea',
    'sc': 'serum creatinine',
    'sod': 'sodium',
    'pot': 'potassium',
    'hemo': 'hemoglobin',
    'pcv': 'packed cell volume',
    'wc': 'white blood cell count',
    'rc': 'red blood cell count',
    'htn': 'hypertension',
    'dm': 'diabetes mellitus',
    'cad': 'coronary artery disease',
    'appet': 'appetite',
    'pe': 'pedal edema',
    'ane': 'anemia',
    'class': 'class'
}

removed_missing_values.rename(columns=rename_dict, inplace=True)
print(removed_missing_values)
# Out:
#      unique_id   age  blood pressure  blood glucose random  blood urea  \
# 0       102677  59.0            70.0                  76.0       186.0
# 6       109053  64.0            60.0                 106.0        27.0
# 7       114717  41.0            80.0                 122.0        25.0
# 8       118191  42.0            70.0                  93.0        32.0
# 9       118596  74.0            60.0                  88.0        50.0
# ..         ...   ...             ...                   ...         ...
# 390     980291  62.0            70.0                 122.0        42.0
# 391     991031  30.0            80.0                  89.0        42.0
# 394     994377  71.0            70.0                  81.0        18.0
# 395     995177  69.0            70.0                 214.0        96.0
# 396     996076  57.0            60.0                 105.0        49.0
#
#      serum creatinine  sodium  potassium  hemoglobin  packed cell volume  ...  \
# 0                15.0   135.0        7.6         7.1                22.0  ...
# 6                 0.7   150.0        3.3        14.4                42.0  ...
# 7                 0.8   138.0        5.0        17.1                41.0  ...
# 8                 0.9   143.0        4.7        16.6                43.0  ...
# 9                 0.6   147.0        3.7        17.2                53.0  ...
# ..                ...     ...        ...         ...                 ...  ...
# 390               1.7   136.0        4.7        12.6                39.0  ...
# 391               0.5   139.0        5.0        16.7                52.0  ...
# 394               0.8   145.0        5.0        14.7                44.0  ...
# 395               6.3   120.0        3.9         9.4                28.0  ...
# 396               1.2   150.0        4.7        15.7                44.0  ...
#
#      pus cell  pus cell clumps    bacteria  hypertension diabetes mellitus  \
# 0    abnormal       notpresent  notpresent           yes                no
# 6      normal       notpresent  notpresent            no                no
# 7      normal       notpresent  notpresent            no                no
# 8      normal       notpresent  notpresent            no                no
# 9      normal       notpresent  notpresent            no                no
# ..        ...              ...         ...           ...               ...
# 390  abnormal       notpresent  notpresent           yes               yes
# 391    normal       notpresent  notpresent            no                no
# 394    normal       notpresent  notpresent            no                no
# 395  abnormal          present     present           yes               yes
# 396    normal       notpresent  notpresent            no                no
#
#     coronary artery disease appetite pedal edema anemia  Target
# 0                        no     poor         yes    yes     ckd
# 6                        no     good          no     no  notckd
# 7                        no     good          no     no  notckd
# 8                        no     good          no     no  notckd
# 9                        no     good          no     no  notckd
# ..                      ...      ...         ...    ...     ...
# 390                      no     good          no     no     ckd
# 391                      no     good          no     no  notckd
# 394                      no     good          no     no  notckd
# 395                     yes     good         yes    yes     ckd
# 396                      no     good          no     no  notckd
#
# [153 rows x 25 columns]
# C:\Users\jeffr\AppData\Local\Temp\ipykernel_16380\2614167474.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   removed_missing_values.rename(columns=rename_dict, inplace=True)

# %% [markdown]
# ## Part 4.3 Augmenting our skills with prompting
#
# In addition, we can also use 383GPT to convert our data manipulation operations between different data manipulation languages and libraries. For example let's prompt 383GPT to convert the following SQL query to a pandas query.
#
# **SQL Query**
# ```sql
# SELECT Target, COUNT(*) AS count
# FROM your_table_name
# GROUP BY Target;
# ```
#
# Prompt 383GPT to convert this to a pandas query. Run this query below, then describe what it does. (If you're not familiar with SQL that is okay you need to only comment on the final resulting output.)

# %%
# Converted SQL to Pandas code
result = removed_missing_values.groupby('Target').size().reset_index(name='count')

print(result)
# Out:
#    Target  count
# 0     ckd     42
# 1  notckd    111

# %% [markdown]
# *Describe what the above code does here*

# %% [markdown]
# The code effectively summarizes the distributions of the categorical data under the target column. It counts up the number of each group that appears under the specified column.

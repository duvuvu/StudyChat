# %%
# Imports and pip installations (if needed)
import pandas as pd
import numpy as np

# %% [markdown]
# # Part 1: Load the dataset

# %%
# Load the given datasets
numerical = pd.read_csv("chronic_kidney_disease_numerical.csv")
categorical = pd.read_csv("chronic_kidney_disease_categorical.csv")

# Print the data

display(numerical)
display(categorical)
# Out:
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       203694  38.0   80.0   99.0   19.0  0.5  147.0  3.5  13.6  44.0
# 1       938027  43.0   60.0  108.0   25.0  1.0  144.0  5.0  17.8  43.0
# 2       421471  37.0   60.0  111.0   35.0  0.8  135.0  4.1  16.2  50.0
# 3       764115  70.0   90.0  144.0  125.0  4.0  136.0  4.6  12.0  37.0
# 4       240975  47.0   80.0   95.0   35.0  0.9  140.0  4.1   NaN   NaN
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 415     522912  56.0   80.0  165.0   55.0  1.8    NaN  NaN  13.5  40.0
# 416     475200  64.0  100.0  163.0   54.0  7.2  140.0  4.6   7.9  26.0
# 417     168242  48.0   60.0  112.0   44.0  1.2  142.0  4.9  14.5  44.0
# 418     474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 419     926033  50.0   70.0  230.0   50.0  2.2    NaN  NaN  12.0  41.0
#
#         wbcc  rbcc
# 0     7300.0   6.4
# 1     7200.0   5.5
# 2     5500.0   5.7
# 3     8200.0   4.5
# 4        NaN   NaN
# ..       ...   ...
# 415  11800.0   5.0
# 416   7500.0   3.4
# 417   9400.0   6.4
# 418  12400.0   3.9
# 419  10400.0   4.6
#
# [420 rows x 12 columns]
#      unique_id   al   su       rbc        pc         pcc          ba  htn  \
# 0       224481  3.0  NaN       NaN       NaN  notpresent  notpresent  yes
# 1       992643  0.0  0.0       NaN       NaN  notpresent  notpresent   no
# 2       308740  1.0  0.0  abnormal  abnormal  notpresent  notpresent  yes
# 3       450314  1.0  0.0       NaN    normal  notpresent  notpresent   no
# 4       881763  0.0  0.0    normal    normal  notpresent  notpresent   no
# ..         ...  ...  ...       ...       ...         ...         ...  ...
# 425     769512  0.0  0.0    normal    normal  notpresent  notpresent   no
# 426     872034  2.0  1.0  abnormal  abnormal  notpresent     present  yes
# 427     643007  NaN  NaN       NaN    normal  notpresent  notpresent  yes
# 428     840392  NaN  NaN       NaN       NaN  notpresent  notpresent  yes
# 429     856244  0.0  0.0       NaN    normal  notpresent  notpresent  yes
#
#       dm  cad appet   pe  ane  Target
# 0    yes   no  good  yes   no     ckd
# 1     no   no  good   no   no  notckd
# 2     no   no  good  yes   no     ckd
# 3     no   no  good   no  yes     ckd
# 4     no   no  good   no   no  notckd
# ..   ...  ...   ...  ...  ...     ...
# 425   no   no  good   no   no  notckd
# 426  yes  yes  poor   no   no     ckd
# 427  yes  yes  poor   no   no     ckd
# 428   no   no  poor   no   no     ckd
# 429  yes   no  poor   no   no     ckd
#
# [430 rows x 14 columns]

# %% [markdown]
# # Part 2: Analyze the Dataset

# %% [markdown]
# Refer to this: https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease
#
# Explain what the each data is in your own words. What are the features and labels? Are the features in the given datasets : categorical, numerical or both? Give 3 examples of categorical and numerical columns each (if they exist)

# %% [markdown]
# Answer:
#
# The data in the datasets can be used to help predict if a patient will have chronic kidney disease. The features of the dataset are all the different variables that help determine if someone has chronic kidney disorder, and the label is the variable "Target", which is whether or not someone has ckd.
#
# All the features in the numerical dataset are numerical features (such as age, bp, and bgr). All the features in the categorical dataset are either categorical (such as rbc, pc, and bs), or nominal (such as al and su).

# %% [markdown]
# # Part 3: Data Preprocessing
#
# A fundamental skill in Machine Learning is mastering the art of data cleaning and preprocessing. In this assignment, you will learn and apply essential data cleaning techniques to transform a raw dataset into a clean, ready-to-use form which you can use for regression or classification tasks. By the end of this assignment, you'll have a fully clean dataset and a solid foundation in preparing data for various machine learning models.

# %% [markdown]
# ## Part 3.1 : Drop Duplicate rows
#
# Let's start by checking if the given datasets have any duplicate rows (same Unique Id). Use pandas to identify and remove these duplicate rows from the given dataset

# %%
# For the numerical dataset, check if there are duplicate rows in the dataset. If yes, print total number of duplicate rows
num_before = len(numerical)
num_no_dup = numerical.drop_duplicates(subset="unique_id")
num_after = len(num_no_dup)
if num_before > num_after:
    num_diff = num_before - num_after
    print("Duplicates in numerical:", num_diff)

# Drop these duplicate rows


# Repeat the same for categorical dataset. Print the duplicate rows and drop them
cat_before = len(categorical)
cat_no_dup = categorical.drop_duplicates(subset="unique_id")
cat_after = len(cat_no_dup)
if cat_before > cat_after:
    cat_diff = cat_before - cat_after
    print("Duplicates in categorical:", cat_diff)
# Out:
# Duplicates in numerical: 30
# Duplicates in categorical: 30

# %% [markdown]
# ## Part 3.2: Combine two differents datasets
#
# A good skill to have is to know how to combine 2 different datasets.
#
# Are all the unique ids are present in both datasets? Why do you think so? If not, what do the rows that are missing from one of the datasets look like in the combined table?

# %% [markdown]
# Answer:
# All the unique ids should be in both datasets. Each unique id represents a different patient, and if they aren't in both datasets, then you have some data missing on them. If they are missing from one of the datasets, then you are only going to have half of the information on them.

# %%
# Merge the two given numerical and categorical datasets based on their unique_ID.
df = pd.merge(num_no_dup, cat_no_dup)
#Print the combined dataset
display(df)
# Out:
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       203694  38.0   80.0   99.0   19.0  0.5  147.0  3.5  13.6  44.0
# 1       938027  43.0   60.0  108.0   25.0  1.0  144.0  5.0  17.8  43.0
# 2       421471  37.0   60.0  111.0   35.0  0.8  135.0  4.1  16.2  50.0
# 3       764115  70.0   90.0  144.0  125.0  4.0  136.0  4.6  12.0  37.0
# 4       240975  47.0   80.0   95.0   35.0  0.9  140.0  4.1   NaN   NaN
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 385     522912  56.0   80.0  165.0   55.0  1.8    NaN  NaN  13.5  40.0
# 386     475200  64.0  100.0  163.0   54.0  7.2  140.0  4.6   7.9  26.0
# 387     168242  48.0   60.0  112.0   44.0  1.2  142.0  4.9  14.5  44.0
# 388     474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 389     926033  50.0   70.0  230.0   50.0  2.2    NaN  NaN  12.0  41.0
#
#         wbcc  rbcc   al   su       rbc        pc         pcc          ba  htn  \
# 0     7300.0   6.4  0.0  0.0    normal    normal  notpresent  notpresent   no
# 1     7200.0   5.5  0.0  0.0    normal    normal  notpresent  notpresent   no
# 2     5500.0   5.7  0.0  0.0    normal    normal  notpresent  notpresent   no
# 3     8200.0   4.5  0.0  0.0       NaN    normal  notpresent  notpresent  yes
# 4        NaN   NaN  0.0  0.0    normal    normal  notpresent  notpresent   no
# ..       ...   ...  ...  ...       ...       ...         ...         ...  ...
# 385  11800.0   5.0  1.0  0.0       NaN    normal  notpresent  notpresent  yes
# 386   7500.0   3.4  4.0  2.0  abnormal  abnormal  notpresent     present  yes
# 387   9400.0   6.4  0.0  0.0    normal    normal  notpresent  notpresent   no
# 388  12400.0   3.9  4.0  0.0    normal  abnormal     present     present   no
# 389  10400.0   4.6  0.0  0.0       NaN    normal  notpresent  notpresent  yes
#
#       dm cad appet   pe  ane  Target
# 0     no  no  good   no   no  notckd
# 1     no  no  good   no   no  notckd
# 2     no  no  good   no   no  notckd
# 3    yes  no  poor  yes   no     ckd
# 4     no  no  good   no   no  notckd
# ..   ...  ..   ...  ...  ...     ...
# 385  yes  no  poor  yes   no     ckd
# 386  yes  no  good  yes   no     ckd
# 387   no  no  good   no   no  notckd
# 388   no  no  good   no  yes     ckd
# 389  yes  no  good   no   no     ckd
#
# [390 rows x 25 columns]

# %% [markdown]
# ## Part 3.3: Rows with Missing values
#
# Removing missing values from a dataset is important for classification because it ensures the model is trained on complete and accurate data, leading to better performance and reliable predictions. Incomplete data can introduce bias and errors, negatively impacting the model's effectiveness.

# %%
# Calculate the percentage of rows that contain atleast one missing value
before = len(df)
df = df.dropna(axis=0, how='any')
after = len(df)
# Print %
diff = (after/before)*100
print("Percent of rows with at least one missing value:", diff,"%")
# Drop these rows from the dataset

# Print the Dataset
display(df)
# Out:
# Percent of rows with at least one missing value: 39.23076923076923 %
#      unique_id   age     bp    bgr    bu   sc    sod  pot  hemo   pcv  \
# 0       203694  38.0   80.0   99.0  19.0  0.5  147.0  3.5  13.6  44.0
# 1       938027  43.0   60.0  108.0  25.0  1.0  144.0  5.0  17.8  43.0
# 2       421471  37.0   60.0  111.0  35.0  0.8  135.0  4.1  16.2  50.0
# 7       109053  64.0   60.0  106.0  27.0  0.7  150.0  3.3  14.4  42.0
# 13      349892  59.0   70.0  424.0  55.0  1.7  138.0  4.5  12.6  37.0
# ..         ...   ...    ...    ...   ...  ...    ...  ...   ...   ...
# 379     486397  20.0   70.0  123.0  44.0  1.0  135.0  3.8  14.6  44.0
# 381     462892  36.0   80.0   85.0  16.0  1.1  142.0  4.1  15.6  44.0
# 386     475200  64.0  100.0  163.0  54.0  7.2  140.0  4.6   7.9  26.0
# 387     168242  48.0   60.0  112.0  44.0  1.2  142.0  4.9  14.5  44.0
# 388     474407  21.0   90.0  107.0  40.0  1.7  125.0  3.5   8.3  23.0
#
#         wbcc  rbcc   al   su       rbc        pc         pcc          ba  htn  \
# 0     7300.0   6.4  0.0  0.0    normal    normal  notpresent  notpresent   no
# 1     7200.0   5.5  0.0  0.0    normal    normal  notpresent  notpresent   no
# 2     5500.0   5.7  0.0  0.0    normal    normal  notpresent  notpresent   no
# 7     8100.0   4.7  0.0  0.0    normal    normal  notpresent  notpresent   no
# 13   10200.0   4.1  1.0  3.0  abnormal  abnormal  notpresent  notpresent  yes
# ..       ...   ...  ...  ...       ...       ...         ...         ...  ...
# 379   5500.0   4.8  0.0  0.0    normal    normal  notpresent  notpresent   no
# 381   5800.0   6.3  0.0  0.0    normal    normal  notpresent  notpresent   no
# 386   7500.0   3.4  4.0  2.0  abnormal  abnormal  notpresent     present  yes
# 387   9400.0   6.4  0.0  0.0    normal    normal  notpresent  notpresent   no
# 388  12400.0   3.9  4.0  0.0    normal  abnormal     present     present   no
#
#       dm  cad appet   pe  ane  Target
# 0     no   no  good   no   no  notckd
# 1     no   no  good   no   no  notckd
# 2     no   no  good   no   no  notckd
# 7     no   no  good   no   no  notckd
# 13   yes  yes  good   no   no     ckd
# ..   ...  ...   ...  ...  ...     ...
# 379   no   no  good   no   no  notckd
# 381   no   no  good   no   no  notckd
# 386  yes   no  good  yes   no     ckd
# 387   no   no  good   no   no  notckd
# 388   no   no  good   no  yes     ckd
#
# [153 rows x 25 columns]

# %% [markdown]
# ## Part 3.4: Sort the dataset according to the Labels

# %%
# Sort the dataset according to the values in 'Target' column. Make sure reset the indices after sorting
df = df.sort_values(by=['Target'])
df = df.reset_index(drop=True)
# Print the dataset
display(df)
# Out:
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 1       137148  73.0  100.0  295.0   90.0  5.6  140.0  2.9   9.2  30.0
# 2       484175  53.0   90.0   70.0  107.0  7.2  114.0  3.7   9.5  29.0
# 3       343710  61.0   80.0  173.0  148.0  3.9  135.0  5.2   7.7  24.0
# 4       532520  60.0   90.0  105.0   53.0  2.3  136.0  5.2  11.1  33.0
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 148     647552  61.0   70.0  120.0   29.0  0.7  137.0  3.5  17.4  52.0
# 149     125587  37.0   60.0  109.0   47.0  1.1  141.0  4.9  15.0  48.0
# 150     614376  57.0   80.0  119.0   17.0  1.2  135.0  4.7  15.4  42.0
# 151     853426  41.0   70.0  125.0   38.0  0.6  140.0  5.0  16.8  41.0
# 152     572140  55.0   80.0  104.0   28.0  0.9  142.0  4.8  17.3  52.0
#
#         wbcc  rbcc   al   su       rbc        pc         pcc          ba  htn  \
# 0    12400.0   3.9  4.0  0.0    normal  abnormal     present     present   no
# 1     7000.0   3.2  3.0  2.0  abnormal  abnormal     present  notpresent  yes
# 2    12100.0   3.7  2.0  0.0  abnormal  abnormal     present  notpresent  yes
# 3     9200.0   3.2  2.0  0.0  abnormal  abnormal  notpresent  notpresent  yes
# 4    10500.0   4.1  2.0  0.0  abnormal    normal  notpresent  notpresent   no
# ..       ...   ...  ...  ...       ...       ...         ...         ...  ...
# 148   7000.0   5.3  0.0  0.0    normal    normal  notpresent  notpresent   no
# 149   7000.0   5.2  0.0  0.0    normal    normal  notpresent  notpresent   no
# 150   6200.0   6.2  0.0  0.0    normal    normal  notpresent  notpresent   no
# 151   6300.0   5.9  0.0  0.0    normal    normal  notpresent  notpresent   no
# 152   8200.0   4.8  0.0  0.0    normal    normal  notpresent  notpresent   no
#
#       dm  cad appet   pe  ane  Target
# 0     no   no  good   no  yes     ckd
# 1    yes  yes  poor   no   no     ckd
# 2    yes   no  poor   no  yes     ckd
# 3    yes  yes  poor  yes  yes     ckd
# 4     no   no  good   no   no     ckd
# ..   ...  ...   ...  ...  ...     ...
# 148   no   no  good   no   no  notckd
# 149   no   no  good   no   no  notckd
# 150   no   no  good   no   no  notckd
# 151   no   no  good   no   no  notckd
# 152   no   no  good   no   no  notckd
#
# [153 rows x 25 columns]

# %% [markdown]
# ## Part 3.5: Encoding Categorical data
#
# In this step, we identify and process the categorical columns in the sorted dataset. We map each unique value in these columns to separate "dummy" columns.
#
# For example, the column 'rbc' will be transformed into two columns 'rbc_normal' and 'rbc_abnormal'. If a row's value in 'rbc' is 'normal', the 'rbc_normal' column will be set to 1 and 'rbc_abnormal' will be set to 0.
#
#
# **Note: Find a correct pandas function to do this **

# %%
# Write code here
categorical_columns = ['rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'Target']
df_dummies = pd.get_dummies(df, columns=categorical_columns)
# Print the dataset
display(df_dummies)
# Out:
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 1       137148  73.0  100.0  295.0   90.0  5.6  140.0  2.9   9.2  30.0
# 2       484175  53.0   90.0   70.0  107.0  7.2  114.0  3.7   9.5  29.0
# 3       343710  61.0   80.0  173.0  148.0  3.9  135.0  5.2   7.7  24.0
# 4       532520  60.0   90.0  105.0   53.0  2.3  136.0  5.2  11.1  33.0
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 148     647552  61.0   70.0  120.0   29.0  0.7  137.0  3.5  17.4  52.0
# 149     125587  37.0   60.0  109.0   47.0  1.1  141.0  4.9  15.0  48.0
# 150     614376  57.0   80.0  119.0   17.0  1.2  135.0  4.7  15.4  42.0
# 151     853426  41.0   70.0  125.0   38.0  0.6  140.0  5.0  16.8  41.0
# 152     572140  55.0   80.0  104.0   28.0  0.9  142.0  4.8  17.3  52.0
#
#         wbcc  rbcc   al   su  rbc_abnormal  rbc_normal  pc_abnormal  \
# 0    12400.0   3.9  4.0  0.0         False        True         True
# 1     7000.0   3.2  3.0  2.0          True       False         True
# 2    12100.0   3.7  2.0  0.0          True       False         True
# 3     9200.0   3.2  2.0  0.0          True       False         True
# 4    10500.0   4.1  2.0  0.0          True       False        False
# ..       ...   ...  ...  ...           ...         ...          ...
# 148   7000.0   5.3  0.0  0.0         False        True        False
# 149   7000.0   5.2  0.0  0.0         False        True        False
# 150   6200.0   6.2  0.0  0.0         False        True        False
# 151   6300.0   5.9  0.0  0.0         False        True        False
# 152   8200.0   4.8  0.0  0.0         False        True        False
#
#      pc_normal  pcc_notpresent  pcc_present  ba_notpresent  ba_present  \
# 0        False           False         True          False        True
# 1        False           False         True           True       False
# 2        False           False         True           True       False
# 3        False            True        False           True       False
# 4         True            True        False           True       False
# ..         ...             ...          ...            ...         ...
# 148       True            True        False           True       False
# 149       True            True        False           True       False
# 150       True            True        False           True       False
# 151       True            True        False           True       False
# 152       True            True        False           True       False
#
#      htn_no  htn_yes  dm_no  dm_yes  cad_no  cad_yes  appet_good  appet_poor  \
# 0      True    False   True   False    True    False        True       False
# 1     False     True  False    True   False     True       False        True
# 2     False     True  False    True    True    False       False        True
# 3     False     True  False    True   False     True       False        True
# 4      True    False   True   False    True    False        True       False
# ..      ...      ...    ...     ...     ...      ...         ...         ...
# 148    True    False   True   False    True    False        True       False
# 149    True    False   True   False    True    False        True       False
# 150    True    False   True   False    True    False        True       False
# 151    True    False   True   False    True    False        True       False
# 152    True    False   True   False    True    False        True       False
#
#      pe_no  pe_yes  ane_no  ane_yes  Target_ckd  Target_notckd
# 0     True   False   False     True        True          False
# 1     True   False    True    False        True          False
# 2     True   False   False     True        True          False
# 3    False    True   False     True        True          False
# 4     True   False    True    False        True          False
# ..     ...     ...     ...      ...         ...            ...
# 148   True   False    True    False       False           True
# 149   True   False    True    False       False           True
# 150   True   False    True    False       False           True
# 151   True   False    True    False       False           True
# 152   True   False    True    False       False           True
#
# [153 rows x 36 columns]

# %% [markdown]
# In the example we went through above, another solution is to have a single column for the binary variable. In the downstream modeling would this be equivalent? What effect would this have if the categorical variable could take more than 2 values? For example, let's say we have a categorical feature that is "type of condiment" that can take 5 separate values and we are trying to predict the rating of a particular sandwich.

# %% [markdown]
# Answer: If there are only two possibilities for values for a column, it would be possible to use a singular column with a binary variable instead. This is not the case for categorical variables with more than two values, as a binary value is a maximum of two, and won't be able to represent all possible values.

# %% [markdown]
# ## Part 3.6 : Remove Outliers from Numerical Columns
#
# Outliers can disproportionately influence the fit of a regression model, potentially leading to a model that does not generalize well therefore it is important that we remove outliers from the numerical columns of the dataset.
#
# For this dataset, we define an outlier to be 3 times the standard deviation from the mean. Drop these outliers from the dataset

# %%
# Remove outliers
numerical_columns = ['age', 'bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']
temp_df = df.loc[:, numerical_columns]
lim = np.abs((temp_df - temp_df.mean()) / temp_df.std(ddof=0)) < 3
df.loc[:, numerical_columns] = temp_df.where(lim, np.nan)
df = df.dropna(axis=0, how='any')
df = df.reset_index(drop=True)

# Print the dataset
display(df)
# Out:
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 1       137148  73.0  100.0  295.0   90.0  5.6  140.0  2.9   9.2  30.0
# 2       343710  61.0   80.0  173.0  148.0  3.9  135.0  5.2   7.7  24.0
# 3       532520  60.0   90.0  105.0   53.0  2.3  136.0  5.2  11.1  33.0
# 4       546225  46.0   60.0  163.0   92.0  3.3  141.0  4.0   9.8  28.0
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 129     647552  61.0   70.0  120.0   29.0  0.7  137.0  3.5  17.4  52.0
# 130     125587  37.0   60.0  109.0   47.0  1.1  141.0  4.9  15.0  48.0
# 131     614376  57.0   80.0  119.0   17.0  1.2  135.0  4.7  15.4  42.0
# 132     853426  41.0   70.0  125.0   38.0  0.6  140.0  5.0  16.8  41.0
# 133     572140  55.0   80.0  104.0   28.0  0.9  142.0  4.8  17.3  52.0
#
#         wbcc  rbcc   al   su       rbc        pc         pcc          ba  htn  \
# 0    12400.0   3.9  4.0  0.0    normal  abnormal     present     present   no
# 1     7000.0   3.2  3.0  2.0  abnormal  abnormal     present  notpresent  yes
# 2     9200.0   3.2  2.0  0.0  abnormal  abnormal  notpresent  notpresent  yes
# 3    10500.0   4.1  2.0  0.0  abnormal    normal  notpresent  notpresent   no
# 4    14600.0   3.2  1.0  0.0    normal    normal  notpresent  notpresent  yes
# ..       ...   ...  ...  ...       ...       ...         ...         ...  ...
# 129   7000.0   5.3  0.0  0.0    normal    normal  notpresent  notpresent   no
# 130   7000.0   5.2  0.0  0.0    normal    normal  notpresent  notpresent   no
# 131   6200.0   6.2  0.0  0.0    normal    normal  notpresent  notpresent   no
# 132   6300.0   5.9  0.0  0.0    normal    normal  notpresent  notpresent   no
# 133   8200.0   4.8  0.0  0.0    normal    normal  notpresent  notpresent   no
#
#       dm  cad appet   pe  ane  Target
# 0     no   no  good   no  yes     ckd
# 1    yes  yes  poor   no   no     ckd
# 2    yes  yes  poor  yes  yes     ckd
# 3     no   no  good   no   no     ckd
# 4    yes   no  good   no   no     ckd
# ..   ...  ...   ...  ...  ...     ...
# 129   no   no  good   no   no  notckd
# 130   no   no  good   no   no  notckd
# 131   no   no  good   no   no  notckd
# 132   no   no  good   no   no  notckd
# 133   no   no  good   no   no  notckd
#
# [134 rows x 25 columns]

# %% [markdown]
# ## Part 3.7 : Normalize the Numerical Columns
#
# Normalizing numerical attributes ensures that all features contribute equally to the model by scaling them to a consistent range, which improves model performance and convergence. It prevents features with larger scales from disproportionately influencing the model's learning process.

# %%
# Normalize the all Numerical Attributes in the dataset.
df_min_max_scaled = df
for column in numerical_columns:
    df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())
df = df_min_max_scaled
# Print the dataset
display(df)
# Out:
#      unique_id       age    bp       bgr        bu        sc       sod  \
# 0       474407  0.202703  0.75  0.158798  0.196078  0.160494  0.166667
# 1       137148  0.905405  1.00  0.965665  0.522876  0.641975  0.666667
# 2       343710  0.743243  0.50  0.442060  0.901961  0.432099  0.500000
# 3       532520  0.729730  0.75  0.150215  0.281046  0.234568  0.533333
# 4       546225  0.540541  0.00  0.399142  0.535948  0.358025  0.700000
# ..         ...       ...   ...       ...       ...       ...       ...
# 129     647552  0.743243  0.25  0.214592  0.124183  0.037037  0.566667
# 130     125587  0.418919  0.00  0.167382  0.241830  0.086420  0.700000
# 131     614376  0.689189  0.50  0.210300  0.045752  0.098765  0.500000
# 132     853426  0.472973  0.25  0.236052  0.183007  0.024691  0.666667
# 133     572140  0.662162  0.50  0.145923  0.117647  0.061728  0.733333
#
#           pot      hemo       pcv      wbcc      rbcc   al   su       rbc  \
# 0    0.171429  0.221311  0.184211  0.653226  0.333333  4.0  0.0    normal
# 1    0.000000  0.295082  0.368421  0.217742  0.153846  3.0  2.0  abnormal
# 2    0.657143  0.172131  0.210526  0.395161  0.153846  2.0  0.0  abnormal
# 3    0.657143  0.450820  0.447368  0.500000  0.384615  2.0  0.0  abnormal
# 4    0.314286  0.344262  0.315789  0.830645  0.153846  1.0  0.0    normal
# ..        ...       ...       ...       ...       ...  ...  ...       ...
# 129  0.171429  0.967213  0.947368  0.217742  0.692308  0.0  0.0    normal
# 130  0.571429  0.770492  0.842105  0.217742  0.666667  0.0  0.0    normal
# 131  0.514286  0.803279  0.684211  0.153226  0.923077  0.0  0.0    normal
# 132  0.600000  0.918033  0.657895  0.161290  0.846154  0.0  0.0    normal
# 133  0.542857  0.959016  0.947368  0.314516  0.564103  0.0  0.0    normal
#
#            pc         pcc          ba  htn   dm  cad appet   pe  ane  Target
# 0    abnormal     present     present   no   no   no  good   no  yes     ckd
# 1    abnormal     present  notpresent  yes  yes  yes  poor   no   no     ckd
# 2    abnormal  notpresent  notpresent  yes  yes  yes  poor  yes  yes     ckd
# 3      normal  notpresent  notpresent   no   no   no  good   no   no     ckd
# 4      normal  notpresent  notpresent  yes  yes   no  good   no   no     ckd
# ..        ...         ...         ...  ...  ...  ...   ...  ...  ...     ...
# 129    normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 130    normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 131    normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 132    normal  notpresent  notpresent   no   no   no  good   no   no  notckd
# 133    normal  notpresent  notpresent   no   no   no  good   no   no  notckd
#
# [134 rows x 25 columns]

# %% [markdown]
# ## Part 3.8: Remove Unnecessary columns

# %% [markdown]
# Are there any columns in this dataset which are not appropriate for modeling and predictions? Which column(s)? Justify their exclusion and remove them

# %% [markdown]
# Answer: Specific gravity is already removed, but it doesn't relate to either the patient's symptoms or any lab results. Appetite is a subjective term, and isn't super clear, so as a result is isn't really relevant in terms of predicting CKD in patients.

# %%
#Remove that column
df = df.drop(axis=1, columns=['appet'])
# Print the dataset
df
# Out:
#      unique_id       age    bp       bgr        bu        sc       sod  \
# 0       474407  0.202703  0.75  0.158798  0.196078  0.160494  0.166667
# 1       137148  0.905405  1.00  0.965665  0.522876  0.641975  0.666667
# 2       343710  0.743243  0.50  0.442060  0.901961  0.432099  0.500000
# 3       532520  0.729730  0.75  0.150215  0.281046  0.234568  0.533333
# 4       546225  0.540541  0.00  0.399142  0.535948  0.358025  0.700000
# ..         ...       ...   ...       ...       ...       ...       ...
# 129     647552  0.743243  0.25  0.214592  0.124183  0.037037  0.566667
# 130     125587  0.418919  0.00  0.167382  0.241830  0.086420  0.700000
# 131     614376  0.689189  0.50  0.210300  0.045752  0.098765  0.500000
# 132     853426  0.472973  0.25  0.236052  0.183007  0.024691  0.666667
# 133     572140  0.662162  0.50  0.145923  0.117647  0.061728  0.733333
#
#           pot      hemo       pcv      wbcc      rbcc   al   su       rbc  \
# 0    0.171429  0.221311  0.184211  0.653226  0.333333  4.0  0.0    normal
# 1    0.000000  0.295082  0.368421  0.217742  0.153846  3.0  2.0  abnormal
# 2    0.657143  0.172131  0.210526  0.395161  0.153846  2.0  0.0  abnormal
# 3    0.657143  0.450820  0.447368  0.500000  0.384615  2.0  0.0  abnormal
# 4    0.314286  0.344262  0.315789  0.830645  0.153846  1.0  0.0    normal
# ..        ...       ...       ...       ...       ...  ...  ...       ...
# 129  0.171429  0.967213  0.947368  0.217742  0.692308  0.0  0.0    normal
# 130  0.571429  0.770492  0.842105  0.217742  0.666667  0.0  0.0    normal
# 131  0.514286  0.803279  0.684211  0.153226  0.923077  0.0  0.0    normal
# 132  0.600000  0.918033  0.657895  0.161290  0.846154  0.0  0.0    normal
# 133  0.542857  0.959016  0.947368  0.314516  0.564103  0.0  0.0    normal
#
#            pc         pcc          ba  htn   dm  cad   pe  ane  Target
# 0    abnormal     present     present   no   no   no   no  yes     ckd
# 1    abnormal     present  notpresent  yes  yes  yes   no   no     ckd
# 2    abnormal  notpresent  notpresent  yes  yes  yes  yes  yes     ckd
# 3      normal  notpresent  notpresent   no   no   no   no   no     ckd
# 4      normal  notpresent  notpresent  yes  yes   no   no   no     ckd
# ..        ...         ...         ...  ...  ...  ...  ...  ...     ...
# 129    normal  notpresent  notpresent   no   no   no   no   no  notckd
# 130    normal  notpresent  notpresent   no   no   no   no   no  notckd
# 131    normal  notpresent  notpresent   no   no   no   no   no  notckd
# 132    normal  notpresent  notpresent   no   no   no   no   no  notckd
# 133    normal  notpresent  notpresent   no   no   no   no   no  notckd
#
# [134 rows x 24 columns]

# %% [markdown]
# ## Part 3.9: Export the Cleaned Data

# %% [markdown]
# Now that you've completed these cleaning steps you should have a pandas dataframe which is much cleaner and ready for modeling. Our final step is to save our work. Export the DataFrame to a two new formats: csv and json.

# %%
# Export the dataframe to a new csv file
df.to_csv("chronic_kidney_disease_cleaned.csv", index=False)
# Export the dataframe to a new json file
df.to_json("chronic_kidney_disease_cleaned.json", orient='index', indent=1)

# %% [markdown]
# # Part 4: Data conversions with Large Language Models
#
# One powerful use case of ChatGPT (and other generative language models) is cleaning and transforming data. In some cases, these models can directly manipulate loosely structured data that you provide to them into a standard format. In the other cases, you can often prompt the model to create a conversion or extraction script for you in python or Pandas and then run it on your own.
#
# In this part of the assignment you will prompt 383GPT to explore these capabilities.

# %% [markdown]
# ## Part 4.1 GPT Data Manipulation
#
# Take the cleaned dataset that you created in part three and output the top 15 rows of that dataset. Then copy the terminal output, open 383gpt and ask it to convert that output to a markdown table. Paste that markdown table in the cell bellow

# %%
first_fifteen = df.head(15)
first_fifteen.to_json("first_fifteen.json", orient='index')
first_fifteen
# Out:
#     unique_id       age    bp       bgr        bu        sc       sod  \
# 0      474407  0.202703  0.75  0.158798  0.196078  0.160494  0.166667
# 1      137148  0.905405  1.00  0.965665  0.522876  0.641975  0.666667
# 2      343710  0.743243  0.50  0.442060  0.901961  0.432099  0.500000
# 3      532520  0.729730  0.75  0.150215  0.281046  0.234568  0.533333
# 4      546225  0.540541  0.00  0.399142  0.535948  0.358025  0.700000
# 5      514721  0.675676  0.75  0.253219  0.633987  0.777778  0.366667
# 6      621332  0.716216  0.50  1.000000  0.163399  0.111111  0.066667
# 7      481293  0.729730  0.00  0.935622  0.169935  0.160494  0.333333
# 8      297893  0.837838  0.50  0.373391  0.522876  0.456790  0.333333
# 9      615697  0.000000  0.00  0.103004  0.372549  0.074074  0.500000
# 10     843362  0.878378  0.00  0.206009  0.751634  0.604938  0.533333
# 11     995177  0.851351  0.25  0.618026  0.562092  0.728395  0.000000
# 12     828592  0.878378  0.25  0.639485  0.470588  0.395062  0.433333
# 13     923613  0.783784  0.00  0.725322  0.313725  0.481481  0.566667
# 14     955830  0.662162  0.50  0.618026  0.411765  0.432099  0.566667
#
#          pot      hemo       pcv      wbcc      rbcc   al   su       rbc  \
# 0   0.171429  0.221311  0.184211  0.653226  0.333333  4.0  0.0    normal
# 1   0.000000  0.295082  0.368421  0.217742  0.153846  3.0  2.0  abnormal
# 2   0.657143  0.172131  0.210526  0.395161  0.153846  2.0  0.0  abnormal
# 3   0.657143  0.450820  0.447368  0.500000  0.384615  2.0  0.0  abnormal
# 4   0.314286  0.344262  0.315789  0.830645  0.153846  1.0  0.0    normal
# 5   0.542857  0.286885  0.342105  0.169355  0.205128  2.0  0.0  abnormal
# 6   0.171429  0.393443  0.500000  0.532258  0.435897  1.0  0.0  abnormal
# 7   0.028571  0.188525  0.236842  0.879032  0.102564  3.0  1.0    normal
# 8   1.000000  0.000000  0.000000  0.540323  0.000000  3.0  2.0    normal
# 9   0.571429  0.352459  0.368421  1.000000  0.564103  4.0  0.0  abnormal
# 10  0.571429  0.475410  0.500000  0.879032  0.435897  4.0  0.0    normal
# 11  0.285714  0.311475  0.315789  0.580645  0.179487  4.0  3.0    normal
# 12  0.428571  0.393443  0.447368  0.104839  0.256410  3.0  0.0    normal
# 13  0.714286  0.319672  0.342105  0.258065  0.205128  4.0  1.0  abnormal
# 14  0.571429  0.434426  0.473684  0.250000  0.282051  3.0  1.0    normal
#
#           pc         pcc          ba  htn   dm  cad   pe  ane Target
# 0   abnormal     present     present   no   no   no   no  yes    ckd
# 1   abnormal     present  notpresent  yes  yes  yes   no   no    ckd
# 2   abnormal  notpresent  notpresent  yes  yes  yes  yes  yes    ckd
# 3     normal  notpresent  notpresent   no   no   no   no   no    ckd
# 4     normal  notpresent  notpresent  yes  yes   no   no   no    ckd
# 5   abnormal  notpresent  notpresent  yes   no   no   no   no    ckd
# 6     normal  notpresent  notpresent   no  yes   no   no   no    ckd
# 7   abnormal     present  notpresent  yes   no   no   no  yes    ckd
# 8   abnormal     present     present  yes  yes  yes  yes   no    ckd
# 9   abnormal  notpresent     present   no   no   no   no   no    ckd
# 10    normal  notpresent  notpresent  yes  yes   no  yes   no    ckd
# 11  abnormal     present     present  yes  yes  yes  yes  yes    ckd
# 12  abnormal     present     present  yes  yes  yes   no   no    ckd
# 13  abnormal  notpresent     present  yes  yes   no  yes   no    ckd
# 14  abnormal     present     present  yes  yes   no  yes   no    ckd

# %% [markdown]
# ### Paste the markdown table here

# %% [markdown]
# |unique_id| age         | bp   | bgr         | bu          | sc          | sod         | pot         | hemo        | pcv         | wbcc        | rbcc        | al | su | rbc      | pc       | pcc         | ba         | htn | dm  | cad | pe  | ane | Target |
# |-----------|-------------|------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|-------------|----|----|----------|----------|-------------|------------|-----|-----|-----|-----|-----|--------|
# |474407| 0.2027|0.75|0.1588| 0.1961      | 0.1605      | 0.1667      | 0.1714      | 0.2213      | 0.1842      | 0.6532      | 0.3333      | 4  | 0  | normal   | abnormal | present     | present    | no  | no  | no  | no  | yes | ckd    |
# | 137148    | 0.9054     | 1.0  | 0.9657      | 0.5229      | 0.6420      | 0.6667      | 0.0         | 0.2951      | 0.3684      | 0.2177      | 0.1538      | 3  | 2  | abnormal | abnormal | present     | notpresent | yes | yes | yes | no  | no  | ckd    |
# | 343710    | 0.7432     | 0.5  | 0.4421      | 0.9020      | 0.4321      | 0.5         | 0.6571      | 0.1721      | 0.2105      | 0.3952      | 0.1538      | 2  | 0  | abnormal | abnormal | notpresent  | notpresent | yes | yes | yes | yes | yes | ckd    |
# | 532520    | 0.7297     | 0.75 | 0.1502      | 0.2810      | 0.2346      | 0.5333      | 0.6571      | 0.4508      | 0.4474      | 0.5         | 0.3846      | 2  | 0  | abnormal | normal   | notpresent  | notpresent | no  | no  | no  | no  | no  | ckd    |
# | 546225    | 0.5405     | 0.0  | 0.3991      | 0.5359      | 0.3580      | 0.7         | 0.3143      | 0.3443      | 0.3158      | 0.8306      | 0.1538      | 1  | 0  | normal   | normal   | notpresent  | notpresent | yes | yes | no  | no  | no  | ckd    |
# | 514721    | 0.6757     | 0.75 | 0.2532      | 0.6340      | 0.7778      | 0.3667      | 0.5429      | 0.2869      | 0.3421      | 0.1694      | 0.2051      | 2  | 0  | abnormal | abnormal | notpresent  | notpresent | yes | no  | no  | no  | no  | ckd    |
# | 621332    | 0.7162     | 0.5  | 1.0         | 0.1634      | 0.1111      | 0.0667      | 0.1714      | 0.3934      | 0.5         | 0.5323      | 0.4359      | 1  | 0  | abnormal | normal   | notpresent  | notpresent | no  | yes | no  | no  | no  | ckd    |
# | 481293    | 0.7297     | 0.0  | 0.9356      | 0.1699      | 0.1605      | 0.3333      | 0.0286      | 0.1885      | 0.2368      | 0.8790      | 0.1026      | 3  | 1  | normal   | abnormal | present     | notpresent | yes | no  | no  | no  | yes | ckd    |
# | 297893    | 0.8378     | 0.5  | 0.3734      | 0.5229      | 0.4568      | 0.3333      | 1.0         | 0.0         | 0.0         | 0.5403      | 0.0         | 3  | 2  | normal   | abnormal | present     | present    | yes | yes | yes | yes | no  | ckd    |
# | 615697    | 0.0       | 0.0  | 0.1030      | 0.3725      | 0.0741      | 0.5         | 0.5714      | 0.3525      | 0.3684      | 1.0         | 0.5641      | 4  | 0  | abnormal | abnormal | notpresent  | present    | no  | no  | no  | no  | no  | ckd    |
# | 843362    | 0.8784     | 0.0  | 0.2060      | 0.7516      | 0.6049      | 0.5333      | 0.5714      | 0.4754      | 0.5         | 0.8790      | 0.4359      | 4  | 0  | normal   | normal   | notpresent  | notpresent | yes | yes | no  | yes | no  | ckd    |
# | 995177    | 0.8514     | 0.25 | 0.6180      | 0.5621      | 0.7284      | 0.0         | 0.2857      | 0.3115      | 0.3158      | 0.5806      | 0.1795      | 4  | 3  | normal   | abnormal | present     | present    | yes | yes | yes | yes | yes | ckd    |
# | 828592    | 0.8784     | 0.25 | 0.6395      | 0.4706      | 0.3951      | 0.4333      | 0.4286      | 0.3934      | 0.4474      | 0.1048      | 0.2564      | 3  | 0  | normal   | abnormal | present     | present    | yes | yes | yes | no  | no  | ckd    |
# | 923613    | 0.7838     | 0.0  | 0.7253      | 0.3137      | 0.4815      | 0.5667      | 0.7143      | 0.3197      | 0.3421      | 0.2581      | 0.2051      | 4  | 1  | abnormal | abnormal | notpresent  | present    | yes | yes | no  | yes | no  | ckd    |
# | 955830    | 0.6622     | 0.5  | 0.6180      | 0.4118      | 0.4321      | 0.5667      | 0.5714      | 0.4344      | 0.4737      | 0.25        | 0.2821      | 3  | 1  | normal   | abnormal | present     | present    | yes | yes | no  | yes | no  | ckd    |

# %% [markdown]
# ** Caution: ** while language models can perform data conversions they also can * hallucinate * during this process, particularly for bigger datasets. Reflect on this below, how could you mitigate data conversion hallucinations from LLM conversions?
#
# One way to mitigate data conversion hallucinations would be to convert one column at a time to reduce the amount of data being converted at once.

# %% [markdown]
# ## Part 4.2 GPT Pandas Prompting
#
# In this section, you will prompt 383GPT to write pandas code manipulations for you.
#
# After working with this data for awhile, we realized we're starting to forget the meanings of the abbreviated column names. Let's ask 383GPT to fix this for us. First, navigate to the [UCI dataset overview](https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease) and copy the abbrevation to name mapping. Then, go to 383GPT and instruct the LLM to provide you with a pandas script to apply this renaming to all the columns of your dataset. Paste that code below and make any adjustments necessary to run it in your notebook.

# %%
# Code to rename all the columns in the dataset

# Create a mapping dictionary for column name conversions
column_mapping = {
    'age': 'age',
    'bp': 'blood pressure',
    'al': 'albumin',
    'su': 'sugar',
    'rbc': 'red blood cells',
    'pc': 'pus cell',
    'pcc': 'pus cell clumps',
    'ba': 'bacteria',
    'bgr': 'blood glucose random',
    'bu': 'blood urea',
    'sc': 'serum creatinine',
    'sod': 'sodium',
    'pot': 'potassium',
    'hemo': 'hemoglobin',
    'pcv': 'packed cell volume',
    'wc': 'white blood cell count',
    'rc': 'red blood cell count',
    'htn': 'hypertension',
    'dm': 'diabetes mellitus',
    'cad': 'coronary artery disease',
    'appet': 'appetite',
    'pe': 'pedal edema',
    'ane': 'anemia'
}

# Rename the columns using the mapping
df.rename(columns=column_mapping, inplace=True)

# Display the updated DataFrame
df
# Out:
#      unique_id       age  blood pressure  blood glucose random  blood urea  \
# 0       474407  0.202703            0.75              0.158798    0.196078
# 1       137148  0.905405            1.00              0.965665    0.522876
# 2       343710  0.743243            0.50              0.442060    0.901961
# 3       532520  0.729730            0.75              0.150215    0.281046
# 4       546225  0.540541            0.00              0.399142    0.535948
# ..         ...       ...             ...                   ...         ...
# 129     647552  0.743243            0.25              0.214592    0.124183
# 130     125587  0.418919            0.00              0.167382    0.241830
# 131     614376  0.689189            0.50              0.210300    0.045752
# 132     853426  0.472973            0.25              0.236052    0.183007
# 133     572140  0.662162            0.50              0.145923    0.117647
#
#      serum creatinine    sodium  potassium  hemoglobin  packed cell volume  \
# 0            0.160494  0.166667   0.171429    0.221311            0.184211
# 1            0.641975  0.666667   0.000000    0.295082            0.368421
# 2            0.432099  0.500000   0.657143    0.172131            0.210526
# 3            0.234568  0.533333   0.657143    0.450820            0.447368
# 4            0.358025  0.700000   0.314286    0.344262            0.315789
# ..                ...       ...        ...         ...                 ...
# 129          0.037037  0.566667   0.171429    0.967213            0.947368
# 130          0.086420  0.700000   0.571429    0.770492            0.842105
# 131          0.098765  0.500000   0.514286    0.803279            0.684211
# 132          0.024691  0.666667   0.600000    0.918033            0.657895
# 133          0.061728  0.733333   0.542857    0.959016            0.947368
#
#          wbcc      rbcc  albumin  sugar red blood cells  pus cell  \
# 0    0.653226  0.333333      4.0    0.0          normal  abnormal
# 1    0.217742  0.153846      3.0    2.0        abnormal  abnormal
# 2    0.395161  0.153846      2.0    0.0        abnormal  abnormal
# 3    0.500000  0.384615      2.0    0.0        abnormal    normal
# 4    0.830645  0.153846      1.0    0.0          normal    normal
# ..        ...       ...      ...    ...             ...       ...
# 129  0.217742  0.692308      0.0    0.0          normal    normal
# 130  0.217742  0.666667      0.0    0.0          normal    normal
# 131  0.153226  0.923077      0.0    0.0          normal    normal
# 132  0.161290  0.846154      0.0    0.0          normal    normal
# 133  0.314516  0.564103      0.0    0.0          normal    normal
#
#     pus cell clumps    bacteria hypertension diabetes mellitus  \
# 0           present     present           no                no
# 1           present  notpresent          yes               yes
# 2        notpresent  notpresent          yes               yes
# 3        notpresent  notpresent           no                no
# 4        notpresent  notpresent          yes               yes
# ..              ...         ...          ...               ...
# 129      notpresent  notpresent           no                no
# 130      notpresent  notpresent           no                no
# 131      notpresent  notpresent           no                no
# 132      notpresent  notpresent           no                no
# 133      notpresent  notpresent           no                no
#
#     coronary artery disease pedal edema anemia  Target
# 0                        no          no    yes     ckd
# 1                       yes          no     no     ckd
# 2                       yes         yes    yes     ckd
# 3                        no          no     no     ckd
# 4                        no          no     no     ckd
# ..                      ...         ...    ...     ...
# 129                      no          no     no  notckd
# 130                      no          no     no  notckd
# 131                      no          no     no  notckd
# 132                      no          no     no  notckd
# 133                      no          no     no  notckd
#
# [134 rows x 24 columns]

# %% [markdown]
# ## Part 4.3 Augmenting our skills with prompting
#
# In addition, we can also use 383GPT to convert our data manipulation operations between different data manipulation languages and libraries. For example let's prompt 383GPT to convert the following SQL query to a pandas query.
#
# **SQL Query**
# ```sql
# SELECT Target, COUNT(*) AS count
# FROM your_table_name
# GROUP BY Target;
# ```
#
# Prompt 383GPT to convert this to a pandas query. Run this query below, then describe what it does. (If you're not familiar with SQL that is okay you need to only comment on the final resulting output.)

# %%
# Converted SQL to Pandas code
result = df.groupby('Target').count().reset_index()
result
# Out:
#    Target  unique_id  age  blood pressure  blood glucose random  blood urea  \
# 0     ckd         23   23              23                    23          23
# 1  notckd        111  111             111                   111         111
#
#    serum creatinine  sodium  potassium  hemoglobin  packed cell volume  wbcc  \
# 0                23      23         23          23                  23    23
# 1               111     111        111         111                 111   111
#
#    rbcc  albumin  sugar  red blood cells  pus cell  pus cell clumps  bacteria  \
# 0    23       23     23               23        23               23        23
# 1   111      111    111              111       111              111       111
#
#    hypertension  diabetes mellitus  coronary artery disease  pedal edema  \
# 0            23                 23                       23           23
# 1           111                111                      111          111
#
#    anemia
# 0      23
# 1     111

# %% [markdown]
# *Describe what the above code does here*
#
# The above code converts the dataframe from each row representing a different patient to a new dataframe that represents the distribution of each feature between patients with CKD and patients without CKD.

# %%
# Imports and pip installations (if needed)

import pandas as pandas

# %% [markdown]
# # Part 1: Load the dataset

# %%
# Load the given datasets
numerical = pandas.read_csv('./chronic_kidney_disease_numerical.csv')
categorical = pandas.read_csv('./chronic_kidney_disease_categorical.csv')

# Print the data
print(numerical)
print(categorical)
# Out:
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       203694  38.0   80.0   99.0   19.0  0.5  147.0  3.5  13.6  44.0
# 1       938027  43.0   60.0  108.0   25.0  1.0  144.0  5.0  17.8  43.0
# 2       421471  37.0   60.0  111.0   35.0  0.8  135.0  4.1  16.2  50.0
# 3       764115  70.0   90.0  144.0  125.0  4.0  136.0  4.6  12.0  37.0
# 4       240975  47.0   80.0   95.0   35.0  0.9  140.0  4.1   NaN   NaN
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 415     522912  56.0   80.0  165.0   55.0  1.8    NaN  NaN  13.5  40.0
# 416     475200  64.0  100.0  163.0   54.0  7.2  140.0  4.6   7.9  26.0
# 417     168242  48.0   60.0  112.0   44.0  1.2  142.0  4.9  14.5  44.0
# 418     474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 419     926033  50.0   70.0  230.0   50.0  2.2    NaN  NaN  12.0  41.0
#
#         wbcc  rbcc
# 0     7300.0   6.4
# 1     7200.0   5.5
# 2     5500.0   5.7
# 3     8200.0   4.5
# 4        NaN   NaN
# ..       ...   ...
# 415  11800.0   5.0
# 416   7500.0   3.4
# 417   9400.0   6.4
# 418  12400.0   3.9
# 419  10400.0   4.6
#
# [420 rows x 12 columns]
#      unique_id   al   su       rbc        pc         pcc          ba  htn  \
# 0       224481  3.0  NaN       NaN       NaN  notpresent  notpresent  yes
# 1       992643  0.0  0.0       NaN       NaN  notpresent  notpresent   no
# 2       308740  1.0  0.0  abnormal  abnormal  notpresent  notpresent  yes
# 3       450314  1.0  0.0       NaN    normal  notpresent  notpresent   no
# 4       881763  0.0  0.0    normal    normal  notpresent  notpresent   no
# ..         ...  ...  ...       ...       ...         ...         ...  ...
# 425     769512  0.0  0.0    normal    normal  notpresent  notpresent   no
# 426     872034  2.0  1.0  abnormal  abnormal  notpresent     present  yes
# 427     643007  NaN  NaN       NaN    normal  notpresent  notpresent  yes
# 428     840392  NaN  NaN       NaN       NaN  notpresent  notpresent  yes
# 429     856244  0.0  0.0       NaN    normal  notpresent  notpresent  yes
#
#       dm  cad appet   pe  ane  Target
# 0    yes   no  good  yes   no     ckd
# 1     no   no  good   no   no  notckd
# 2     no   no  good  yes   no     ckd
# 3     no   no  good   no  yes     ckd
# 4     no   no  good   no   no  notckd
# ..   ...  ...   ...  ...  ...     ...
# 425   no   no  good   no   no  notckd
# 426  yes  yes  poor   no   no     ckd
# 427  yes  yes  poor   no   no     ckd
# 428   no   no  poor   no   no     ckd
# 429  yes   no  poor   no   no     ckd
#
# [430 rows x 14 columns]

# %% [markdown]
# # Part 2: Analyze the Dataset

# %% [markdown]
# Refer to this: https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease
#
# Explain what the each data is in your own words. What are the features and labels? Are the features in the given datasets : categorical, numerical or both? Give 3 examples of categorical and numerical columns each (if they exist)

# %% [markdown]
# Answer: The data's features are the 24 different features that are medical information about the patients from their blood. The labels are whether they have chronic kidney disease or not. The features in the datasets are both categorical and numerical (some are categorical and some are numerical). Three examples of the categorical columns are specific gravity, albumin, and sugar. Three examples of the numerical columns are blood pressure, blood glucose random, and blood urea.

# %% [markdown]
# # Part 3: Data Preprocessing
#
# A fundamental skill in Machine Learning is mastering the art of data cleaning and preprocessing. In this assignment, you will learn and apply essential data cleaning techniques to transform a raw dataset into a clean, ready-to-use form which you can use for regression or classification tasks. By the end of this assignment, you'll have a fully clean dataset and a solid foundation in preparing data for various machine learning models.

# %% [markdown]
# ## Part 3.1 : Drop Duplicate rows
#
# Let's start by checking if the given datasets have any duplicate rows (same Unique Id). Use pandas to identify and remove these duplicate rows from the given dataset

# %%
# For the numerical dataset, check if there are duplicate rows in the dataset. If yes, print total number of duplicate rows
num_duplicates = numerical[numerical.duplicated(subset='unique_id', keep=False)]
if(num_duplicates.shape[0]>0):
    print(num_duplicates.shape[0])

# Drop these duplicate rows
numerical_dropped = numerical.drop_duplicates(subset='unique_id',keep='first')

# Repeat the same for categorical dataset. Print the duplicate rows and drop them
cat_duplicates = categorical[categorical.duplicated(subset='unique_id',keep=False)]
if(cat_duplicates.shape[0]>0):
    print(cat_duplicates.shape[0])

categorical_dropped = categorical.drop_duplicates(subset='unique_id',keep='first')

#NOTE: number of duplicates includes the original ones that were duplicated. 
print(numerical_dropped)
print(categorical_dropped)
# Out:
# 59
# 59
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       203694  38.0   80.0   99.0   19.0  0.5  147.0  3.5  13.6  44.0
# 1       938027  43.0   60.0  108.0   25.0  1.0  144.0  5.0  17.8  43.0
# 2       421471  37.0   60.0  111.0   35.0  0.8  135.0  4.1  16.2  50.0
# 3       764115  70.0   90.0  144.0  125.0  4.0  136.0  4.6  12.0  37.0
# 4       240975  47.0   80.0   95.0   35.0  0.9  140.0  4.1   NaN   NaN
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 415     522912  56.0   80.0  165.0   55.0  1.8    NaN  NaN  13.5  40.0
# 416     475200  64.0  100.0  163.0   54.0  7.2  140.0  4.6   7.9  26.0
# 417     168242  48.0   60.0  112.0   44.0  1.2  142.0  4.9  14.5  44.0
# 418     474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 419     926033  50.0   70.0  230.0   50.0  2.2    NaN  NaN  12.0  41.0
#
#         wbcc  rbcc
# 0     7300.0   6.4
# 1     7200.0   5.5
# 2     5500.0   5.7
# 3     8200.0   4.5
# 4        NaN   NaN
# ..       ...   ...
# 415  11800.0   5.0
# 416   7500.0   3.4
# 417   9400.0   6.4
# 418  12400.0   3.9
# 419  10400.0   4.6
#
# [390 rows x 12 columns]
#      unique_id   al   su       rbc        pc         pcc          ba  htn  \
# 0       224481  3.0  NaN       NaN       NaN  notpresent  notpresent  yes
# 1       992643  0.0  0.0       NaN       NaN  notpresent  notpresent   no
# 2       308740  1.0  0.0  abnormal  abnormal  notpresent  notpresent  yes
# 3       450314  1.0  0.0       NaN    normal  notpresent  notpresent   no
# 4       881763  0.0  0.0    normal    normal  notpresent  notpresent   no
# ..         ...  ...  ...       ...       ...         ...         ...  ...
# 396     789906  0.0  0.0    normal    normal  notpresent  notpresent   no
# 397     490253  0.0  0.0    normal    normal  notpresent  notpresent   no
# 398     492993  3.0  0.0       NaN    normal  notpresent  notpresent  yes
# 399     273038  0.0  0.0    normal    normal  notpresent  notpresent   no
# 400     583971  1.0  0.0       NaN    normal  notpresent  notpresent  yes
#
#       dm cad appet   pe  ane  Target
# 0    yes  no  good  yes   no     ckd
# 1     no  no  good   no   no  notckd
# 2     no  no  good  yes   no     ckd
# 3     no  no  good   no  yes     ckd
# 4     no  no  good   no   no  notckd
# ..   ...  ..   ...  ...  ...     ...
# 396   no  no  good   no   no  notckd
# 397   no  no  good   no   no  notckd
# 398   no  no  good   no  yes     ckd
# 399   no  no  good   no   no  notckd
# 400   no  no  good  yes  yes     ckd
#
# [400 rows x 14 columns]

# %% [markdown]
# ## Part 3.2: Combine two differents datasets
#
# A good skill to have is to know how to combine 2 different datasets.
#
# Are all the unique ids are present in both datasets? Why do you think so? If not, what do the rows that are missing from one of the datasets look like in the combined table?

# %% [markdown]
# Answer: I don't think so, because both of them are different lengths (one is 421, one is 431) and we know that they both have 59 duplicates. In the combined table, we would just have those rows with some missing column data (only have the categorical data for 10 of the rows).

# %%
# Merge the two given numerical and categorical datasets based on their unique_ID.
merged = categorical_dropped.merge(numerical_dropped, how='outer')
#merged = pandas.merge(numerical_dropped, categorical_dropped, on='unique_id')


#Print the combined dataset
print(merged)
# Out:
#      unique_id   al   su     rbc        pc         pcc          ba  htn   dm  \
# 0       102677  3.0  0.0  normal  abnormal  notpresent  notpresent  yes   no
# 1       103570  0.0  0.0  normal    normal  notpresent  notpresent   no   no
# 2       104675  2.0  1.0  normal    normal     present  notpresent   no  yes
# 3       105923  1.0  0.0     NaN    normal  notpresent  notpresent  yes  yes
# 4       107297  0.0  0.0  normal    normal  notpresent  notpresent   no   no
# ..         ...  ...  ...     ...       ...         ...         ...  ...  ...
# 395     995177  4.0  3.0  normal  abnormal     present     present  yes  yes
# 396     996076  0.0  0.0  normal    normal  notpresent  notpresent   no   no
# 397     996412  NaN  NaN     NaN       NaN  notpresent  notpresent   no   no
# 398     997629  0.0  0.0  normal    normal         NaN         NaN   no   no
# 399     997876  0.0  0.0     NaN    normal  notpresent  notpresent   no   no
#
#      cad  ...    bp    bgr     bu    sc    sod  pot  hemo   pcv     wbcc  rbcc
# 0     no  ...  70.0   76.0  186.0  15.0  135.0  7.6   7.1  22.0   3800.0   2.1
# 1     no  ...  80.0  125.0    NaN   NaN  136.0  3.5  15.4  43.0   5600.0   4.5
# 2     no  ...  80.0  215.0  133.0   2.5    NaN  NaN  13.2  41.0      NaN   NaN
# 3     no  ...  90.0  139.0   89.0   3.0  140.0  4.1  12.0  37.0   7900.0   3.9
# 4     no  ...  70.0    NaN    NaN   NaN    NaN  NaN  16.4  43.0  10800.0   5.7
# ..   ...  ...   ...    ...    ...   ...    ...  ...   ...   ...      ...   ...
# 395  yes  ...  70.0  214.0   96.0   6.3  120.0  3.9   9.4  28.0  11500.0   3.3
# 396   no  ...  60.0  105.0   49.0   1.2  150.0  4.7  15.7  44.0  10400.0   6.2
# 397   no  ...  60.0  120.0   40.0   0.5  140.0  4.6  16.0  43.0   4500.0   4.9
# 398   no  ...   NaN   99.0   30.0   0.5  135.0  4.9  15.4  48.0   5000.0   5.2
# 399   no  ...  70.0  107.0   15.0   NaN    NaN  NaN  12.8  38.0      NaN   NaN
#
# [400 rows x 25 columns]

# %% [markdown]
# ## Part 3.3: Rows with Missing values
#
# Removing missing values from a dataset is important for classification because it ensures the model is trained on complete and accurate data, leading to better performance and reliable predictions. Incomplete data can introduce bias and errors, negatively impacting the model's effectiveness.

# %%
# Calculate the percentage of rows that contain atleast one missing value
percentage_missing = merged.isnull().any(axis=1).mean() * 100


# Print %
print(percentage_missing)

# Drop these rows from the dataset
merged_dropped = merged.dropna()

# Print the Dataset
print(merged_dropped)
# Out:
# 61.75000000000001
#      unique_id   al   su     rbc        pc         pcc          ba  htn   dm  \
# 0       102677  3.0  0.0  normal  abnormal  notpresent  notpresent  yes   no
# 6       109053  0.0  0.0  normal    normal  notpresent  notpresent   no   no
# 7       114717  0.0  0.0  normal    normal  notpresent  notpresent   no   no
# 8       118191  0.0  0.0  normal    normal  notpresent  notpresent   no   no
# 9       118596  0.0  0.0  normal    normal  notpresent  notpresent   no   no
# ..         ...  ...  ...     ...       ...         ...         ...  ...  ...
# 390     980291  3.0  0.0  normal  abnormal  notpresent  notpresent  yes  yes
# 391     991031  0.0  0.0  normal    normal  notpresent  notpresent   no   no
# 394     994377  0.0  0.0  normal    normal  notpresent  notpresent   no   no
# 395     995177  4.0  3.0  normal  abnormal     present     present  yes  yes
# 396     996076  0.0  0.0  normal    normal  notpresent  notpresent   no   no
#
#      cad  ...    bp    bgr     bu    sc    sod  pot  hemo   pcv     wbcc  rbcc
# 0     no  ...  70.0   76.0  186.0  15.0  135.0  7.6   7.1  22.0   3800.0   2.1
# 6     no  ...  60.0  106.0   27.0   0.7  150.0  3.3  14.4  42.0   8100.0   4.7
# 7     no  ...  80.0  122.0   25.0   0.8  138.0  5.0  17.1  41.0   9100.0   5.2
# 8     no  ...  70.0   93.0   32.0   0.9  143.0  4.7  16.6  43.0   7100.0   5.3
# 9     no  ...  60.0   88.0   50.0   0.6  147.0  3.7  17.2  53.0   6000.0   4.5
# ..   ...  ...   ...    ...    ...   ...    ...  ...   ...   ...      ...   ...
# 390   no  ...  70.0  122.0   42.0   1.7  136.0  4.7  12.6  39.0   7900.0   3.9
# 391   no  ...  80.0   89.0   42.0   0.5  139.0  5.0  16.7  52.0  10200.0   5.0
# 394   no  ...  70.0   81.0   18.0   0.8  145.0  5.0  14.7  44.0   9800.0   6.0
# 395  yes  ...  70.0  214.0   96.0   6.3  120.0  3.9   9.4  28.0  11500.0   3.3
# 396   no  ...  60.0  105.0   49.0   1.2  150.0  4.7  15.7  44.0  10400.0   6.2
#
# [153 rows x 25 columns]

# %% [markdown]
# ## Part 3.4: Sort the dataset according to the Labels

# %%
# Sort the dataset according to the values in 'Target' column. Make sure reset the indices after sorting
print(merged_dropped.columns.tolist()) 

merged_sorted = merged_dropped.sort_values(by='Target')  
merged_sorted.reset_index(drop=True, inplace=True) 

# Print the dataset
print(merged_sorted)
# Out:
# ['unique_id', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'Target', 'age', 'bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']
#      unique_id   al   su       rbc        pc         pcc          ba  htn  \
# 0       102677  3.0  0.0    normal  abnormal  notpresent  notpresent  yes
# 1       337834  4.0  0.0    normal  abnormal     present  notpresent  yes
# 2       343710  2.0  0.0  abnormal  abnormal  notpresent  notpresent  yes
# 3       349892  1.0  3.0  abnormal  abnormal  notpresent  notpresent  yes
# 4       353025  3.0  4.0    normal    normal  notpresent  notpresent  yes
# ..         ...  ...  ...       ...       ...         ...         ...  ...
# 148     486397  0.0  0.0    normal    normal  notpresent  notpresent   no
# 149     203466  0.0  0.0    normal    normal  notpresent  notpresent   no
# 150     482105  0.0  0.0    normal    normal  notpresent  notpresent   no
# 151     228849  0.0  0.0    normal    normal  notpresent  notpresent   no
# 152     996076  0.0  0.0    normal    normal  notpresent  notpresent   no
#
#       dm  cad  ...    bp    bgr     bu    sc    sod  pot  hemo   pcv     wbcc  \
# 0     no   no  ...  70.0   76.0  186.0  15.0  135.0  7.6   7.1  22.0   3800.0
# 1     no   no  ...  70.0  117.0   56.0   3.8  111.0  2.5  11.2  32.0   6700.0
# 2    yes  yes  ...  80.0  173.0  148.0   3.9  135.0  5.2   7.7  24.0   9200.0
# 3    yes  yes  ...  70.0  424.0   55.0   1.7  138.0  4.5  12.6  37.0  10200.0
# 4    yes   no  ...  70.0  253.0  150.0  11.9  132.0  5.6  10.9  31.0   8800.0
# ..   ...  ...  ...   ...    ...    ...   ...    ...  ...   ...   ...      ...
# 148   no   no  ...  70.0  123.0   44.0   1.0  135.0  3.8  14.6  44.0   5500.0
# 149   no   no  ...  60.0   97.0   18.0   1.2  138.0  4.3  13.5  42.0   7900.0
# 150   no   no  ...  60.0   95.0   46.0   0.5  138.0  4.2  15.0  50.0   7700.0
# 151   no   no  ...  80.0  100.0   50.0   1.2  140.0  3.5  14.0  50.0   6700.0
# 152   no   no  ...  60.0  105.0   49.0   1.2  150.0  4.7  15.7  44.0  10400.0
#
#      rbcc
# 0     2.1
# 1     3.9
# 2     3.2
# 3     4.1
# 4     3.4
# ..    ...
# 148   4.8
# 149   6.4
# 150   6.3
# 151   6.5
# 152   6.2
#
# [153 rows x 25 columns]

# %% [markdown]
# ## Part 3.5: Encoding Categorical data
#
# In this step, we identify and process the categorical columns in the sorted dataset. We map each unique value in these columns to separate "dummy" columns.
#
# For example, the column 'rbc' will be transformed into two columns 'rbc_normal' and 'rbc_abnormal'. If a row's value in 'rbc' is 'normal', the 'rbc_normal' column will be set to 1 and 'rbc_abnormal' will be set to 0.
#
#
# **Note: Find a correct pandas function to do this **

# %%
# Write code here
categorical_columns = ['rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'Target']
df = pandas.get_dummies(merged_sorted, prefix=categorical_columns, columns=categorical_columns)

# for column in categorical_columns:
#     dummies = pandas.get_dummies(merged_sorted[column], prefix=column, drop_first=False)
#     df = pandas.concat([merged_sorted, dummies], axis=1)


# Print the dataset
print(df)
# Out:
#      unique_id   al   su   age    bp    bgr     bu    sc    sod  pot  ...  \
# 0       102677  3.0  0.0  59.0  70.0   76.0  186.0  15.0  135.0  7.6  ...
# 1       337834  4.0  0.0  48.0  70.0  117.0   56.0   3.8  111.0  2.5  ...
# 2       343710  2.0  0.0  61.0  80.0  173.0  148.0   3.9  135.0  5.2  ...
# 3       349892  1.0  3.0  59.0  70.0  424.0   55.0   1.7  138.0  4.5  ...
# 4       353025  3.0  4.0  40.0  70.0  253.0  150.0  11.9  132.0  5.6  ...
# ..         ...  ...  ...   ...   ...    ...    ...   ...    ...  ...  ...
# 148     486397  0.0  0.0  20.0  70.0  123.0   44.0   1.0  135.0  3.8  ...
# 149     203466  0.0  0.0  22.0  60.0   97.0   18.0   1.2  138.0  4.3  ...
# 150     482105  0.0  0.0  44.0  60.0   95.0   46.0   0.5  138.0  4.2  ...
# 151     228849  0.0  0.0  58.0  80.0  100.0   50.0   1.2  140.0  3.5  ...
# 152     996076  0.0  0.0  57.0  60.0  105.0   49.0   1.2  150.0  4.7  ...
#
#      cad_no  cad_yes  appet_good  appet_poor  pe_no  pe_yes  ane_no  ane_yes  \
# 0      True    False       False        True  False    True   False     True
# 1      True    False       False        True  False    True   False     True
# 2     False     True       False        True  False    True   False     True
# 3     False     True        True       False   True   False    True    False
# 4      True    False       False        True  False    True    True    False
# ..      ...      ...         ...         ...    ...     ...     ...      ...
# 148    True    False        True       False   True   False    True    False
# 149    True    False        True       False   True   False    True    False
# 150    True    False        True       False   True   False    True    False
# 151    True    False        True       False   True   False    True    False
# 152    True    False        True       False   True   False    True    False
#
#      Target_ckd  Target_notckd
# 0          True          False
# 1          True          False
# 2          True          False
# 3          True          False
# 4          True          False
# ..          ...            ...
# 148       False           True
# 149       False           True
# 150       False           True
# 151       False           True
# 152       False           True
#
# [153 rows x 36 columns]

# %% [markdown]
# In the example we went through above, another solution is to have a single column for the binary variable. In the downstream modeling would this be equivalent? What effect would this have if the categorical variable could take more than 2 values? For example, let's say we have a categorical feature that is "type of condiment" that can take 5 separate values and we are trying to predict the rating of a particular sandwich.

# %% [markdown]
# ## Part 3.6 : Remove Outliers from Numerical Columns
#
# Outliers can disproportionately influence the fit of a regression model, potentially leading to a model that does not generalize well therefore it is important that we remove outliers from the numerical columns of the dataset.
#
# For this dataset, we define an outlier to be 3 times the standard deviation from the mean. Drop these outliers from the dataset

# %%
# Remove outliers
numerical_columns = ['age', 'bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']
print(df)
# Identify and drop outliers
for column in numerical_columns:
    mean = df[column].mean()
    std_dev = df[column].std()
    
    # Define the upper and lower bounds for outliers
    lower_bound = mean - 3 * std_dev
    upper_bound = mean + 3 * std_dev
    
    # Filter out outliers
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]


# Print the dataset
print(df)
# Out:
#      unique_id   al   su   age    bp    bgr     bu    sc    sod  pot  ...  \
# 0       102677  3.0  0.0  59.0  70.0   76.0  186.0  15.0  135.0  7.6  ...
# 1       337834  4.0  0.0  48.0  70.0  117.0   56.0   3.8  111.0  2.5  ...
# 2       343710  2.0  0.0  61.0  80.0  173.0  148.0   3.9  135.0  5.2  ...
# 3       349892  1.0  3.0  59.0  70.0  424.0   55.0   1.7  138.0  4.5  ...
# 4       353025  3.0  4.0  40.0  70.0  253.0  150.0  11.9  132.0  5.6  ...
# ..         ...  ...  ...   ...   ...    ...    ...   ...    ...  ...  ...
# 148     486397  0.0  0.0  20.0  70.0  123.0   44.0   1.0  135.0  3.8  ...
# 149     203466  0.0  0.0  22.0  60.0   97.0   18.0   1.2  138.0  4.3  ...
# 150     482105  0.0  0.0  44.0  60.0   95.0   46.0   0.5  138.0  4.2  ...
# 151     228849  0.0  0.0  58.0  80.0  100.0   50.0   1.2  140.0  3.5  ...
# 152     996076  0.0  0.0  57.0  60.0  105.0   49.0   1.2  150.0  4.7  ...
#
#      cad_no  cad_yes  appet_good  appet_poor  pe_no  pe_yes  ane_no  ane_yes  \
# 0      True    False       False        True  False    True   False     True
# 1      True    False       False        True  False    True   False     True
# 2     False     True       False        True  False    True   False     True
# 3     False     True        True       False   True   False    True    False
# 4      True    False       False        True  False    True    True    False
# ..      ...      ...         ...         ...    ...     ...     ...      ...
# 148    True    False        True       False   True   False    True    False
# 149    True    False        True       False   True   False    True    False
# 150    True    False        True       False   True   False    True    False
# 151    True    False        True       False   True   False    True    False
# 152    True    False        True       False   True   False    True    False
#
#      Target_ckd  Target_notckd
# 0          True          False
# 1          True          False
# 2          True          False
# 3          True          False
# 4          True          False
# ..          ...            ...
# 148       False           True
# 149       False           True
# 150       False           True
# 151       False           True
# 152       False           True
#
# [153 rows x 36 columns]
#      unique_id   al   su   age     bp    bgr     bu   sc    sod  pot  ...  \
# 2       343710  2.0  0.0  61.0   80.0  173.0  148.0  3.9  135.0  5.2  ...
# 5       397388  2.0  2.0  63.0  100.0  280.0   35.0  3.2  143.0  3.5  ...
# 7       438182  2.0  0.0  73.0   80.0  253.0  142.0  4.6  138.0  5.8  ...
# 8       474407  4.0  0.0  21.0   90.0  107.0   40.0  1.7  125.0  3.5  ...
# 9       475200  4.0  2.0  64.0  100.0  163.0   54.0  7.2  140.0  4.6  ...
# ..         ...  ...  ...   ...    ...    ...    ...  ...    ...  ...  ...
# 148     486397  0.0  0.0  20.0   70.0  123.0   44.0  1.0  135.0  3.8  ...
# 149     203466  0.0  0.0  22.0   60.0   97.0   18.0  1.2  138.0  4.3  ...
# 150     482105  0.0  0.0  44.0   60.0   95.0   46.0  0.5  138.0  4.2  ...
# 151     228849  0.0  0.0  58.0   80.0  100.0   50.0  1.2  140.0  3.5  ...
# 152     996076  0.0  0.0  57.0   60.0  105.0   49.0  1.2  150.0  4.7  ...
#
#      cad_no  cad_yes  appet_good  appet_poor  pe_no  pe_yes  ane_no  ane_yes  \
# 2     False     True       False        True  False    True   False     True
# 5     False     True        True       False   True   False    True    False
# 7     False     True        True       False   True   False    True    False
# 8      True    False        True       False   True   False   False     True
# 9      True    False        True       False  False    True    True    False
# ..      ...      ...         ...         ...    ...     ...     ...      ...
# 148    True    False        True       False   True   False    True    False
# 149    True    False        True       False   True   False    True    False
# 150    True    False        True       False   True   False    True    False
# 151    True    False        True       False   True   False    True    False
# 152    True    False        True       False   True   False    True    False
#
#      Target_ckd  Target_notckd
# 2          True          False
# 5          True          False
# 7          True          False
# 8          True          False
# 9          True          False
# ..          ...            ...
# 148       False           True
# 149       False           True
# 150       False           True
# 151       False           True
# 152       False           True
#
# [133 rows x 36 columns]

# %% [markdown]
# ## Part 3.7 : Normalize the Numerical Columns
#
# Normalizing numerical attributes ensures that all features contribute equally to the model by scaling them to a consistent range, which improves model performance and convergence. It prevents features with larger scales from disproportionately influencing the model's learning process.

# %%
# Normalize the all Numerical Attributes in the dataset.
for column in numerical_columns:
    mean_value = df[column].mean()
    std_dev = df[column].std()
    df[column] = (df[column] - mean_value) / std_dev

# Print the dataset
print(df)
# Out:
#      unique_id   al   su       age        bp       bgr        bu        sc  \
# 2       343710  2.0  0.0  0.807138  0.727802  1.142120  3.999185  1.683685
# 5       397388  2.0  2.0  0.932840  2.765646  3.507298 -0.225144  1.213526
# 7       438182  2.0  0.0  1.561350  0.727802  2.910477  3.774884  2.153844
# 8       474407  4.0  0.0 -1.706899  1.746724 -0.316775 -0.038227  0.206042
# 9       475200  4.0  2.0  0.995691  2.765646  0.921075  0.485141  3.900150
# ..         ...  ...  ...       ...       ...       ...       ...       ...
# 148     486397  0.0  0.0 -1.769750 -0.291121  0.036896  0.111307 -0.264117
# 149     203466  0.0  0.0 -1.644048 -1.310043 -0.537820 -0.860662 -0.129786
# 150     482105  0.0  0.0 -0.261328 -1.310043 -0.582029  0.186074 -0.599945
# 151     228849  0.0  0.0  0.618586  0.727802 -0.471507  0.335608 -0.129786
# 152     996076  0.0  0.0  0.555735 -1.310043 -0.360984  0.298224 -0.129786
#
#           sod       pot  ...  cad_no  cad_yes  appet_good  appet_poor  pe_no  \
# 2   -0.956087  1.367853  ...   False     True       False        True  False
# 5    0.447053 -1.298281  ...   False     True        True       False   True
# 7   -0.429910  2.308841  ...   False     True        True       False   True
# 8   -2.710013 -1.298281  ...    True    False        True       False   True
# 9   -0.079124  0.426864  ...    True    False        True       False  False
# ..        ...       ...  ...     ...      ...         ...         ...    ...
# 148 -0.956087 -0.827787  ...    True    False        True       False   True
# 149 -0.429910 -0.043630  ...    True    False        True       False   True
# 150 -0.429910 -0.200461  ...    True    False        True       False   True
# 151 -0.079124 -1.298281  ...    True    False        True       False   True
# 152  1.674801  0.583696  ...    True    False        True       False   True
#
#      pe_yes  ane_no  ane_yes  Target_ckd  Target_notckd
# 2      True   False     True        True          False
# 5     False    True    False        True          False
# 7     False    True    False        True          False
# 8     False   False     True        True          False
# 9      True    True    False        True          False
# ..      ...     ...      ...         ...            ...
# 148   False    True    False       False           True
# 149   False    True    False       False           True
# 150   False    True    False       False           True
# 151   False    True    False       False           True
# 152   False    True    False       False           True
#
# [133 rows x 36 columns]

# %% [markdown]
# ## Part 3.8: Remove Unnecessary columns

# %% [markdown]
# Are there any columns in this dataset which are not appropriate for modeling and predictions? Which column(s)? Justify their exclusion and remove them
#
# The unique id columns are not necessary, since they do not contribute at all to the result of whether or not they have CKD.

# %% [markdown]
# Answer:

# %%
#Remove that column
df_cleaned = df.drop(columns=['unique_id'])



# Print the dataset
print(df_cleaned)
# Out:
#       al   su       age        bp       bgr        bu        sc       sod  \
# 2    2.0  0.0  0.807138  0.727802  1.142120  3.999185  1.683685 -0.956087
# 5    2.0  2.0  0.932840  2.765646  3.507298 -0.225144  1.213526  0.447053
# 7    2.0  0.0  1.561350  0.727802  2.910477  3.774884  2.153844 -0.429910
# 8    4.0  0.0 -1.706899  1.746724 -0.316775 -0.038227  0.206042 -2.710013
# 9    4.0  2.0  0.995691  2.765646  0.921075  0.485141  3.900150 -0.079124
# ..   ...  ...       ...       ...       ...       ...       ...       ...
# 148  0.0  0.0 -1.769750 -0.291121  0.036896  0.111307 -0.264117 -0.956087
# 149  0.0  0.0 -1.644048 -1.310043 -0.537820 -0.860662 -0.129786 -0.429910
# 150  0.0  0.0 -0.261328 -1.310043 -0.582029  0.186074 -0.599945 -0.429910
# 151  0.0  0.0  0.618586  0.727802 -0.471507  0.335608 -0.129786 -0.079124
# 152  0.0  0.0  0.555735 -1.310043 -0.360984  0.298224 -0.129786  1.674801
#
#           pot      hemo  ...  cad_no  cad_yes  appet_good  appet_poor  pe_no  \
# 2    1.367853 -2.902248  ...   False     True       False        True  False
# 5   -1.298281 -0.604893  ...   False     True        True       False   True
# 7    2.308841 -1.688551  ...   False     True        True       False   True
# 8   -1.298281 -2.642170  ...    True    False        True       False   True
# 9    0.426864 -2.815556  ...    True    False        True       False  False
# ..        ...       ...  ...     ...      ...         ...         ...    ...
# 148 -0.827787  0.088648  ...    True    False        True       False   True
# 149 -0.043630 -0.388161  ...    True    False        True       False   True
# 150 -0.200461  0.262033  ...    True    False        True       False   True
# 151 -1.298281 -0.171430  ...    True    False        True       False   True
# 152  0.583696  0.565458  ...    True    False        True       False   True
#
#      pe_yes  ane_no  ane_yes  Target_ckd  Target_notckd
# 2      True   False     True        True          False
# 5     False    True    False        True          False
# 7     False    True    False        True          False
# 8     False   False     True        True          False
# 9      True    True    False        True          False
# ..      ...     ...      ...         ...            ...
# 148   False    True    False       False           True
# 149   False    True    False       False           True
# 150   False    True    False       False           True
# 151   False    True    False       False           True
# 152   False    True    False       False           True
#
# [133 rows x 35 columns]

# %% [markdown]
# ## Part 3.9: Export the Cleaned Data

# %% [markdown]
# Now that you've completed these cleaning steps you should have a pandas dataframe which is much cleaner and ready for modeling. Our final step is to save our work. Export the DataFrame to a two new formats: csv and json.

# %%
# Export the dataframe to a new csv file
df_cleaned.to_csv('cleaned_data.csv', index=False)

# Export the dataframe to a new json file
df_cleaned.to_json('cleaned_data.json', orient='records', lines=True)

# %% [markdown]
# # Part 4: Data conversions with Large Language Models
#
# One powerful use case of ChatGPT (and other generative language models) is cleaning and transforming data. In some cases, these models can directly manipulate loosely structured data that you provide to them into a standard format. In the other cases, you can often prompt the model to create a conversion or extraction script for you in python or Pandas and then run it on your own.
#
# In this part of the assignment you will prompt 383GPT to explore these capabilities.

# %% [markdown]
# ## Part 4.1 GPT Data Manipulation
#
# Take the cleaned dataset that you created in part three and output the top 15 rows of that dataset. Then copy the terminal output, open 383gpt and ask it to convert that output to a markdown table. Paste that markdown table in the cell bellow

# %% [markdown]
# ### Paste the markdown table here
# ### Paste the markdown table here
# 2.0,0.0,0.8071384044502957,0.7278015004635852,1.1421196773719922,3.9991846655266765,1.6836850578469942,-0.9560871877676435,1.3678528532282872,-2.9022482425120306,-2.894559784712837,0.5177007742231726,-2.2932919804295917,True,False,True,False,True,False,True,False,False,True,False,True,False,True,False,True,False,True,False,True,True,False
# 2.0,0.0,0.49288369779956587,1.7467236011126048,0.16952300217104652,2.4664636941240223,3.564321877109803,-1.657657372446797,0.7405272343339351,-2.29539970488627,-2.1739000105331154,-0.718143894499324,-2.0506445393817514,True,False,True,False,True,False,True,False,False,True,True,False,True,False,True,False,True,False,True,False,True,False
# 3.0,4.0,1.3099459350914635,-0.2911206001854346,3.153626437446675,1.718794927586142,0.8776978495915045,-1.8330499186165852,-0.514124003454768,-0.8216246849379928,-1.0208443718455604,0.6942500126121007,-1.2013784957143092,False,True,True,False,True,False,True,False,False,True,False,True,False,True,True,False,False,True,True,False,True,False
# 3.0,0.0,0.8699893457804416,-0.2911206001854346,0.014791712934532424,0.03654020287591149,0.20604184271192966,-0.7806946415978551,0.5836958296103477,-0.7782783608218672,-0.7325804621736717,-0.056084250540843664,-1.4440259367621497,False,True,True,False,True,False,True,False,False,True,False,True,True,False,True,False,True,False,True,False,True,False
# 4.0,0.0,-2.6496633687077322,-1.3100427008344544,-0.6041334440115239,0.9711261610482618,-0.2641173621037726,-0.9560871877676435,0.8973586390575238,-1.9486291119572632,-2.0297680556971707,3.8279989940155748,-0.35211245204686653,True,False,True,False,True,False,False,True,True,False,True,False,True,False,False,True,True,False,True,False,True,False
# 3.0,1.0,0.4300327564694199,0.7278015004635852,2.0484029429001462,1.195426791009626,1.6836850578469942,-0.6053020954280667,0.8973586390575238,-1.5151658707960054,-1.4532402363533934,-0.27677079852700376,-1.68667337780999,False,True,True,False,False,True,False,True,False,True,False,True,True,False,True,False,False,True,True,False,True,False
# 1.0,0.0,-0.13562571550189376,-1.3100427008344544,0.9210749784626864,1.9057121192206121,1.280691453719249,0.09626808925108674,-0.514124003454768,-1.991975436073389,-2.3180319653690598,2.9011154924737017,-2.2932919804295917,False,True,False,True,True,False,True,False,False,True,False,True,True,False,True,False,True,False,True,False,True,False
# 4.0,2.0,0.9956912284407335,2.7656457017616245,0.9210749784626864,0.4851414627986396,3.9001498805495904,-0.07912445691870162,0.42686442488675896,-2.815555594279779,-2.6062958750409484,-0.23263348892977176,-2.0506445393817514,True,False,True,False,True,False,False,True,False,True,False,True,True,False,True,False,False,True,True,False,True,False
# 4.0,0.0,-0.00992383284160183,0.7278015004635852,-0.5820289741205934,4.559936240430087,4.235977883989378,-0.7806946415978551,-0.8277868129019442,-1.991975436073389,-1.7415041460252823,-0.49745734651316387,-2.0506445393817514,False,True,True,False,True,False,True,False,False,True,True,False,True,False,True,False,True,False,False,True,True,False
# 4.0,3.0,1.3099459350914635,-0.2911206001854346,2.0484029429001462,2.055245872528188,3.295659474357973,-3.5869753803144686,-0.6709554081783561,-2.1653607325378923,-2.3180319653690598,1.532858894959509,-2.1719682599056718,False,True,True,False,False,True,False,True,False,True,False,True,False,True,True,False,False,True,False,True,True,False
# 3.0,2.0,1.5613497004120473,2.7656457017616245,3.8388650040655232,1.830945242566824,2.8255002695422706,-0.07912445691870162,-2.2392694554142354,-2.2520533807701444,-2.0297680556971707,-0.45332003691593187,-2.2932919804295917,True,False,True,False,False,True,True,False,False,True,False,True,False,True,False,True,True,False,True,False,True,False
# 4.0,0.0,-1.7068992487555428,1.7467236011126048,-0.3167753354294263,-0.03822667377787653,0.20604184271192966,-2.710012649465527,-1.2982810270727076,-2.6421702978152757,-3.0386917395487814,1.9300946813345974,-1.4440259367621497,False,True,True,False,False,True,False,True,True,False,True,False,True,False,True,False,True,False,False,True,True,False
# 4.0,1.0,0.9956912284407335,-1.3100427008344544,2.601014690173411,0.6346752161062157,1.9523474605988238,-0.6053020954280667,1.6815156626754635,-2.1220144084217667,-2.1739000105331154,-0.23263348892977176,-2.0506445393817514,True,False,True,False,True,False,False,True,False,True,False,True,True,False,False,True,False,True,True,False,True,False
# 4.0,1.0,0.49288369779956587,-0.2911206001854346,1.959985063336424,-0.5615948103543927,0.20604184271192966,-0.7806946415978551,-0.8277868129019442,0.7388429832425364,1.141134950693605,1.9742319909318293,0.6184773121444961,True,False,False,True,True,False,True,False,True,False,True,False,True,False,True,False,True,False,True,False,True,False
# 4.0,0.0,-0.00992383284160183,0.7278015004635852,0.25794088173476887,3.6627337205846304,4.773302689493038,-1.4822648262770084,1.8383470673990507,-1.77524381549276,-1.1649763266815047,-0.806418513693788,-1.3227022162382291,True,False,True,False,True,False,False,True,True,False,False,True,True,False,True,False,False,True,True,False,True,False

# %% [markdown]
# ** Caution: ** while language models can perform data conversions they also can * hallucinate * during this process, particularly for bigger datasets. Reflect on this below, how could you mitigate data conversion hallucinations from LLM conversions?
#
# Maybe try to make GPT work on data in small bits at a time, like only a few rows?

# %% [markdown]
# ## Part 4.2 GPT Pandas Prompting
#
# In this section, you will prompt 383GPT to write pandas code manipulations for you.
#
# After working with this data for awhile, we realized we're starting to forget the meanings of the abbreviated column names. Let's ask 383GPT to fix this for us. First, navigate to the [UCI dataset overview](https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease) and copy the abbrevation to name mapping. Then, go to 383GPT and instruct the LLM to provide you with a pandas script to apply this renaming to all the columns of your dataset. Paste that code below and make any adjustments necessary to run it in your notebook.

# %%
# Code to rename all the columns in the dataset


# Define the column mappings based on your descriptions
column_mapping = {
    'age': 'age',
    'bp': 'blood pressure',
    'sg': 'specific gravity',
    'al': 'albumin',
    'su': 'sugar',
    'rbc': 'red blood cells',
    'pc': 'pus cell',
    'pcc': 'pus cell clumps',
    'ba': 'bacteria',
    'bgr': 'blood glucose random',
    'bu': 'blood urea',
    'sc': 'serum creatinine',
    'sod': 'sodium',
    'pot': 'potassium',
    'hemo': 'hemoglobin',
    'pcv': 'packed cell volume',
    'wc': 'white blood cell count',
    'rc': 'red blood cell count',
    'htn': 'hypertension',
    'dm': 'diabetes mellitus',
    'cad': 'coronary artery disease',
    'appet': 'appetite',
    'pe': 'pedal edema',
    'ane': 'anemia',
    'class': 'class'
}

# Rename the columns using the mapping
df_cleaned.rename(columns=column_mapping, inplace=True)

# Print the updated DataFrame
print("\nUpdated DataFrame with Renamed Columns:")
print(df_cleaned)
# Out:
# Updated DataFrame with Renamed Columns:
#      albumin  sugar       age  blood pressure  blood glucose random  \
# 2        2.0    0.0  0.807138        0.727802              1.142120
# 5        2.0    2.0  0.932840        2.765646              3.507298
# 7        2.0    0.0  1.561350        0.727802              2.910477
# 8        4.0    0.0 -1.706899        1.746724             -0.316775
# 9        4.0    2.0  0.995691        2.765646              0.921075
# ..       ...    ...       ...             ...                   ...
# 148      0.0    0.0 -1.769750       -0.291121              0.036896
# 149      0.0    0.0 -1.644048       -1.310043             -0.537820
# 150      0.0    0.0 -0.261328       -1.310043             -0.582029
# 151      0.0    0.0  0.618586        0.727802             -0.471507
# 152      0.0    0.0  0.555735       -1.310043             -0.360984
#
#      blood urea  serum creatinine    sodium  potassium  hemoglobin  ...  \
# 2      3.999185          1.683685 -0.956087   1.367853   -2.902248  ...
# 5     -0.225144          1.213526  0.447053  -1.298281   -0.604893  ...
# 7      3.774884          2.153844 -0.429910   2.308841   -1.688551  ...
# 8     -0.038227          0.206042 -2.710013  -1.298281   -2.642170  ...
# 9      0.485141          3.900150 -0.079124   0.426864   -2.815556  ...
# ..          ...               ...       ...        ...         ...  ...
# 148    0.111307         -0.264117 -0.956087  -0.827787    0.088648  ...
# 149   -0.860662         -0.129786 -0.429910  -0.043630   -0.388161  ...
# 150    0.186074         -0.599945 -0.429910  -0.200461    0.262033  ...
# 151    0.335608         -0.129786 -0.079124  -1.298281   -0.171430  ...
# 152    0.298224         -0.129786  1.674801   0.583696    0.565458  ...
#
#      cad_no  cad_yes  appet_good  appet_poor  pe_no  pe_yes  ane_no  ane_yes  \
# 2     False     True       False        True  False    True   False     True
# 5     False     True        True       False   True   False    True    False
# 7     False     True        True       False   True   False    True    False
# 8      True    False        True       False   True   False   False     True
# 9      True    False        True       False  False    True    True    False
# ..      ...      ...         ...         ...    ...     ...     ...      ...
# 148    True    False        True       False   True   False    True    False
# 149    True    False        True       False   True   False    True    False
# 150    True    False        True       False   True   False    True    False
# 151    True    False        True       False   True   False    True    False
# 152    True    False        True       False   True   False    True    False
#
#      Target_ckd  Target_notckd
# 2          True          False
# 5          True          False
# 7          True          False
# 8          True          False
# 9          True          False
# ..          ...            ...
# 148       False           True
# 149       False           True
# 150       False           True
# 151       False           True
# 152       False           True
#
# [133 rows x 35 columns]

# %% [markdown]
# ## Part 4.3 Augmenting our skills with prompting
#
# In addition, we can also use 383GPT to convert our data manipulation operations between different data manipulation languages and libraries. For example let's prompt 383GPT to convert the following SQL query to a pandas query.
#
# **SQL Query**
# ```sql
# SELECT Target, COUNT(*) AS count
# FROM your_table_name
# GROUP BY Target;
# ```
#
# Prompt 383GPT to convert this to a pandas query. Run this query below, then describe what it does. (If you're not familiar with SQL that is okay you need to only comment on the final resulting output.)

# %%
df_cleaned.head()
# Out:
#    albumin  sugar       age  blood pressure  blood glucose random  blood urea  \
# 2      2.0    0.0  0.807138        0.727802              1.142120    3.999185
# 5      2.0    2.0  0.932840        2.765646              3.507298   -0.225144
# 7      2.0    0.0  1.561350        0.727802              2.910477    3.774884
# 8      4.0    0.0 -1.706899        1.746724             -0.316775   -0.038227
# 9      4.0    2.0  0.995691        2.765646              0.921075    0.485141
#
#    serum creatinine    sodium  potassium  hemoglobin  ...  cad_no  cad_yes  \
# 2          1.683685 -0.956087   1.367853   -2.902248  ...   False     True
# 5          1.213526  0.447053  -1.298281   -0.604893  ...   False     True
# 7          2.153844 -0.429910   2.308841   -1.688551  ...   False     True
# 8          0.206042 -2.710013  -1.298281   -2.642170  ...    True    False
# 9          3.900150 -0.079124   0.426864   -2.815556  ...    True    False
#
#    appet_good  appet_poor  pe_no  pe_yes  ane_no  ane_yes  Target_ckd  \
# 2       False        True  False    True   False     True        True
# 5        True       False   True   False    True    False        True
# 7        True       False   True   False    True    False        True
# 8        True       False   True   False   False     True        True
# 9        True       False  False    True    True    False        True
#
#    Target_notckd
# 2          False
# 5          False
# 7          False
# 8          False
# 9          False
#
# [5 rows x 35 columns]

# %%
# Converted SQL to Pandas code


# Use groupby to count occurrences of each unique value in the 'Target' column
target_count = merged_dropped.groupby('Target').size().reset_index(name='count')

# Print the result
print(target_count)
# Out:
#    Target  count
# 0     ckd     42
# 1  notckd    111

# %% [markdown]
# *Describe what the above code does here*
# *Describe what the above code does here*
#
# Group By and Count:
# - `df_cleaned.groupby('Target')`: This groups the DataFrame by the `Target` column.
# - `.size()`: This counts the number of occurrences for each group.
# - `.reset_index(name='count')`: This resets the index of the resulting Series, converting it back to a DataFrame, and renames the count column to `count`.
# Output: Finally, it prints the `target_count` DataFrame, which will contain the unique values of `Target` along with their counts.

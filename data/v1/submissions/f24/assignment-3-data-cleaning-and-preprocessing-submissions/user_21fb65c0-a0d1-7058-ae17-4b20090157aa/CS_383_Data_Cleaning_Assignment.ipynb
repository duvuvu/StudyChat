# %%
# Install openai python library
# !pip install openai
# Out:
# Requirement already satisfied: openai in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (1.53.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.12.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from openai) (0.6.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.6.2.post1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from openai) (0.27.2)
# Requirement already satisfied: sniffio in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from openai) (1.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from openai) (1.9.0)
# Requirement already satisfied: tqdm>4 in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.62.3)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from openai) (2.9.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (3.2)
# Requirement already satisfied: certifi in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (2021.10.8)
# Requirement already satisfied: httpcore==1.* in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/<redacted>/opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)

# %%
# Read authentication keys from environmental variables
import os
_open_ai_tkn = os.environ.get('OPENAI_KEY')
_project_tkn = os.environ.get('OPENAI_PROJECT')
_organisation_tkn = os.environ.get('OPENAI_ORG')

# %%
# create client endpoint for accessing remote LLM
from openai import OpenAI

client = OpenAI(
  organization=_organisation_tkn,
  project=_project_tkn,
  api_key=_open_ai_tkn
)

# %%
# Making a request
response = client.chat.completions.create(
    messages=[{
        "role": "user",
        "content": "What are the benefits of taking an AI course as a computer science student?"
    }],
    model="gpt-4o-mini",
    max_completion_tokens=100
)

# %%
print(response.choices[0].message.content)
# Out:
# Taking an AI course as a computer science student can offer numerous benefits, including:
#
# 1. **In-Demand Skill Set**: AI and machine learning skills are highly sought after in the tech industry. Having expertise in these areas can make graduates more competitive in the job market.
#
# 2. **Career Opportunities**: Knowledge of AI opens doors to various career paths like data scientist, machine learning engineer, AI researcher, and roles in automation, robotics, and more.
#
# 3. **Interdisciplinary Applications**

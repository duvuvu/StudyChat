# %% [markdown]
# Name: <redacted> <redacted>
# Spire ID: 33302116
# https://github.com/<redacted>/assignment-5-judging-flowers-<redacted>
# Commit ID: assignment-5-final

# %%
# Imports and pip installations (if needed)
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Part 1: Load the dataset

# %%
# Load the dataset (load remotely or locally)
data = pd.read_csv('./iris.csv')
# Output the first 15 rows of the data
print(data.head(15))
# Display a summary of the table information (number of datapoints, etc.)
data.info()
print(data['species'].unique())
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %% [markdown]
# ## About the dataset
# Explain what the data is in your own words. What are your features and labels? What is the mapping of your labels to the actual classes?

# %% [markdown]
# The dataset is about different species of iris flowers. It contains 150 entries. The features for the dataset are sepal_length, sepal_width, petal_length and petal_width. And the label is species. The actual classes are the setosa, versicolor and virginica, which are the species of iris flowers in the dataset. The labels for the classes should be [0, 1, 2], and 0 represents the setosa, 1 represents versicolor, 2 represents virginica.

# %% [markdown]
# # Part 2: Split the dataset into train and test

# %%
# Take the dataset and split it into our features (X) and label (y)
from sklearn.model_selection import train_test_split
X = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = data['species']
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)
# Use sklearn to split the features and labels into a training/test set. (90% train, 10% test)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 50)
print(X_train.shape)
print(y_train.shape)
# Out:
# (135, 4)
# (135,)

# %% [markdown]
# # Part 3: Logistic Regression

# %%
# i. Use sklearn to train a LogisticRegression model on the training set
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# ii. For a sample datapoint, predict the probabilities for each possible class
sample_point = [[1,1,1,0]]
sample_point_df = pd.DataFrame(sample_point, columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
probabilities = model.predict_proba(sample_point_df)
print(probabilities)
# iii. Report on the score for Logistic regression model, what does the score measure?
score = model.score(X_test, y_test)
print(f'Score: {score: .3f}')
# iv. Extract the coefficents and intercepts for the boundary line(s)
coefficents = model.coef_
intercept = model.intercept_
print(f'coefficents: {coefficents}')
print(f'intercept: {intercept}')
# Out:
# [[9.96357368e-01 3.64259607e-03 3.55119637e-08]]
# Score:  1.000
# coefficents: [[-0.42326446  0.97656528 -2.45647874 -1.04890609]
#  [ 0.51368556 -0.21905272 -0.20248426 -0.86080569]
#  [-0.0904211  -0.75751256  2.65896301  1.90971178]]
# intercept: [  9.49023001   1.88349415 -11.37372416]

# %% [markdown]
# Score in iii.: The score calculate the accuracy of the model, and it returns a value in [0, 1].

# %% [markdown]
# # Part 4: Support Vector Machine

# %%
# i. Use sklearn to train a Support Vector Classifier on the training set
from sklearn.svm import SVC
model = SVC(kernel = 'linear', probability = True)
model.fit(X_train, y_train)
# ii. For a sample datapoint, predict the probabilities for each possible class
sample_datapoint = pd.DataFrame([[1,1,1,0]], columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
probabilities = model.predict_proba(sample_datapoint)
# iii. Report on the score for the SVM, what does the score measure?
score = model.score(X_test, y_test)
print(f'Score: {score: .3f}')
# Out:
# Score:  0.933

# %% [markdown]
# Score in SVC: The score measures the accuracy of the model.

# %% [markdown]
# # Part 5: Neural Network

# %%
# i. Use sklearn to train a Neural Network (MLP Classifier) on the training set
from sklearn.neural_network import MLPClassifier
# ii. For a sample datapoint, predict the probabilities for each possible class
model = MLPClassifier(hidden_layer_sizes=(50, 50), max_iter=1000, random_state=42)
model.fit(X_train, y_train)
sample_point = pd.DataFrame([[1,1,1,0]], columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
probabilities = model.predict_proba(sample_point)
print(probabilities)
# iii. Report on the score for the Neural Network, what does the score measure?
score = model.score(X_test, y_test)
print(f'Score: {score: .3f}')
# iv: Experiment with different options for the neural network, report on your best configuration
# Out:
# [[0.77836252 0.22044616 0.00119132]]
# Score:  0.867

# %% [markdown]
# # Part 6: K-Nearest Neighbors

# %%
# i. Use sklearn to 'train' a k-Neighbors Classifier
# Note: KNN is a nonparametric model and technically doesn't require training
# fit will essentially load the data into the model see link below for more information
# https://stats.stackexchange.com/questions/349842/why-do-we-need-to-fit-a-k-nearest-neighbors-classifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train, y_train)
# ii. For a sample datapoint, predict the probabilities for each possible class
sample_point = pd.DataFrame([[1, 1, 1, 0]], columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
probabilities = knn.predict_proba(sample_point)
print(probabilities)
# iii. Report on the score for kNN, what does the score measure?
score = knn.score(X_test, y_test)
print(f'Score: {score: .3f}')
# Out:
# [[1. 0. 0.]]
# Score:  0.933

# %% [markdown]
# The score measures the accuracy for the model.

# %% [markdown]
# # Part 7: Conclusions and takeaways
#
# In your own words describe the results of the notebook. Which model(s) performed the best on the dataset? Why do you think that is? Did anything surprise you about the exercise?

# %% [markdown]
# The logistic regression model performed the best on the dataset. The score for logistic regression model is 1.000, which is a perfect score. The score of other models are less than 1.000. What surprised me is that the more complex models like k-NN and Neural Networks got scores lower than the simpler models which is Logistic Regression. I think that may because the dataset might be linearly separable, allowing simpler models to be sufficiently effective.

# %%
# Imports and pip installations (if needed)
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# # Part 1: Load the dataset

# %%
# Load the dataset (load remotely or locally)

# Output the first 15 rows of the data
# Display a summary of the table information (number of datapoints, etc.)
url = '/workspaces/assignment-5-judging-flowers-<redacted>/iris.csv'
data = pd.read_csv(url)
print(data.head(15))
print(data.info())
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %% [markdown]
# ## About the dataset
# Explain what the data is in your own words. What are your features and labels? What is the mapping of your labels to the actual classes?

# %% [markdown]
# the dataset collects the measurments of three different species of flowers to indicate which specie the given flower is. the features are sepal_length, sepal_width, petal_length, and petal_width which are the length and width of the sepal and petal of the flower, the label is species which indicate what is the specie of a certain flower, the three labels are setosa, versicolor, and virginica. each label corespond to the classes, it seems like there is a relation between the overall size and the ratio between the width and length of the petal to the different classes.

# %% [markdown]
# # Part 2: Split the dataset into train and test

# %%
# Take the dataset and split it into our features (X) and label (y)

# Use sklearn to split the features and labels into a training/test set. (90% train, 10% test)
x = data.drop(columns=['species'])  # features
y = data['species']
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=87)

# %% [markdown]
# # Part 3: Logistic Regression

# %%
# i. Use sklearn to train a LogisticRegression model on the training set
model = LogisticRegression()
model.fit(x_train, y_train)

sample_data_setosa = {
    'sepal_length': [5.2], 
    'sepal_width': [3.8],
    'petal_length': [1.8],   
    'petal_width': [0.8],   
}
sample_df = pd.DataFrame(sample_data_setosa)
predicted_output = model.predict_proba(sample_df)
target_names = ['setosa', 'versicolor', 'virginica']
print("Predicted probabilities for each class:")
for class_label, probability in zip(target_names, predicted_output[0]):
    print(f"{class_label}: {probability:.4f}")

# ii. For a sample datapoint, predict the probabilities for each possible class
score = model.score(x_test, y_test)
print(f"Accuracy score of the Logistic Regression model: {score:.4f}")
print("the score measures the accuracy of the model. Accuracy is defined as the ratio of the number of correctly predicted instances (true positives and true negatives) to the total number of instances in the dataset.")
# iii. Report on the score for Logistic regression model, what does the score measure?

# iv. Extract the coefficents and intercepts for the boundary line(s)
coefficients = model.coef_  # Coefficients for each class
intercepts = model.intercept_  # Intercepts for each class
for i, class_label in enumerate(data['species'].unique()):
    print(f"Class: {class_label}")
    print(f"Coefficients: {coefficients[i]}")
    print(f"Intercept: {intercepts[i]}")
    print("-" * 30)
# Out:
# Predicted probabilities for each class:
# setosa: 0.9584
# versicolor: 0.0416
# virginica: 0.0000
# Accuracy score of the Logistic Regression model: 0.9333
# the score measures the accuracy of the model. Accuracy is defined as the ratio of the number of correctly predicted instances (true positives and true negatives) to the total number of instances in the dataset.
# Class: setosa
# Coefficients: [-0.42338707  0.93124505 -2.4738173  -1.05587378]
# Intercept: 9.688844333542637
# ------------------------------
# Class: versicolor
# Coefficients: [ 0.54615979 -0.33561841 -0.22992051 -0.87144036]
# Intercept: 2.1371773393290843
# ------------------------------
# Class: virginica
# Coefficients: [-0.12277272 -0.59562664  2.70373781  1.92731414]
# Intercept: -11.82602167287178
# ------------------------------

# %% [markdown]
# # Part 4: Support Vector Machine

# %%
# i. Use sklearn to train a Support Vector Classifier on the training set
model_svc = SVC(kernel='rbf',probability=True)  # You can change the kernel type (e.g., 'linear', 'rbf', 'poly')
model_svc.fit(x_train, y_train)
# ii. For a sample datapoint, predict the probabilities for each possible class
sample_df = pd.DataFrame(sample_data_setosa)
predicted_prob = model_svc.predict_proba(sample_df)
print("Predicted probabilities for each class:")
for class_label, probability in zip(target_names, predicted_prob[0]):
    print(f"{class_label}: {probability:.4f}")

# iii. Report on the score for the SVM, what does the score measure?
y_pred = model_svc.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of the Support Vector Classifier: {accuracy:.4f}")
print("Once again the score measures the accuracy of the model. Accuracy is defined as the ratio of the number") 
print("of correctly predicted instances (true positives and true negatives) to the total number of instances in the dataset.")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Predicted probabilities for each class:
# setosa: 0.9292
# versicolor: 0.0529
# virginica: 0.0179
# Accuracy of the Support Vector Classifier: 0.9333
# Once again the score measures the accuracy of the model. Accuracy is defined as the ratio of the number
# of correctly predicted instances (true positives and true negatives) to the total number of instances in the dataset.
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         6
#   versicolor       1.00      0.80      0.89         5
#    virginica       0.80      1.00      0.89         4
#
#     accuracy                           0.93        15
#    macro avg       0.93      0.93      0.93        15
# weighted avg       0.95      0.93      0.93        15

# %% [markdown]
# # Part 5: Neural Network

# %%
# i. Use sklearn to train a Neural Network (MLP Classifier) on the training set
mlp_model = MLPClassifier(activation='relu', hidden_layer_sizes=(1000), max_iter=300, random_state=55,alpha=0.0001) 
mlp_model.fit(x_train, y_train)

# ii. For a sample datapoint, predict the probabilities for each possible class
predicted_prob = mlp_model.predict_proba(sample_df)
print("Predicted probabilities for each class:")
for class_label, probability in zip(target_names, predicted_prob[0]):
    print(f"{class_label}: {probability:.4f}")

# iii. Report on the score for the Neural Network, what does the score measure?
mlp_y_pred = mlp_model.predict(x_test)
mlp_acc = accuracy_score(y_test, mlp_y_pred)
print(f"Accuracy of the MLP Classifier: {mlp_acc:.4f}")
print("the score measures how many accurate results there are out of all reasults")
# iv: Experiment with different options for the neural network, report on your best configuration
print("although it seems like the accuracy score hasn't changed much, the current configuration gave the best reasult")
print("the 'relu' activation gave the best reasult and further increasing the hidden layers or the max iterations did not improved")
print("the reasults, same for decreasing the alpha further. ")
print("\nClassification Report:")
print(classification_report(y_test, mlp_y_pred))
# Out:
# Predicted probabilities for each class:
# setosa: 0.9992
# versicolor: 0.0008
# virginica: 0.0000
# Accuracy of the MLP Classifier: 0.9333
# the score measures how many accurate results there are out of all reasults
# although it seems like the accuracy score hasn't changed much, the current configuration gave the best reasult
# the 'relu' activation gave the best reasult and further increasing the hidden layers or the max iterations did not improved
# the reasults, same for decreasing the alpha further.
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         6
#   versicolor       1.00      0.80      0.89         5
#    virginica       0.80      1.00      0.89         4
#
#     accuracy                           0.93        15
#    macro avg       0.93      0.93      0.93        15
# weighted avg       0.95      0.93      0.93        15
# ...

# %% [markdown]
# # Part 6: K-Nearest Neighbors

# %%
# i. Use sklearn to 'train' a k-Neighbors Classifier
# Note: KNN is a nonparametric model and technically doesn't require training
# fit will essentially load the data into the model see link below for more information
# https://stats.stackexchange.com/questions/349842/why-do-we-need-to-fit-a-k-nearest-neighbors-classifier
k_neighbors = 1 # You can choose different values for k
knn_model = KNeighborsClassifier(n_neighbors=k_neighbors)
knn_model.fit(x_train, y_train)
# ii. For a sample datapoint, predict the probabilities for each possible class
predicted_prob = knn_model.predict_proba(sample_df)
print("Predicted probabilities for each class:")
for class_label, probability in zip(target_names, predicted_prob[0]):
    print(f"{class_label}: {probability:.4f}")

# iii. Report on the score for kNN, what does the score measure?
y_pred_knn = knn_model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred_knn)
print(f"Accuracy of the k-Neighbors Classifier with k={k_neighbors}: {accuracy:.8f}")
print("it seems like the score havent chancged although by the sample data it seems that the model did improved")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_knn))
# Out:
# Predicted probabilities for each class:
# setosa: 1.0000
# versicolor: 0.0000
# virginica: 0.0000
# Accuracy of the k-Neighbors Classifier with k=1: 0.93333333
# it seems like the score havent chancged although by the sample data it seems that the model did improved
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         6
#   versicolor       1.00      0.80      0.89         5
#    virginica       0.80      1.00      0.89         4
#
#     accuracy                           0.93        15
#    macro avg       0.93      0.93      0.93        15
# weighted avg       0.95      0.93      0.93        15

# %% [markdown]
# # Part 7: Conclusions and takeaways
#
# In your own words describe the results of the notebook. Which model(s) performed the best on the dataset? Why do you think that is? Did anything surprise you about the exercise?

# %% [markdown]
# It seems like the best model was the K-nearest neighbors as it predicted the sample data point the best, although score wise all models are compitable. I was surprised that the accuracy score did not changed at all, I suspect that it is probably because the data is not clean enough and some of the entries are not acurate.

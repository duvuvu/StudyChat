# %%
# Imports and pip installations (if needed)

import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# <redacted> <redacted>
# <br>repo url: https://github.com/<redacted>/assignment-5-judging-flowers-<redacted>
# <br> commit ID: "Assignment 5 done part 2:

# %% [markdown]
# # Part 1: Load the dataset

# %%
# Load the dataset (load remotely or locally)

# Output the first 15 rows of the data
# Display a summary of the table information (number of datapoints, etc.)

df = pd.read_csv('iris.csv')

print(df.head(15))

print(df.info())
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %% [markdown]
# ## About the dataset
# Explain what the data is in your own words. What are your features and labels? What is the mapping of your labels to the actual classes?
#
# The Iris dataset is a collection of measurements of three types of iris flowers. It consists of a total of 150 samples. Each sample has four features sepal length, sepal width, petal_length, and petal_width. These four features are numerical and describe the physical characteristics of each flower. The label (or target) is the flower species which are Setosa(mapped to 0), Versicolor(mapped to 1), and Virginica(mapped to 2).

# %% [markdown]
# # Part 2: Split the dataset into train and test

# %%
# Take the dataset and split it into our features (X) and label (y)

# Use sklearn to split the features and labels into a training/test set. (90% train, 10% test)

X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = df['species']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# # Part 3: Logistic Regression

# %%
# i. Use sklearn to train a LogisticRegression model on the training set
log_reg_model = LogisticRegression(max_iter=1000)
log_reg_model.fit(X_train, y_train)

# ii. For a sample datapoint, predict the probabilities for each possible class
sample_datapoint = X_test.sample(random_state=42)
predicted_probabilities = log_reg_model.predict_proba(sample_datapoint)
print("Predicted probabilities for each possible class:", predicted_probabilities)

# iii. Report on the score for Logistic regression model, what does the score measure?
score = log_reg_model.score(X_test, y_test)
print("Logistic Regression model score:", score)
# The score measures the accuracy which is the proportion of correct predictions
# out of the total predictions on the test set. 
# The Logistic Regression model score of 1.0 means that 100% accuracy on the test set, 
# which means that the model correctly classified all samples. 

# iv. Extract the coefficents and intercepts for the boundary line(s)
coefficients = log_reg_model.coef_
intercepts = log_reg_model.intercept_
print("Coefficients for the boundary lines:", coefficients)
print("Intercepts for the boundary lines:", intercepts)
# Out:
# Predicted probabilities for each possible class: [[0.02747507 0.94963395 0.02289098]]
# Logistic Regression model score: 1.0
# Coefficients for the boundary lines: [[-0.4265052   0.96610277 -2.44672332 -1.04021115]
#  [ 0.51240312 -0.21933882 -0.21416451 -0.84582944]
#  [-0.08589792 -0.74676396  2.66088783  1.88604059]]
# Intercepts for the boundary lines: [  9.53563973   1.89322401 -11.42886374]

# %% [markdown]
# # Part 4: Support Vector Machine

# %%
# i. Use sklearn to train a Support Vector Classifier on the training set
svm_model = SVC(probability=True)
svm_model.fit(X_train, y_train)

# ii. For a sample datapoint, predict the probabilities for each possible class
sample_datapoint = X_test.sample(random_state=42)  
predicted_probabilities = svm_model.predict_proba(sample_datapoint)
print("Predicted probabilities for each possible class:", predicted_probabilities)

# iii. Report on the score for the SVM, what does the score measure?
score = svm_model.score(X_test, y_test)
print("Support Vector Classifier model accuracy:", score)
# The score measures the accuracy which is the proportion of correct predictions
# out of the total predictions on the test set. 
# The Support Vector Classifier model score of 1.0 means that 100% accuracy on the test set, 
# which means that the model correctly classified all samples.
# Out:
# Predicted probabilities for each possible class: [[0.01207695 0.98258631 0.00533674]]
# Support Vector Classifier model accuracy: 1.0

# %% [markdown]
# # Part 5: Neural Network

# %%
# i. Use sklearn to train a Neural Network (MLP Classifier) on the training set
mlp_model = MLPClassifier(hidden_layer_sizes=(10,), max_iter=10000, random_state=42)
mlp_model.fit(X_train, y_train)

# ii. For a sample datapoint, predict the probabilities for each possible class
sample_datapoint = X_test.sample(random_state=42)  
predicted_probabilities = mlp_model.predict_proba(sample_datapoint)
print("Predicted probabilities for each possible class:", predicted_probabilities)

# iii. Report on the score for the Neural Network, what does the score measure?
score = mlp_model.score(X_test, y_test)
print("Neural Network (MLP Classifier) model accuracy:", score)
# The Neural Network model score of 0.9333 indicates 93.33% accuracy on the test set, 
# which means the model correctly classified about 93% of the samples. 
# This score measures accuracy, which is the proportion of correct predictions 
# out of the total predictions made on the test set.

# iv: Experiment with different options for the neural network, report on your best configuration
best_score = score
best_config = {'hidden_layer_sizes': (10,), 'activation': 'relu', 'solver': 'adam'}

for hidden_layer_sizes in [(5,), (10,), (20,), (10, 10), (20, 10)]:
    for activation in ['identity', 'logistic', 'tanh', 'relu']:
        for solver in ['lbfgs', 'sgd', 'adam']:
            temp_model = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, activation=activation, solver=solver, max_iter=10000, random_state=42)
            temp_model.fit(X_train, y_train)
            temp_score = temp_model.score(X_test, y_test)
            
            if temp_score > best_score:
                best_score = temp_score
                best_config = {'hidden_layer_sizes': hidden_layer_sizes, 'activation': activation, 'solver': solver}

print("Best Neural Network configuration:", best_config)
print("Best Neural Network accuracy:", best_score)

# The best Neural Network configuration achieved 100% accuracy with
# a hidden layer size of (5,), activation function as identity, and 
# solver as lbfgs. 
# This setup was sufficient for the Iris dataset which means it effectively captured the patterns without overfitting.
# Out:
# Predicted probabilities for each possible class: [[0.01567868 0.96392394 0.02039738]]
# Neural Network (MLP Classifier) model accuracy: 0.9333333333333333
# Best Neural Network configuration: {'hidden_layer_sizes': (5,), 'activation': 'identity', 'solver': 'lbfgs'}
# Best Neural Network accuracy: 1.0

# %% [markdown]
# # Part 6: K-Nearest Neighbors

# %%
# i. Use sklearn to 'train' a k-Neighbors Classifier
# Note: KNN is a nonparametric model and technically doesn't require training
# fit will essentially load the data into the model see link below for more information
# https://stats.stackexchange.com/questions/349842/why-do-we-need-to-fit-a-k-nearest-neighbors-classifier

knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(X_train, y_train) 

# ii. For a sample datapoint, predict the probabilities for each possible class
sample_datapoint = X_test.sample(random_state=42) 
predicted_probabilities = knn_model.predict_proba(sample_datapoint)
print("Predicted probabilities for the sample datapoint:", predicted_probabilities)

# iii. Report on the score for kNN, what does the score measure?
score = knn_model.score(X_test, y_test)
print("k-Nearest Neighbors model accuracy:", score)
# The k-Nearest Neighbors (k-NN) model score of 1.0 means that there was a 100% accuracy on the test set, 
# meaning the model correctly classified all samples.
# Out:
# Predicted probabilities for the sample datapoint: [[0. 1. 0.]]
# k-Nearest Neighbors model accuracy: 1.0

# %% [markdown]
# # Part 7: Conclusions and takeaways
#
# In your own words describe the results of the notebook. Which model(s) performed the best on the dataset? Why do you think that is? Did anything surprise you about the exercise?
#
# The models that performed the best on the dataset include the Logistic Regression, Support Vector Classifier, the best Neutral Network configuration, and K-Nearest Neighbors Classifier as they all got a accuracy of a 100%. This high performance across different models shows that the Iris dataset is relatively easy to classify as it is a smaller and simpler models. This shows that with well-structured data, simpler models can be as accurate as more complex ones, which highlights the need to understand the dataset before choosing a model. It was surprising to see that simpler models achieved 100% accuracy just like the more complex models.

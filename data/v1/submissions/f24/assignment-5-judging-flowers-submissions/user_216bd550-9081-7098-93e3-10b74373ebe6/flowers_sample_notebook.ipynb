# %%
# Imports and pip installations (if needed)
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Commmit ID of submission: b87856066228b818ba7c7857b6fcc44792fd7ec7
# Github Repo: https://github.com/<redacted>/assignment-5-judging-flowers-<redacted>
# <redacted> <redacted>

# %% [markdown]
# # Part 1: Load the dataset

# %%
# Load the dataset (load remotely or locally)
iris = pd.read_csv('iris.csv')

# Output the first 15 rows of the data
print(iris.head(16))
# Display a summary of the table information (number of datapoints, etc.)
iris.info()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %% [markdown]
# ## About the dataset
# Explain what the data is in your own words. What are your features and labels? What is the mapping of your labels to the actual classes?

# %% [markdown]
# # Part 2: Split the dataset into train and test

# %%
# Take the dataset and split it into our features (X) and label (y)
X = iris.iloc[:, :-1]   
y = iris.iloc[:, -1]   

# Use sklearn to split the features and labels into a training/test set. (90% train, 10% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# # Part 3: Logistic Regression

# %%
# i. Use sklearn to train a LogisticRegression model on the training set
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)
# ii. For a sample datapoint, predict the probabilities for each possible class
sample = X_test.iloc[0].values.reshape(1, -1) 
probabilities = model.predict_proba(sample)
print("Probabilities for each class:", probabilities)
# iii. Report on the score for Logistic regression model, what does the score measure?
score = model.score(X_test, y_test)
print("Accuracy:", score)
# iv. Extract the coefficents and intercepts for the boundary line(s)
coefficients = model.coef_
intercepts = model.intercept_

print("Coefficients:", coefficients)
print("Intercepts:", intercepts)
# Out:
# Probabilities for each class: [[0.0034491  0.83683574 0.15971516]]
# Accuracy: 1.0
# Coefficients: [[-0.42830334  0.96729205 -2.44742526 -1.03780396]
#  [ 0.5130202  -0.22029888 -0.21604909 -0.84453741]
#  [-0.08471686 -0.74699317  2.66347435  1.88234137]]
# Intercepts: [  9.54356486   1.89887279 -11.44243765]
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# The accuracy score measures the percentage of correctly classified samples in the test set. 1.0 means perfect classification.

# %% [markdown]
# # Part 4: Support Vector Machine

# %%
# i. Use sklearn to train a Support Vector Classifier on the training set
svc_model = SVC(probability=True)
svc_model.fit(X_train, y_train)

# ii. For a sample datapoint, predict the probabilities for each possible class
sample = X_test.iloc[0].values.reshape(1, -1)
probabilities = svc_model.predict_proba(sample)
print("Probabilities for each class:", probabilities)

# iii. Report on the score for the SVM, what does the score measure?
score = svc_model.score(X_test, y_test)
print("Accuracy:", score)
# Out:
# Probabilities for each class: [[0.0070892  0.90519271 0.08771809]]
# Accuracy: 1.0
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# The accuracy measures the percentage of correctly classified samples in the test set. The score of 1.0 means perfect classification.

# %% [markdown]
# # Part 5: Neural Network

# %%
# i. Use sklearn to train a Neural Network (MLP Classifier) on the training set
mlp_model = MLPClassifier(max_iter=300, random_state=42)
mlp_model.fit(X_train, y_train)
# ii. For a sample datapoint, predict the probabilities for each possible class
sample = X_test.iloc[0].values.reshape(1, -1)
probabilities = mlp_model.predict_proba(sample)
print("Probabilities for each class:", probabilities)
# iii. Report on the score for the Neural Network, what does the score measure?
score = mlp_model.score(X_test, y_test)
print("Accuracy:", score)
configurations = [
    {'hidden_layer_sizes': (50,), 'activation': 'relu', 'solver': 'adam'},
    {'hidden_layer_sizes': (100,), 'activation': 'relu', 'solver': 'adam'},
    {'hidden_layer_sizes': (50, 50), 'activation': 'tanh', 'solver': 'adam'},
    {'hidden_layer_sizes': (50, 50), 'activation': 'relu', 'solver': 'sgd'},
]

best_score = 0
best_config = None

for config in configurations:
    mlp = MLPClassifier(
        hidden_layer_sizes=config['hidden_layer_sizes'],
        activation=config['activation'],
        solver=config['solver'],
        max_iter=300,
        random_state=42
    )
    mlp.fit(X_train, y_train)
    
    score = mlp.score(X_test, y_test)
    print(f"Configuration: {config}, Accuracy: {score}")

    if score > best_score:
        best_score = score
        best_config = config

print("Best Configuration:", best_config)
print("Best Score:", best_score)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Probabilities for each class: [[0.00701436 0.81993512 0.17305052]]
# Accuracy: 1.0
# Configuration: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'solver': 'adam'}, Accuracy: 0.9333333333333333
# ...

# %% [markdown]
# The accuracy measures the percentage of correctly classified samples in the test set. The score of 1.0 means perfect classification.

# %% [markdown]
# # Part 6: K-Nearest Neighbors

# %%
# i. Use sklearn to 'train' a k-Neighbors Classifier
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(X_train, y_train)
# Note: KNN is a nonparametric model and technically doesn't require training
# fit will essentially load the data into the model see link below for more information
# https://stats.stackexchange.com/questions/349842/why-do-we-need-to-fit-a-k-nearest-neighbors-classifier

# ii. For a sample datapoint, predict the probabilities for each possible class
sample = X_test.iloc[0].values.reshape(1, -1)
probabilities = knn_model.predict_proba(sample)
print("Probabilities for each class:", probabilities)
# iii. Report on the score for kNN, what does the score measure?
score = knn_model.score(X_test, y_test)
print("Accuracy:", score)
# Out:
# Probabilities for each class: [[0. 1. 0.]]
# Accuracy: 1.0
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Part 7: Conclusions and takeaways
#
# In your own words describe the results of the notebook. Which model(s) performed the best on the dataset? Why do you think that is? Did anything surprise you about the exercise?
#
# All the models performed the same with perfect accuracy in testing. This means that the data may be overfitted and won't generalize well. The perfect accuracy for all models surprised me. The perfect accuracy could be due to overfitting or becuase of the data.

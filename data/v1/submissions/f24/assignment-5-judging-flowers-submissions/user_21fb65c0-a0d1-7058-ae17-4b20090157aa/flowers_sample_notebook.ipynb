# %%
# Imports and pip installations (if needed)
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# url: https://github.com/<redacted>/assignment-5-judging-flowers-<redacted> commit id: ed3a644b5910723f3643a5a910ae6f7cfd7f1870

# %% [markdown]
# # Part 1: Load the dataset

# %%
# Load the dataset (load remotely or locally)
iris = datasets.load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target
iris_df['species'] = iris_df['species'].map({0: 'Iris-setosa', 
                                              1: 'Iris-versicolor', 
                                              2: 'Iris-virginica'})
# Output the first 15 rows of the data
print(iris_df.head(15))
# Display a summary of the table information (number of datapoints, etc.)
print(iris_df.info())
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# ...

# %% [markdown]
# ## About the dataset
# Explain what the data is in your own words. What are your features and labels? What is the mapping of your labels to the actual classes?
# The table has different labels relating to the dimensions of the flower. Length and width of the pedal along with the length and width of the sepal along with the species of the flower.

# %% [markdown]
# # Part 2: Split the dataset into train and test

# %%
# Take the dataset and split it into our features (X) and label (y)
X = iris_df.drop('species', axis=1)  
y = iris_df['species']                

# Use sklearn to split the features and labels into a training/test set. (90% train, 10% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# # Part 3: Logistic Regression

# %%
# i. Use sklearn to train a LogisticRegression model on the training set
log_reg = LogisticRegression(max_iter=200) 
log_reg.fit(X_train, y_train)    
# ii. For a sample datapoint, predict the probabilities for each possible class
sample_datapoint = X_test.iloc[0].values.reshape(1, -1)  
predicted_probabilities = log_reg.predict_proba(sample_datapoint)  
print("Predicted probabilities for sample datapoint:", predicted_probabilities)
# iii. Report on the score for Logistic regression model, what does the score measure?
score = log_reg.score(X_test, y_test)
print("Logistic Regression model score (accuracy):", score)
# iv. Extract the coefficents and intercepts for the boundary line(s)
coefficients = log_reg.coef_  
intercept = log_reg.intercept_
# Out:
# Predicted probabilities for sample datapoint: [[0.00348709 0.83712491 0.159388  ]]
# Logistic Regression model score (accuracy): 1.0
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Part 4: Support Vector Machine

# %%
# i. Use sklearn to train a Support Vector Classifier on the training set
svm_classifier = SVC(probability=True)  
svm_classifier.fit(X_train, y_train) 
# ii. For a sample datapoint, predict the probabilities for each possible class
sample_datapoint = X_test.iloc[0].values.reshape(1, -1)  
predicted_probabilities = svm_classifier.predict_proba(sample_datapoint)  
print("Predicted probabilities for sample datapoint:", predicted_probabilities)
# iii. Report on the score for the SVM, what does the score measure?
score = svm_classifier.score(X_test, y_test)  
print("SVM model score (accuracy):", score)
# Out:
# Predicted probabilities for sample datapoint: [[0.00621528 0.92271232 0.0710724 ]]
# SVM model score (accuracy): 1.0
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Part 5: Neural Network

# %%
# i. Use sklearn to train a Neural Network (MLP Classifier) on the training set
mlp_classifier = MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=1000, random_state=42)  
mlp_classifier.fit(X_train, y_train)
# ii. For a sample datapoint, predict the probabilities for each possible class
sample_datapoint = X_test.iloc[0].values.reshape(1, -1)  
predicted_probabilities = mlp_classifier.predict_proba(sample_datapoint) 
print("Predicted probabilities for sample datapoint:", predicted_probabilities)
# iii. Report on the score for the Neural Network, what does the score measure?
score = mlp_classifier.score(X_test, y_test) 
print("MLP Classifier model score (accuracy):", score)
# iv: Experiment with different options for the neural network, report on your best configuration
best_score = 0
best_config = None

for hidden_layers in [(5,), (10,), (5, 5), (10, 5), (10, 10, 10)]:
    mlp_classifier = MLPClassifier(hidden_layer_sizes=hidden_layers, max_iter=1000, random_state=42)
    mlp_classifier.fit(X_train, y_train)
    score = mlp_classifier.score(X_test, y_test)
    print(f"Configuration: {hidden_layers} - Score: {score}")
    
    if score > best_score:
        best_score = score
        best_config = hidden_layers

print("Best configuration:", best_config, "with score:", best_score)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   warnings.warn(
# Predicted probabilities for sample datapoint: [[0.00172107 0.97537245 0.02290648]]
# MLP Classifier model score (accuracy): 0.9333333333333333
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Configuration: (5,) - Score: 0.7333333333333333
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Configuration: (10,) - Score: 0.9333333333333333
# ...

# %% [markdown]
# # Part 6: K-Nearest Neighbors

# %%
# i. Use sklearn to 'train' a k-Neighbors Classifier
# Note: KNN is a nonparametric model and technically doesn't require training
# fit will essentially load the data into the model see link below for more information
# https://stats.stackexchange.com/questions/349842/why-do-we-need-to-fit-a-k-nearest-neighbors-classifier
knn_classifier = KNeighborsClassifier(n_neighbors=3)  
knn_classifier.fit(X_train, y_train)  
# ii. For a sample datapoint, predict the probabilities for each possible class
sample_datapoint = X_test.iloc[0].values.reshape(1, -1) 
predicted_probabilities = knn_classifier.predict_proba(sample_datapoint)  
print("Predicted probabilities for sample datapoint (KNN):", predicted_probabilities)
# iii. Report on the score for kNN, what does the score measure?
score = knn_classifier.score(X_test, y_test)  
print("KNN model score (accuracy):", score)
# Out:
# Predicted probabilities for sample datapoint (KNN): [[0. 1. 0.]]
# KNN model score (accuracy): 1.0
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Part 7: Conclusions and takeaways
#
# In your own words describe the results of the notebook. Which model(s) performed the best on the dataset? Why do you think that is? Did anything surprise you about the exercise?
# The model that preformed the best was the K-nearest neighbors model as the accuracy score was a 1 which indicates it is a very accurate model.
